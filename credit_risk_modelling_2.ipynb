# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import Data

# %%
loan_data_backup = pd.read_csv(r'D:\data\credit_risk\loan_data_2007_2014.csv')
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\3901339210.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_data_backup = pd.read_csv(r'D:\data\credit_risk\loan_data_2007_2014.csv')

# %%
loan_data = loan_data_backup.copy()

# %% [markdown]
# # Explore Data

# %%
pd.options.display.max_columns = None

# %%
loan_data.head()
# Out:
#    Unnamed: 0       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           0  1077501    1296599       5000         5000           4975.0
# 1           1  1077430    1314167       2500         2500           2500.0
# 2           2  1077175    1313524       2400         2400           2400.0
# 3           3  1076863    1277178      10000        10000          10000.0
# 4           4  1075358    1311748       3000         3000           3000.0
#
#          term  int_rate  installment grade sub_grade  \
# 0   36 months     10.65       162.87     B        B2
# 1   60 months     15.27        59.83     C        C4
# 2   36 months     15.96        84.33     C        C5
# 3   36 months     13.49       339.31     C        C1
# 4   60 months     12.69        67.79     B        B5
#
#                   emp_title emp_length home_ownership  annual_inc  \
# 0                       NaN  10+ years           RENT     24000.0
# 1                     Ryder   < 1 year           RENT     30000.0
# 2                       NaN  10+ years           RENT     12252.0
# 3       AIR RESOURCES BOARD  10+ years           RENT     49200.0
# 4  University Medical Group     1 year           RENT     80000.0
#
#   verification_status issue_d  loan_status pymnt_plan  \
# 0            Verified  Dec-11   Fully Paid          n
# 1     Source Verified  Dec-11  Charged Off          n
# 2        Not Verified  Dec-11   Fully Paid          n
# 3     Source Verified  Dec-11   Fully Paid          n
# 4     Source Verified  Dec-11      Current          n
#
#                                                  url  \
# 0  https://www.lendingclub.com/browse/loanDetail....
# 1  https://www.lendingclub.com/browse/loanDetail....
# 2  https://www.lendingclub.com/browse/loanDetail....
# 3  https://www.lendingclub.com/browse/loanDetail....
# 4  https://www.lendingclub.com/browse/loanDetail....
#
#                                                 desc         purpose  \
# 0    Borrower added on 12/22/11 > I need to upgra...     credit_card
# 1    Borrower added on 12/22/11 > I plan to use t...             car
# 2                                                NaN  small_business
# 3    Borrower added on 12/21/11 > to pay for prop...           other
# 4    Borrower added on 12/21/11 > I plan on combi...           other
#
#                   title zip_code addr_state    dti  delinq_2yrs  \
# 0              Computer    860xx         AZ  27.65          0.0
# 1                  bike    309xx         GA   1.00          0.0
# 2  real estate business    606xx         IL   8.72          0.0
# 3              personel    917xx         CA  20.00          0.0
# 4              Personal    972xx         OR  17.94          0.0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0           Jan-85             1.0                     NaN
# 1           Apr-99             5.0                     NaN
# 2           Nov-01             2.0                     NaN
# 3           Feb-96             1.0                    35.0
# 4           Jan-96             0.0                    38.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                     NaN       3.0      0.0      13648        83.7
# 1                     NaN       3.0      0.0       1687         9.4
# 2                     NaN       2.0      0.0       2956        98.5
# 3                     NaN      10.0      0.0       5598        21.0
# 4                     NaN      15.0      0.0      27783        53.9
#
#    total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0        9.0                   f        0.0            0.0   5861.071414
# 1        4.0                   f        0.0            0.0   1008.710000
# 2       10.0                   f        0.0            0.0   3003.653644
# 3       37.0                   f        0.0            0.0  12226.302210
# 4       38.0                   f      766.9          766.9   3242.170000
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          5831.78          5000.00         861.07                0.00
# 1          1008.71           456.46         435.17                0.00
# 2          3003.65          2400.00         603.65                0.00
# 3         12226.30         10000.00        2209.33               16.97
# 4          3242.17          2233.10        1009.07                0.00
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0        0.00                     0.00       Jan-15           171.62
# 1      117.08                     1.11       Apr-13           119.66
# 2        0.00                     0.00       Jun-14           649.91
# 3        0.00                     0.00       Jan-15           357.48
# 4        0.00                     0.00       Jan-16            67.79
#
#   next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0          NaN             Jan-16                         0.0
# 1          NaN             Sep-13                         0.0
# 2          NaN             Jan-16                         0.0
# 3          NaN             Jan-15                         0.0
# 4       Feb-16             Jan-16                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN            1       INDIVIDUAL
# 1                          NaN            1       INDIVIDUAL
# 2                          NaN            1       INDIVIDUAL
# 3                          NaN            1       INDIVIDUAL
# 4                          NaN            1       INDIVIDUAL
#
#    annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                        NaN             0.0
# 1               NaN        NaN                        NaN             0.0
# 2               NaN        NaN                        NaN             0.0
# 3               NaN        NaN                        NaN             0.0
# 4               NaN        NaN                        NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 0           NaN          NaN          NaN         NaN          NaN
# 1           NaN          NaN          NaN         NaN          NaN
# 2           NaN          NaN          NaN         NaN          NaN
# 3           NaN          NaN          NaN         NaN          NaN
# 4           NaN          NaN          NaN         NaN          NaN
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          NaN                 NaN           NaN      NaN          NaN
# 1          NaN                 NaN           NaN      NaN          NaN
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          NaN                 NaN           NaN      NaN          NaN
# 4          NaN                 NaN           NaN      NaN          NaN
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          NaN         NaN       NaN               NaN     NaN          NaN
# 1          NaN         NaN       NaN               NaN     NaN          NaN
# 2          NaN         NaN       NaN               NaN     NaN          NaN
# 3          NaN         NaN       NaN               NaN     NaN          NaN
# 4          NaN         NaN       NaN               NaN     NaN          NaN
#
#    inq_last_12m
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
loan_data.tail()
# Out:
#         Unnamed: 0       id  member_id  loan_amnt  funded_amnt  \
# 466280      466280  8598660    1440975      18400        18400
# 466281      466281  9684700   11536848      22000        22000
# 466282      466282  9584776   11436914      20700        20700
# 466283      466283  9604874   11457002       2000         2000
# 466284      466284  9199665   11061576      10000        10000
#
#         funded_amnt_inv        term  int_rate  installment grade sub_grade  \
# 466280          18400.0   60 months     14.47       432.64     C        C2
# 466281          22000.0   60 months     19.97       582.50     D        D5
# 466282          20700.0   60 months     16.99       514.34     D        D1
# 466283           2000.0   36 months      7.90        62.59     A        A4
# 466284           9975.0   36 months     19.20       367.58     D        D3
#
#                                     emp_title emp_length home_ownership  \
# 466280                     Financial Advisor     4 years       MORTGAGE
# 466281  Chief of Interpretation (Park Ranger)  10+ years       MORTGAGE
# 466282                                 patrol    7 years       MORTGAGE
# 466283                   Server Engineer Lead    3 years            OWN
# 466284                                    NaN  10+ years       MORTGAGE
#
#         annual_inc verification_status issue_d  loan_status pymnt_plan  \
# 466280    110000.0     Source Verified  Jan-14      Current          n
# 466281     78000.0            Verified  Jan-14  Charged Off          n
# 466282     46000.0            Verified  Jan-14      Current          n
# 466283     83000.0            Verified  Jan-14   Fully Paid          n
# 466284     46000.0            Verified  Jan-14      Current          n
#
#                                                       url  \
# 466280  https://www.lendingclub.com/browse/loanDetail....
# 466281  https://www.lendingclub.com/browse/loanDetail....
# 466282  https://www.lendingclub.com/browse/loanDetail....
# 466283  https://www.lendingclub.com/browse/loanDetail....
# 466284  https://www.lendingclub.com/browse/loanDetail....
#
#                                                      desc             purpose  \
# 466280                                                NaN  debt_consolidation
# 466281                                                NaN  debt_consolidation
# 466282    Borrower added on 12/06/13 > I am going to c...  debt_consolidation
# 466283                                                NaN         credit_card
# 466284    Borrower added on 12/04/13 > I will like a l...               other
#
#                           title zip_code addr_state    dti  delinq_2yrs  \
# 466280       Debt consolidation    773xx         TX  19.85          0.0
# 466281       Debt consolidation    377xx         TN  18.45          0.0
# 466282       Debt consolidation    458xx         OH  25.65          0.0
# 466283  Credit card refinancing    913xx         CA   5.39          3.0
# 466284                    Other    950xx         CA  22.78          1.0
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 466280           Apr-03             2.0                     NaN
# 466281           Jun-97             5.0                     NaN
# 466282           Dec-01             2.0                    65.0
# 466283           Feb-03             1.0                    13.0
# 466284           Feb-00             0.0                     9.0
#
#         mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 466280                     NaN      18.0      0.0      23208        77.6
# 466281                   116.0      18.0      1.0      18238        46.3
# 466282                     NaN      18.0      0.0       6688        51.1
# 466283                     NaN      21.0      0.0      11404        21.5
# 466284                     NaN       6.0      0.0      11325        70.8
#
#         total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 466280       36.0                   w   12574.00       12574.00  10383.360000
# 466281       30.0                   f       0.00           0.00   4677.920000
# 466282       43.0                   f   14428.31       14428.31  12343.980000
# 466283       27.0                   w       0.00           0.00   2126.579838
# 466284       22.0                   f    3984.38        3974.41   8821.620000
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 466280         10383.36          5826.00        4557.36                 0.0
# 466281          4677.92          1837.04        2840.88                 0.0
# 466282         12343.98          6271.69        6072.29                 0.0
# 466283          2126.58          2000.00         126.58                 0.0
# 466284          8799.57          6015.62        2806.00                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 466280         0.0                      0.0       Jan-16           432.64
# 466281         0.0                      0.0       Dec-14            17.50
# 466282         0.0                      0.0       Jan-16           514.34
# 466283         0.0                      0.0       Dec-14          1500.68
# 466284         0.0                      0.0       Jan-16           367.58
#
#        next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 466280       Feb-16             Jan-16                         0.0
# 466281          NaN             Jan-16                         0.0
# 466282       Feb-16             Dec-15                         0.0
# 466283          NaN             Apr-15                         0.0
# 466284       Feb-16             Jan-16                         0.0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 466280                          NaN            1       INDIVIDUAL
# 466281                          NaN            1       INDIVIDUAL
# 466282                          NaN            1       INDIVIDUAL
# 466283                          NaN            1       INDIVIDUAL
# 466284                          NaN            1       INDIVIDUAL
#
#         annual_inc_joint  dti_joint  verification_status_joint  \
# 466280               NaN        NaN                        NaN
# 466281               NaN        NaN                        NaN
# 466282               NaN        NaN                        NaN
# 466283               NaN        NaN                        NaN
# 466284               NaN        NaN                        NaN
#
#         acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  \
# 466280             0.0           0.0     294998.0          NaN         NaN
# 466281             0.0           0.0     221830.0          NaN         NaN
# 466282             0.0           0.0      73598.0          NaN         NaN
# 466283             0.0           0.0     591610.0          NaN         NaN
# 466284             0.0           0.0      57477.0          NaN         NaN
#
#         open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 466280          NaN          NaN                 NaN           NaN      NaN
# 466281          NaN          NaN                 NaN           NaN      NaN
# 466282          NaN          NaN                 NaN           NaN      NaN
# 466283          NaN          NaN                 NaN           NaN      NaN
# 466284          NaN          NaN                 NaN           NaN      NaN
#
#         open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 466280          NaN          NaN         NaN       NaN           29900.0
# 466281          NaN          NaN         NaN       NaN           39400.0
# 466282          NaN          NaN         NaN       NaN           13100.0
# 466283          NaN          NaN         NaN       NaN           53100.0
# 466284          NaN          NaN         NaN       NaN           16000.0
#
#         inq_fi  total_cu_tl  inq_last_12m
# 466280     NaN          NaN           NaN
# 466281     NaN          NaN           NaN
# 466282     NaN          NaN           NaN
# 466283     NaN          NaN           NaN
# 466284     NaN          NaN           NaN

# %%
loan_data.columns.values
# Out:
# array(['Unnamed: 0', 'id', 'member_id', 'loan_amnt', 'funded_amnt',
#        'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade',
#        'sub_grade', 'emp_title', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee',
#        'recoveries', 'collection_recovery_fee', 'last_pymnt_d',
#        'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'open_acc_6m', 'open_il_6m', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m'],
#       dtype=object)

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  object
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  object
#  10  sub_grade                    466285 non-null  object
#  11  emp_title                    438697 non-null  object
#  12  emp_length                   445277 non-null  object
#  13  home_ownership               466285 non-null  object
#  14  annual_inc                   466281 non-null  float64
#  15  verification_status          466285 non-null  object
#  16  issue_d                      466285 non-null  object
#  17  loan_status                  466285 non-null  object
#  18  pymnt_plan                   466285 non-null  object
#  19  url                          466285 non-null  object
#  20  desc                         125981 non-null  object
#  21  purpose                      466285 non-null  object
#  22  title                        466264 non-null  object
#  23  zip_code                     466285 non-null  object
#  24  addr_state                   466285 non-null  object
#  25  dti                          466285 non-null  float64
#  26  delinq_2yrs                  466256 non-null  float64
#  27  earliest_cr_line             466256 non-null  object
#  28  inq_last_6mths               466256 non-null  float64
#  29  mths_since_last_delinq       215934 non-null  float64
#  30  mths_since_last_record       62638 non-null   float64
#  31  open_acc                     466256 non-null  float64
#  32  pub_rec                      466256 non-null  float64
#  33  revol_bal                    466285 non-null  int64
#  34  revol_util                   465945 non-null  float64
#  35  total_acc                    466256 non-null  float64
#  36  initial_list_status          466285 non-null  object
#  37  out_prncp                    466285 non-null  float64
#  38  out_prncp_inv                466285 non-null  float64
#  39  total_pymnt                  466285 non-null  float64
#  40  total_pymnt_inv              466285 non-null  float64
#  41  total_rec_prncp              466285 non-null  float64
#  42  total_rec_int                466285 non-null  float64
#  43  total_rec_late_fee           466285 non-null  float64
#  44  recoveries                   466285 non-null  float64
#  45  collection_recovery_fee      466285 non-null  float64
#  46  last_pymnt_d                 465909 non-null  object
#  47  last_pymnt_amnt              466285 non-null  float64
#  48  next_pymnt_d                 239071 non-null  object
#  49  last_credit_pull_d           466243 non-null  object
#  50  collections_12_mths_ex_med   466140 non-null  float64
#  51  mths_since_last_major_derog  98974 non-null   float64
#  52  policy_code                  466285 non-null  int64
#  53  application_type             466285 non-null  object
#  54  annual_inc_joint             0 non-null       float64
#  55  dti_joint                    0 non-null       float64
#  56  verification_status_joint    0 non-null       float64
#  57  acc_now_delinq               466256 non-null  float64
#  58  tot_coll_amt                 396009 non-null  float64
#  59  tot_cur_bal                  396009 non-null  float64
#  60  open_acc_6m                  0 non-null       float64
#  61  open_il_6m                   0 non-null       float64
#  62  open_il_12m                  0 non-null       float64
#  63  open_il_24m                  0 non-null       float64
#  64  mths_since_rcnt_il           0 non-null       float64
#  65  total_bal_il                 0 non-null       float64
#  66  il_util                      0 non-null       float64
#  67  open_rv_12m                  0 non-null       float64
#  68  open_rv_24m                  0 non-null       float64
#  69  max_bal_bc                   0 non-null       float64
#  70  all_util                     0 non-null       float64
#  71  total_rev_hi_lim             396009 non-null  float64
#  72  inq_fi                       0 non-null       float64
#  73  total_cu_tl                  0 non-null       float64
#  74  inq_last_12m                 0 non-null       float64
# dtypes: float64(46), int64(7), object(22)
# memory usage: 266.8+ MB

# %% [markdown]
# # Cleaning Data

# %%
loan_data['emp_length'].unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %%
loan_data['emp_length_int'] = loan_data['emp_length'].str.replace(r'+ years','')
loan_data['emp_length_int'] = loan_data['emp_length_int'].str.replace('< 1 year', str(0))
loan_data.fillna('0')
loan_data['emp_length_int'] = loan_data['emp_length_int'].str.replace('years', '')
loan_data['emp_length_int'] = loan_data['emp_length_int'].str.replace('year', '')

# %%
loan_data['emp_length_int'].unique()
# Out:
# array(['10', '0', '1 ', '3 ', '8 ', '9 ', '4 ', '5 ', '6 ', '2 ', '7 ',
#        nan], dtype=object)

# %%
type(loan_data['emp_length_int'][0])
# Out:
# str

# %%
loan_data['emp_length_int']= pd.to_numeric(loan_data['emp_length_int'])

# %%
type(loan_data['emp_length_int'][0])
# Out:
# numpy.float64

# %%
loan_data['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
loan_data['term_int'] = loan_data['term'].str.replace('months','')

# %%
loan_data['term_int']= pd.to_numeric(loan_data['term_int'])

# %%
type(loan_data['term_int'][0])
# Out:
# numpy.int64

# %%
#loan_data['earliest_cr_line']

# %%
loan_data['earliest_cr_line_date'] = pd.to_datetime(loan_data['earliest_cr_line'],format = '%b-%y', errors='coerce')
#loan_data['earliest_cr_line_date']

# %%
type(loan_data['earliest_cr_line_date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
pd.to_datetime('2017-12-01') - loan_data['earliest_cr_line_date'] 
#the data is old so we are using dec 2017 as our reference point in practice, it would be today's date
# Out:
# 0        12022 days
# 1         6819 days
# 2         5874 days
# 3         7974 days
# 4         8005 days
#             ...
# 466280    5358 days
# 466281    7488 days
# 466282    5844 days
# 466283    5417 days
# 466284    6513 days
# Name: earliest_cr_line_date, Length: 466285, dtype: timedelta64[ns]

# %%
loan_data['mths_end'] = pd.to_datetime('2017-12-01').to_period('M')

# %%
loan_data['mths_start'] = loan_data['earliest_cr_line_date'].dt.to_period('M') #convert series to period

# %%
loan_data['mths_since_earliest_cr_line']=(loan_data['mths_end'].astype('int64')-loan_data['mths_start'].astype('int64'))
loan_data['mths_since_earliest_cr_line'].describe()
# Out:
# count    4.662850e+05
# mean    -5.736358e+14
# std      7.273609e+16
# min     -9.223372e+18
# 25%      1.830000e+02
# 50%      2.250000e+02
# 75%      2.850000e+02
# max      5.870000e+02
# Name: mths_since_earliest_cr_line, dtype: float64

# %%
loan_data.loc[:,['earliest_cr_line','earliest_cr_line_date','mths_since_earliest_cr_line']][loan_data['mths_since_earliest_cr_line']<0]
# Out:
#        earliest_cr_line earliest_cr_line_date  mths_since_earliest_cr_line
# 1580             Sep-62            2062-09-01                         -537
# 1770             Sep-68            2068-09-01                         -609
# 2799             Sep-64            2064-09-01                         -561
# 3282             Sep-67            2067-09-01                         -597
# 3359             Feb-65            2065-02-01                         -566
# ...                 ...                   ...                          ...
# 464003           Jan-68            2068-01-01                         -601
# 464260           Jul-66            2066-07-01                         -583
# 465100           Oct-67            2067-10-01                         -598
# 465500           Sep-67            2067-09-01                         -597
# 465655           Jan-56            2056-01-01                         -457
#
# [1198 rows x 3 columns]

# %%
loan_data.loc[loan_data['mths_since_earliest_cr_line']<0]
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 1580          1580   1048395    1279722      21000        21000
# 1770          1770   1042802    1272895       5500         5500
# 2799          2799   1031659    1249389       5200         5200
# 3282          3282   1021976    1250746       5000         5000
# 3359          3359   1013619    1240971      21000        21000
# ...            ...       ...        ...        ...          ...
# 464003      464003  10080767   11932249       3650         3650
# 464260      464260  10106909   11958941      22500        22500
# 465100      465100  10109870   11961435      14000        14000
# 465500      465500  10099451   11951054       2500         2500
# 465655      465655  10088416   11940047      21000        21000
#
#         funded_amnt_inv        term  int_rate  installment grade sub_grade  \
# 1580            20875.0   36 months      7.51       653.33     A        A3
# 1770             5500.0   36 months      7.51       171.11     A        A3
# 2799             5200.0   60 months      8.90       107.70     A        A5
# 3282             5000.0   36 months     12.69       167.73     B        B5
# 3359            21000.0   36 months     12.69       704.45     B        B5
# ...                 ...         ...       ...          ...   ...       ...
# 464003           3650.0   36 months     16.24       128.76     C        C5
# 464260          22500.0   36 months      6.62       690.84     A        A2
# 465100          13850.0   36 months      9.67       449.58     B        B1
# 465500           2500.0   36 months     19.22        91.92     D        D4
# 465655          20950.0   36 months      9.67       674.37     B        B1
#
#                         emp_title emp_length home_ownership  annual_inc  \
# 1580                          NaN        NaN       MORTGAGE     49200.0
# 1770     AstroMotive Auto Service    4 years           RENT     63000.0
# 2799                          NaN        NaN           RENT     36000.0
# 3282    Pittsburgh Public Schools  10+ years       MORTGAGE     72000.0
# 3359               MAJR Financial  10+ years       MORTGAGE    267000.0
# ...                           ...        ...            ...         ...
# 464003                        NaN        NaN       MORTGAGE     46000.0
# 464260            Fitness Manager    4 years           RENT     50000.0
# 465100         Utilities Director    7 years       MORTGAGE     80100.0
# 465500                        NaN        NaN       MORTGAGE     34908.0
# 465655                        NaN  10+ years       MORTGAGE     72000.0
#
#        verification_status issue_d        loan_status pymnt_plan  \
# 1580              Verified  Dec-11         Fully Paid          n
# 1770              Verified  Dec-11         Fully Paid          n
# 2799       Source Verified  Nov-11  Late (16-30 days)          n
# 3282       Source Verified  Nov-11         Fully Paid          n
# 3359       Source Verified  Nov-11         Fully Paid          n
# ...                    ...     ...                ...        ...
# 464003            Verified  Jan-14            Current          n
# 464260            Verified  Jan-14         Fully Paid          n
# 465100        Not Verified  Jan-14            Current          n
# 465500     Source Verified  Jan-14        Charged Off          n
# 465655            Verified  Jan-14        Charged Off          n
#
#                                                       url  \
# 1580    https://www.lendingclub.com/browse/loanDetail....
# 1770    https://www.lendingclub.com/browse/loanDetail....
# 2799    https://www.lendingclub.com/browse/loanDetail....
# 3282    https://www.lendingclub.com/browse/loanDetail....
# 3359    https://www.lendingclub.com/browse/loanDetail....
# ...                                                   ...
# 464003  https://www.lendingclub.com/browse/loanDetail....
# 464260  https://www.lendingclub.com/browse/loanDetail....
# 465100  https://www.lendingclub.com/browse/loanDetail....
# 465500  https://www.lendingclub.com/browse/loanDetail....
# 465655  https://www.lendingclub.com/browse/loanDetail....
#
#                                                      desc             purpose  \
# 1580                                                  NaN         credit_card
# 1770      Borrower added on 11/28/11 > investment qual...               other
# 2799                                                  NaN            vacation
# 3282      Borrower added on 11/11/11 > Family Vacation...            vacation
# 3359      Borrower added on 11/10/11 > Funds will be u...      small_business
# ...                                                   ...                 ...
# 464003                                                NaN         credit_card
# 464260                                                NaN  debt_consolidation
# 465100    Borrower added on 12/31/13 > Using Lending C...         credit_card
# 465500                                                NaN      major_purchase
# 465655    Borrower added on 12/31/13 > debt consolidat...  debt_consolidation
#
#                             title zip_code addr_state    dti  delinq_2yrs  \
# 1580                Happiness is     591xx         MT  27.02          0.0
# 1770                   shovelhead    902xx         CA   5.56          2.0
# 2799             Wedding/Vacation    109xx         NY   8.17          0.0
# 3282               Family getaway    151xx         PA   7.75          0.0
# 3359             Growing Business    801xx         CO   8.87          0.0
# ...                           ...      ...        ...    ...          ...
# 464003                Home Repair    275xx         NC   9.91          0.0
# 464260  Credit Debt Consolidation    105xx         NY  25.66          0.0
# 465100    Credit card refinancing    661xx         KS  11.69          1.0
# 465500                  Stay Warm    358xx         AL  16.71          0.0
# 465655                      REFIN    927xx         CA  26.02          0.0
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 1580             Sep-62             1.0                     NaN
# 1770             Sep-68             0.0                    13.0
# 2799             Sep-64             0.0                     NaN
# 3282             Sep-67             1.0                    49.0
# 3359             Feb-65             2.0                    46.0
# ...                 ...             ...                     ...
# 464003           Jan-68             2.0                    50.0
# 464260           Jul-66             1.0                     NaN
# 465100           Oct-67             0.0                     7.0
# 465500           Sep-67             1.0                    52.0
# 465655           Jan-56             0.0                    48.0
#
#         mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 1580                       NaN       8.0      0.0      14491        19.7
# 1770                       NaN       6.0      0.0       6981        20.1
# 2799                       NaN       6.0      0.0        465         2.2
# 3282                       NaN       5.0      0.0       4477        32.2
# 3359                       NaN      10.0      0.0      51942        36.8
# ...                        ...       ...      ...        ...         ...
# 464003                     NaN       8.0      0.0      13852        66.0
# 464260                     NaN      16.0      0.0      27776        30.2
# 465100                     NaN      22.0      0.0       9209        30.4
# 465500                     NaN       9.0      0.0       8660        84.1
# 465655                    54.0      11.0      1.0       7854        40.5
#
#         total_acc initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 1580         15.0                   f       0.00           0.00  23043.77000
# 1770         15.0                   f       0.00           0.00   5538.32000
# 2799         25.0                   f    1254.13        1254.13   5177.93000
# 3282         25.0                   f       0.00           0.00   6034.82655
# 3359         27.0                   f       0.00           0.00  25354.04165
# ...           ...                 ...        ...            ...          ...
# 464003       23.0                   f    1417.30        1417.30   3090.10000
# 464260       30.0                   f       0.00           0.00  23502.82531
# 465100       48.0                   f    5122.93        5068.04  10789.33000
# 465500       17.0                   f       0.00           0.00   1654.43000
# 465655       41.0                   f       0.00           0.00   2022.20000
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 1580           22906.61         21000.00        2043.77            0.000000
# 1770            5538.32          5500.00          38.32            0.000000
# 2799            5177.93          3945.87        1202.09           29.962286
# 3282            6034.83          5000.00        1034.83            0.000000
# 3359           25354.04         21000.00        4354.04            0.000000
# ...                 ...              ...            ...                 ...
# 464003          3090.10          2232.70         857.40            0.000000
# 464260         23502.83         22500.00        1002.83            0.000000
# 465100         10673.73          8877.07        1912.26            0.000000
# 465500          1654.43          1072.41         582.02            0.000000
# 465655          2017.39          1527.00         495.20            0.000000
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 1580           0.0                      0.0       Sep-13         10000.95
# 1770           0.0                      0.0       Feb-12           539.21
# 2799           0.0                      0.0       Dec-15           107.70
# 3282           0.0                      0.0       Dec-14           187.76
# 3359           0.0                      0.0       Dec-14           725.56
# ...            ...                      ...          ...              ...
# 464003         0.0                      0.0       Jan-16           128.76
# 464260         0.0                      0.0       Oct-14         17977.71
# 465100         0.0                      0.0       Jan-16           449.58
# 465500         0.0                      0.0       Jul-15            91.92
# 465655         0.0                      0.0       Apr-14           674.37
#
#        next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 1580            NaN             Sep-13                         0.0
# 1770            NaN             Sep-15                         0.0
# 2799         Feb-16             Jan-16                         0.0
# 3282            NaN             May-15                         0.0
# 3359            NaN             Nov-14                         0.0
# ...             ...                ...                         ...
# 464003       Feb-16             Jan-16                         0.0
# 464260          NaN             Dec-15                         0.0
# 465100       Feb-16             Jan-16                         0.0
# 465500          NaN             Sep-15                         0.0
# 465655          NaN             Mar-14                         0.0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 1580                            NaN            1       INDIVIDUAL
# 1770                            NaN            1       INDIVIDUAL
# 2799                            NaN            1       INDIVIDUAL
# 3282                            NaN            1       INDIVIDUAL
# 3359                            NaN            1       INDIVIDUAL
# ...                             ...          ...              ...
# 464003                          NaN            1       INDIVIDUAL
# 464260                          NaN            1       INDIVIDUAL
# 465100                          7.0            1       INDIVIDUAL
# 465500                         52.0            1       INDIVIDUAL
# 465655                          NaN            1       INDIVIDUAL
#
#         annual_inc_joint  dti_joint  verification_status_joint  \
# 1580                 NaN        NaN                        NaN
# 1770                 NaN        NaN                        NaN
# 2799                 NaN        NaN                        NaN
# 3282                 NaN        NaN                        NaN
# 3359                 NaN        NaN                        NaN
# ...                  ...        ...                        ...
# 464003               NaN        NaN                        NaN
# 464260               NaN        NaN                        NaN
# 465100               NaN        NaN                        NaN
# 465500               NaN        NaN                        NaN
# 465655               NaN        NaN                        NaN
#
#         acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  \
# 1580               0.0           NaN          NaN          NaN         NaN
# 1770               0.0           NaN          NaN          NaN         NaN
# 2799               0.0           NaN          NaN          NaN         NaN
# 3282               0.0           NaN          NaN          NaN         NaN
# 3359               0.0           NaN          NaN          NaN         NaN
# ...                ...           ...          ...          ...         ...
# 464003             0.0         150.0      13852.0          NaN         NaN
# 464260             0.0           0.0      69218.0          NaN         NaN
# 465100             0.0           0.0     114817.0          NaN         NaN
# 465500             0.0           0.0      18962.0          NaN         NaN
# 465655             0.0           0.0      43364.0          NaN         NaN
#
#         open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 1580            NaN          NaN                 NaN           NaN      NaN
# 1770            NaN          NaN                 NaN           NaN      NaN
# 2799            NaN          NaN                 NaN           NaN      NaN
# 3282            NaN          NaN                 NaN           NaN      NaN
# 3359            NaN          NaN                 NaN           NaN      NaN
# ...             ...          ...                 ...           ...      ...
# 464003          NaN          NaN                 NaN           NaN      NaN
# 464260          NaN          NaN                 NaN           NaN      NaN
# 465100          NaN          NaN                 NaN           NaN      NaN
# 465500          NaN          NaN                 NaN           NaN      NaN
# 465655          NaN          NaN                 NaN           NaN      NaN
#
#         open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 1580            NaN          NaN         NaN       NaN               NaN
# 1770            NaN          NaN         NaN       NaN               NaN
# 2799            NaN          NaN         NaN       NaN               NaN
# 3282            NaN          NaN         NaN       NaN               NaN
# 3359            NaN          NaN         NaN       NaN               NaN
# ...             ...          ...         ...       ...               ...
# 464003          NaN          NaN         NaN       NaN           21000.0
# 464260          NaN          NaN         NaN       NaN           91900.0
# 465100          NaN          NaN         NaN       NaN           30300.0
# 465500          NaN          NaN         NaN       NaN           10300.0
# 465655          NaN          NaN         NaN       NaN           19400.0
#
#         inq_fi  total_cu_tl  inq_last_12m  emp_length_int  term_int  \
# 1580       NaN          NaN           NaN             NaN        36
# 1770       NaN          NaN           NaN             4.0        36
# 2799       NaN          NaN           NaN             NaN        60
# 3282       NaN          NaN           NaN            10.0        36
# 3359       NaN          NaN           NaN            10.0        36
# ...        ...          ...           ...             ...       ...
# 464003     NaN          NaN           NaN             NaN        36
# 464260     NaN          NaN           NaN             4.0        36
# 465100     NaN          NaN           NaN             7.0        36
# 465500     NaN          NaN           NaN             NaN        36
# 465655     NaN          NaN           NaN            10.0        36
#
#        earliest_cr_line_date mths_end mths_start  mths_since_earliest_cr_line
# 1580              2062-09-01  2017-12    2062-09                         -537
# 1770              2068-09-01  2017-12    2068-09                         -609
# 2799              2064-09-01  2017-12    2064-09                         -561
# 3282              2067-09-01  2017-12    2067-09                         -597
# 3359              2065-02-01  2017-12    2065-02                         -566
# ...                      ...      ...        ...                          ...
# 464003            2068-01-01  2017-12    2068-01                         -601
# 464260            2066-07-01  2017-12    2066-07                         -583
# 465100            2067-10-01  2017-12    2067-10                         -598
# 465500            2067-09-01  2017-12    2067-09                         -597
# 465655            2056-01-01  2017-12    2056-01                         -457
#
# [1198 rows x 81 columns]

# %%
loan_data.loc[loan_data['mths_since_earliest_cr_line']<0,['mths_since_earliest_cr_line']]=loan_data['mths_since_earliest_cr_line'].max()

# %%
min(loan_data['mths_since_earliest_cr_line'])
# Out:
# 73

# %%
loan_data['issue_d']
# Out:
# 0         Dec-11
# 1         Dec-11
# 2         Dec-11
# 3         Dec-11
# 4         Dec-11
#            ...
# 466280    Jan-14
# 466281    Jan-14
# 466282    Jan-14
# 466283    Jan-14
# 466284    Jan-14
# Name: issue_d, Length: 466285, dtype: object

# %%
loan_data['issue_d_date'] = pd.to_datetime(loan_data['issue_d'],format = '%b-%y', errors='coerce')
loan_data['issue_d_date'] = loan_data['issue_d_date'].dt.to_period('M')

# %%
loan_data['mths_end'] = pd.to_datetime('2017-12-01').to_period('M') 
loan_data['mths_since_issue_d']=(loan_data['mths_end'].astype('int64')-loan_data['issue_d_date'].astype('int64'))
loan_data['mths_since_issue_d'].describe()
# Out:
# count    466285.000000
# mean         51.255187
# std          14.340154
# min          36.000000
# 25%          41.000000
# 50%          47.000000
# 75%          57.000000
# max         126.000000
# Name: mths_since_issue_d, dtype: float64

# %%
loan_data.loc[:,['issue_d','issue_d_date','mths_since_issue_d']][loan_data['mths_since_issue_d']<0]
# Out:
# Empty DataFrame
# Columns: [issue_d, issue_d_date, mths_since_issue_d]
# Index: []

# %%
loan_data.loc[loan_data['mths_since_earliest_cr_line']<0,['mths_since_earliest_cr_line']]=loan_data['mths_since_earliest_cr_line'].max()

# %%
min(loan_data['mths_since_earliest_cr_line'])
# Out:
# 73

# %% [markdown]
# ## create dummy variables for categorical variables

# %%
loan_data_dummies =[pd.get_dummies(loan_data['grade'],prefix = 'grade', prefix_sep=':'),
                    pd.get_dummies(loan_data['sub_grade'],prefix ='sub_grade', prefix_sep =':'),
                    pd.get_dummies(loan_data['home_ownership'],prefix ='home_ownership', prefix_sep =':'),
                    pd.get_dummies(loan_data['verification_status'],prefix ='verification_status', prefix_sep =':'),
                    pd.get_dummies(loan_data['loan_status'], prefix ='loan_status', prefix_sep =':'),
                    pd.get_dummies(loan_data['purpose'], prefix ='purpose', prefix_sep =':'),
                    pd.get_dummies(loan_data['addr_state'], prefix ='addr_state', prefix_sep =':'),
                    pd.get_dummies(loan_data['initial_list_status'], prefix ='initial_list-status', prefix_sep =':')]

# %%
loan_data_dummies = pd.concat(loan_data_dummies, axis=1)

# %%
type(loan_data_dummies)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.options.display.max_rows = None
loan_data.isnull().sum()
# Out:
# Unnamed: 0                          0
# id                                  0
# member_id                           0
# loan_amnt                           0
# funded_amnt                         0
# funded_amnt_inv                     0
# term                                0
# int_rate                            0
# installment                         0
# grade                               0
# sub_grade                           0
# emp_title                       27588
# emp_length                      21008
# home_ownership                      0
# annual_inc                          4
# verification_status                 0
# issue_d                             0
# loan_status                         0
# pymnt_plan                          0
# url                                 0
# desc                           340304
# purpose                             0
# title                              21
# zip_code                            0
# addr_state                          0
# dti                                 0
# delinq_2yrs                        29
# earliest_cr_line                   29
# inq_last_6mths                     29
# mths_since_last_delinq         250351
# mths_since_last_record         403647
# open_acc                           29
# pub_rec                            29
# revol_bal                           0
# revol_util                        340
# total_acc                          29
# initial_list_status                 0
# out_prncp                           0
# out_prncp_inv                       0
# total_pymnt                         0
# total_pymnt_inv                     0
# total_rec_prncp                     0
# total_rec_int                       0
# total_rec_late_fee                  0
# recoveries                          0
# collection_recovery_fee             0
# last_pymnt_d                      376
# last_pymnt_amnt                     0
# next_pymnt_d                   227214
# last_credit_pull_d                 42
# collections_12_mths_ex_med        145
# mths_since_last_major_derog    367311
# policy_code                         0
# application_type                    0
# annual_inc_joint               466285
# dti_joint                      466285
# verification_status_joint      466285
# acc_now_delinq                     29
# tot_coll_amt                    70276
# tot_cur_bal                     70276
# open_acc_6m                    466285
# open_il_6m                     466285
# open_il_12m                    466285
# open_il_24m                    466285
# mths_since_rcnt_il             466285
# total_bal_il                   466285
# il_util                        466285
# open_rv_12m                    466285
# open_rv_24m                    466285
# max_bal_bc                     466285
# all_util                       466285
# total_rev_hi_lim                70276
# inq_fi                         466285
# total_cu_tl                    466285
# inq_last_12m                   466285
# emp_length_int                  21008
# term_int                            0
# earliest_cr_line_date              29
# mths_end                            0
# mths_start                         29
# mths_since_earliest_cr_line         0
# issue_d_date                        0
# mths_since_issue_d                  0
# dtype: int64

# %%
loan_data=pd.concat([loan_data,loan_data_dummies], axis=1)

# %%
loan_data.columns.values
# Out:
# array(['Unnamed: 0', 'id', 'member_id', 'loan_amnt', 'funded_amnt',
#        'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade',
#        'sub_grade', 'emp_title', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee',
#        'recoveries', 'collection_recovery_fee', 'last_pymnt_d',
#        'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'open_acc_6m', 'open_il_6m', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'emp_length_int', 'term_int', 'earliest_cr_line_date', 'mths_end',
#        'mths_start', 'mths_since_earliest_cr_line', 'issue_d_date',
#        'mths_since_issue_d', 'grade:A', 'grade:B', 'grade:C', 'grade:D',
#        'grade:E', 'grade:F', 'grade:G', 'sub_grade:A1', 'sub_grade:A2',
#        'sub_grade:A3', 'sub_grade:A4', 'sub_grade:A5', 'sub_grade:B1',
#        'sub_grade:B2', 'sub_grade:B3', 'sub_grade:B4', 'sub_grade:B5',
#        'sub_grade:C1', 'sub_grade:C2', 'sub_grade:C3', 'sub_grade:C4',
#        'sub_grade:C5', 'sub_grade:D1', 'sub_grade:D2', 'sub_grade:D3',
#        'sub_grade:D4', 'sub_grade:D5', 'sub_grade:E1', 'sub_grade:E2',
#        'sub_grade:E3', 'sub_grade:E4', 'sub_grade:E5', 'sub_grade:F1',
#        'sub_grade:F2', 'sub_grade:F3', 'sub_grade:F4', 'sub_grade:F5',
#        'sub_grade:G1', 'sub_grade:G2', 'sub_grade:G3', 'sub_grade:G4',
#        'sub_grade:G5', 'home_ownership:ANY', 'home_ownership:MORTGAGE',
#        'home_ownership:NONE', 'home_ownership:OTHER',
#        'home_ownership:OWN', 'home_ownership:RENT',
#        'verification_status:Not Verified',
#        'verification_status:Source Verified',
#        'verification_status:Verified', 'loan_status:Charged Off',
#        'loan_status:Current', 'loan_status:Default',
#        'loan_status:Does not meet the credit policy. Status:Charged Off',
#        'loan_status:Does not meet the credit policy. Status:Fully Paid',
#        'loan_status:Fully Paid', 'loan_status:In Grace Period',
#        'loan_status:Late (16-30 days)', 'loan_status:Late (31-120 days)',
#        'purpose:car', 'purpose:credit_card', 'purpose:debt_consolidation',
#        'purpose:educational', 'purpose:home_improvement', 'purpose:house',
#        'purpose:major_purchase', 'purpose:medical', 'purpose:moving',
#        'purpose:other', 'purpose:renewable_energy',
#        'purpose:small_business', 'purpose:vacation', 'purpose:wedding',
#        'addr_state:AK', 'addr_state:AL', 'addr_state:AR', 'addr_state:AZ',
#        'addr_state:CA', 'addr_state:CO', 'addr_state:CT', 'addr_state:DC',
#        'addr_state:DE', 'addr_state:FL', 'addr_state:GA', 'addr_state:HI',
#        'addr_state:IA', 'addr_state:ID', 'addr_state:IL', 'addr_state:IN',
#        'addr_state:KS', 'addr_state:KY', 'addr_state:LA', 'addr_state:MA',
#        'addr_state:MD', 'addr_state:ME', 'addr_state:MI', 'addr_state:MN',
#        'addr_state:MO', 'addr_state:MS', 'addr_state:MT', 'addr_state:NC',
#        'addr_state:NE', 'addr_state:NH', 'addr_state:NJ', 'addr_state:NM',
#        'addr_state:NV', 'addr_state:NY', 'addr_state:OH', 'addr_state:OK',
#        'addr_state:OR', 'addr_state:PA', 'addr_state:RI', 'addr_state:SC',
#        'addr_state:SD', 'addr_state:TN', 'addr_state:TX', 'addr_state:UT',
#        'addr_state:VA', 'addr_state:VT', 'addr_state:WA', 'addr_state:WI',
#        'addr_state:WV', 'addr_state:WY', 'initial_list-status:f',
#        'initial_list-status:w'], dtype=object)

# %% [markdown]
# ## Missing Values

# %%
pd.options.display.max_rows = None
loan_data.isnull().sum()
# Out:
# Unnamed: 0                                                              0
# id                                                                      0
# member_id                                                               0
# loan_amnt                                                               0
# funded_amnt                                                             0
# funded_amnt_inv                                                         0
# term                                                                    0
# int_rate                                                                0
# installment                                                             0
# grade                                                                   0
# sub_grade                                                               0
# emp_title                                                           27588
# emp_length                                                          21008
# home_ownership                                                          0
# annual_inc                                                              4
# verification_status                                                     0
# issue_d                                                                 0
# loan_status                                                             0
# pymnt_plan                                                              0
# url                                                                     0
# desc                                                               340304
# purpose                                                                 0
# title                                                                  21
# zip_code                                                                0
# addr_state                                                              0
# dti                                                                     0
# delinq_2yrs                                                            29
# earliest_cr_line                                                       29
# inq_last_6mths                                                         29
# mths_since_last_delinq                                             250351
# mths_since_last_record                                             403647
# open_acc                                                               29
# pub_rec                                                                29
# revol_bal                                                               0
# revol_util                                                            340
# total_acc                                                              29
# initial_list_status                                                     0
# out_prncp                                                               0
# out_prncp_inv                                                           0
# total_pymnt                                                             0
# total_pymnt_inv                                                         0
# total_rec_prncp                                                         0
# total_rec_int                                                           0
# total_rec_late_fee                                                      0
# recoveries                                                              0
# collection_recovery_fee                                                 0
# last_pymnt_d                                                          376
# last_pymnt_amnt                                                         0
# next_pymnt_d                                                       227214
# last_credit_pull_d                                                     42
# collections_12_mths_ex_med                                            145
# mths_since_last_major_derog                                        367311
# policy_code                                                             0
# application_type                                                        0
# annual_inc_joint                                                   466285
# dti_joint                                                          466285
# verification_status_joint                                          466285
# acc_now_delinq                                                         29
# tot_coll_amt                                                        70276
# tot_cur_bal                                                         70276
# open_acc_6m                                                        466285
# open_il_6m                                                         466285
# open_il_12m                                                        466285
# open_il_24m                                                        466285
# mths_since_rcnt_il                                                 466285
# total_bal_il                                                       466285
# il_util                                                            466285
# open_rv_12m                                                        466285
# open_rv_24m                                                        466285
# max_bal_bc                                                         466285
# all_util                                                           466285
# total_rev_hi_lim                                                    70276
# inq_fi                                                             466285
# total_cu_tl                                                        466285
# inq_last_12m                                                       466285
# emp_length_int                                                      21008
# term_int                                                                0
# earliest_cr_line_date                                                  29
# mths_end                                                                0
# mths_start                                                             29
# mths_since_earliest_cr_line                                             0
# issue_d_date                                                            0
# mths_since_issue_d                                                      0
# grade:A                                                                 0
# grade:B                                                                 0
# grade:C                                                                 0
# grade:D                                                                 0
# grade:E                                                                 0
# grade:F                                                                 0
# grade:G                                                                 0
# sub_grade:A1                                                            0
# sub_grade:A2                                                            0
# sub_grade:A3                                                            0
# sub_grade:A4                                                            0
# sub_grade:A5                                                            0
# sub_grade:B1                                                            0
# sub_grade:B2                                                            0
# sub_grade:B3                                                            0
# sub_grade:B4                                                            0
# sub_grade:B5                                                            0
# sub_grade:C1                                                            0
# sub_grade:C2                                                            0
# sub_grade:C3                                                            0
# sub_grade:C4                                                            0
# sub_grade:C5                                                            0
# sub_grade:D1                                                            0
# sub_grade:D2                                                            0
# sub_grade:D3                                                            0
# sub_grade:D4                                                            0
# sub_grade:D5                                                            0
# sub_grade:E1                                                            0
# sub_grade:E2                                                            0
# sub_grade:E3                                                            0
# sub_grade:E4                                                            0
# sub_grade:E5                                                            0
# sub_grade:F1                                                            0
# sub_grade:F2                                                            0
# sub_grade:F3                                                            0
# sub_grade:F4                                                            0
# sub_grade:F5                                                            0
# sub_grade:G1                                                            0
# sub_grade:G2                                                            0
# sub_grade:G3                                                            0
# sub_grade:G4                                                            0
# sub_grade:G5                                                            0
# home_ownership:ANY                                                      0
# home_ownership:MORTGAGE                                                 0
# home_ownership:NONE                                                     0
# home_ownership:OTHER                                                    0
# home_ownership:OWN                                                      0
# home_ownership:RENT                                                     0
# verification_status:Not Verified                                        0
# verification_status:Source Verified                                     0
# verification_status:Verified                                            0
# loan_status:Charged Off                                                 0
# loan_status:Current                                                     0
# loan_status:Default                                                     0
# loan_status:Does not meet the credit policy. Status:Charged Off         0
# loan_status:Does not meet the credit policy. Status:Fully Paid          0
# loan_status:Fully Paid                                                  0
# loan_status:In Grace Period                                             0
# loan_status:Late (16-30 days)                                           0
# loan_status:Late (31-120 days)                                          0
# purpose:car                                                             0
# purpose:credit_card                                                     0
# purpose:debt_consolidation                                              0
# purpose:educational                                                     0
# purpose:home_improvement                                                0
# purpose:house                                                           0
# purpose:major_purchase                                                  0
# purpose:medical                                                         0
# purpose:moving                                                          0
# purpose:other                                                           0
# purpose:renewable_energy                                                0
# purpose:small_business                                                  0
# purpose:vacation                                                        0
# purpose:wedding                                                         0
# addr_state:AK                                                           0
# addr_state:AL                                                           0
# addr_state:AR                                                           0
# addr_state:AZ                                                           0
# addr_state:CA                                                           0
# addr_state:CO                                                           0
# addr_state:CT                                                           0
# addr_state:DC                                                           0
# addr_state:DE                                                           0
# addr_state:FL                                                           0
# addr_state:GA                                                           0
# addr_state:HI                                                           0
# addr_state:IA                                                           0
# addr_state:ID                                                           0
# addr_state:IL                                                           0
# addr_state:IN                                                           0
# addr_state:KS                                                           0
# addr_state:KY                                                           0
# addr_state:LA                                                           0
# addr_state:MA                                                           0
# addr_state:MD                                                           0
# addr_state:ME                                                           0
# addr_state:MI                                                           0
# addr_state:MN                                                           0
# addr_state:MO                                                           0
# addr_state:MS                                                           0
# addr_state:MT                                                           0
# addr_state:NC                                                           0
# addr_state:NE                                                           0
# addr_state:NH                                                           0
# addr_state:NJ                                                           0
# addr_state:NM                                                           0
# addr_state:NV                                                           0
# addr_state:NY                                                           0
# addr_state:OH                                                           0
# addr_state:OK                                                           0
# addr_state:OR                                                           0
# addr_state:PA                                                           0
# addr_state:RI                                                           0
# addr_state:SC                                                           0
# addr_state:SD                                                           0
# addr_state:TN                                                           0
# addr_state:TX                                                           0
# addr_state:UT                                                           0
# addr_state:VA                                                           0
# addr_state:VT                                                           0
# addr_state:WA                                                           0
# addr_state:WI                                                           0
# addr_state:WV                                                           0
# addr_state:WY                                                           0
# initial_list-status:f                                                   0
# initial_list-status:w                                                   0
# dtype: int64

# %%
pd.options.display.max_rows = 100

# %%
loan_data['total_rev_hi_lim'].fillna(loan_data['funded_amnt'])
# Out:
# 0          5000.0
# 1          2500.0
# 2          2400.0
# 3         10000.0
# 4          3000.0
#            ...
# 466280    29900.0
# 466281    39400.0
# 466282    13100.0
# 466283    53100.0
# 466284    16000.0
# Name: total_rev_hi_lim, Length: 466285, dtype: float64

# %%
pd.options.display.max_columns = False
loan_data.loc[loan_data['annual_inc'].isnull()]
# Out:
#        Unnamed: 0     id  member_id  ...  addr_state:WY  initial_list-status:f  initial_list-status:w
# 42449       42449  79967      79912  ...          False                   True                  False
# 42450       42450  79924      79906  ...          False                   True                  False
# 42480       42480  79893      79878  ...          False                   True                  False
# 42533       42533  71623      70735  ...          False                   True                  False
#
# [4 rows x 209 columns]

# %%
annual_inc_mean=(loan_data['annual_inc']).mean
annual_inc_mean
loan_data['annual_inc'].fillna(annual_inc_mean)
# Out:
# 0          24000.0
# 1          30000.0
# 2          12252.0
# 3          49200.0
# 4          80000.0
#             ...
# 466280    110000.0
# 466281     78000.0
# 466282     46000.0
# 466283     83000.0
# 466284     46000.0
# Name: annual_inc, Length: 466285, dtype: object

# %%
loan_data['annual_inc'].isnull().sum()
# Out:
# 4

# %%
loan_data.fillna({'mths_since_earliest_cr_line':0}, inplace=True)
loan_data.fillna({'acc_now_delinq':0}, inplace=True)
loan_data.fillna({'total_acc':0}, inplace=True)
loan_data.fillna({'pub_rec':0}, inplace=True)
loan_data.fillna({'open_acc':0}, inplace=True)
loan_data.fillna({'inq_last_6mths':0}, inplace=True)
loan_data.fillna({'delinq_2yrs':0}, inplace=True)
loan_data.fillna({'emp_length_int':0}, inplace=True)

# %%
loan_data['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'Default',
#        'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %%
loan_data['good_bad'] = np.where(loan_data['loan_status'].isin(['Charged Off',
                                                                'Default', 
                                                                'Does not meet credit policy. Status:Charged Off', 
                                                                'Late(31-120 days)']),0,1)

# %%
loan_data['good_bad']
# Out:
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
#          ..
# 466280    1
# 466281    0
# 466282    1
# 466283    1
# 466284    1
# Name: good_bad, Length: 466285, dtype: int32

# %% [markdown]
# Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
loan_data_inputs_train, loan_data_inputs_test, loan_data_targets_train, loan_data_targets_test = train_test_split(loan_data.drop('good_bad',axis=1),loan_data['good_bad'],test_size=0.2,random_state=42)

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 209)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 209)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Calculating information Value for Grade

# %%
df_inputs_prep=loan_data_inputs_train #comment for preprocessing test dataset
df_targets_prep=loan_data_targets_train #comment for prep test dataset
#df_inputs_prep=loan_data_inputs_test #comment for prep train dataset
#df_targets_prep=loan_data_targets_test #comment for prep train dataset

# %%
df_inputs_prep['grade'].unique()
# Out:
# array(['A', 'C', 'D', 'B', 'E', 'F', 'G'], dtype=object)

# %%
df1=pd.concat([df_inputs_prep['grade'],df_targets_prep], axis = 1)
df1.head()
# Out:
#        grade  good_bad
# 427211     A         1
# 206088     C         1
# 136020     A         1
# 412305     D         1
# 36159      C         0

# %%
df1.groupby(df1.columns.values[0], as_index=False)[df1.columns.values[1]].count() #group by column 0(grades) and count the number of good and bad borrowers
# Out:
#   grade  good_bad
# 0     A     59759
# 1     B    109730
# 2     C    100245
# 3     D     61498
# 4     E     28612
# 5     F     10530
# 6     G      2654

# %%
df1.groupby(df1.columns.values[0], as_index=False)[df1.columns.values[1]].mean() #group by column 0 and get the mean of column 1. In other words, get the proportion of good/bad borrowers because column 1 is only 1 or 0
# Out:
#   grade  good_bad
# 0     A  0.965578
# 1     B  0.931632
# 2     C  0.903496
# 3     D  0.870662
# 4     E  0.836572
# 5     F  0.789269
# 6     G  0.780332

# %%
df1=pd.concat([df1.groupby(df1.columns.values[0], as_index=False)[df1.columns.values[1]].count(),
               df1.groupby(df1.columns.values[0], as_index=False)[df1.columns.values[1]].mean()], axis=1)

# %%
df1
# Out:
#   grade  good_bad grade  good_bad
# 0     A     59759     A  0.965578
# 1     B    109730     B  0.931632
# 2     C    100245     C  0.903496
# 3     D     61498     D  0.870662
# 4     E     28612     E  0.836572
# 5     F     10530     F  0.789269
# 6     G      2654     G  0.780332

# %%
df1 = df1.iloc[:,[0,1,3]]

# %%
df1.columns = [df1.columns.values[0],'n_obs','prop_good']
df1
# Out:
#   grade   n_obs  prop_good
# 0     A   59759   0.965578
# 1     B  109730   0.931632
# 2     C  100245   0.903496
# 3     D   61498   0.870662
# 4     E   28612   0.836572
# 5     F   10530   0.789269
# 6     G    2654   0.780332

# %%
df1['prop_n_obs'] = df1['n_obs'] / df1['n_obs'].sum()

# %%
df1
# Out:
#   grade   n_obs  prop_good  prop_n_obs
# 0     A   59759   0.965578    0.160200
# 1     B  109730   0.931632    0.294160
# 2     C  100245   0.903496    0.268733
# 3     D   61498   0.870662    0.164862
# 4     E   28612   0.836572    0.076702
# 5     F   10530   0.789269    0.028228
# 6     G    2654   0.780332    0.007115

# %%
df1['n_good'] = df1['prop_good'] * df1['n_obs']
df1['n_bad'] = (1-df1['prop_good'])*df1['n_obs']
df1
# Out:
#   grade   n_obs  prop_good  prop_n_obs    n_good   n_bad
# 0     A   59759   0.965578    0.160200   57702.0  2057.0
# 1     B  109730   0.931632    0.294160  102228.0  7502.0
# 2     C  100245   0.903496    0.268733   90571.0  9674.0
# 3     D   61498   0.870662    0.164862   53544.0  7954.0
# 4     E   28612   0.836572    0.076702   23936.0  4676.0
# 5     F   10530   0.789269    0.028228    8311.0  2219.0
# 6     G    2654   0.780332    0.007115    2071.0   583.0

# %%
df1['prop_n_good'] = df1['n_good']/df1['n_good'].sum()
df1['prop_n_bad'] = df1['n_bad']/df1['n_bad'].sum()
df1
# Out:
#   grade   n_obs  prop_good  prop_n_obs    n_good   n_bad  prop_n_good  prop_n_bad
# 0     A   59759   0.965578    0.160200   57702.0  2057.0     0.170533    0.059339
# 1     B  109730   0.931632    0.294160  102228.0  7502.0     0.302125    0.216414
# 2     C  100245   0.903496    0.268733   90571.0  9674.0     0.267674    0.279071
# 3     D   61498   0.870662    0.164862   53544.0  7954.0     0.158244    0.229453
# 4     E   28612   0.836572    0.076702   23936.0  4676.0     0.070741    0.134891
# 5     F   10530   0.789269    0.028228    8311.0  2219.0     0.024562    0.064013
# 6     G    2654   0.780332    0.007115    2071.0   583.0     0.006121    0.016818

# %%
df1['WoE']=np.log(df1['prop_n_good']/df1['prop_n_bad'])
df1
# Out:
#   grade   n_obs  prop_good  prop_n_obs    n_good   n_bad  prop_n_good  prop_n_bad       WoE
# 0     A   59759   0.965578    0.160200   57702.0  2057.0     0.170533    0.059339  1.055654
# 1     B  109730   0.931632    0.294160  102228.0  7502.0     0.302125    0.216414  0.333647
# 2     C  100245   0.903496    0.268733   90571.0  9674.0     0.267674    0.279071 -0.041697
# 3     D   61498   0.870662    0.164862   53544.0  7954.0     0.158244    0.229453 -0.371560
# 4     E   28612   0.836572    0.076702   23936.0  4676.0     0.070741    0.134891 -0.645448
# 5     F   10530   0.789269    0.028228    8311.0  2219.0     0.024562    0.064013 -0.957865
# 6     G    2654   0.780332    0.007115    2071.0   583.0     0.006121    0.016818 -1.010789

# %%
df1=df1.sort_values(['WoE'])
df1=df1.reset_index(drop=True)
df1
# Out:
#   grade   n_obs  prop_good  prop_n_obs    n_good   n_bad  prop_n_good  prop_n_bad       WoE
# 0     G    2654   0.780332    0.007115    2071.0   583.0     0.006121    0.016818 -1.010789
# 1     F   10530   0.789269    0.028228    8311.0  2219.0     0.024562    0.064013 -0.957865
# 2     E   28612   0.836572    0.076702   23936.0  4676.0     0.070741    0.134891 -0.645448
# 3     D   61498   0.870662    0.164862   53544.0  7954.0     0.158244    0.229453 -0.371560
# 4     C  100245   0.903496    0.268733   90571.0  9674.0     0.267674    0.279071 -0.041697
# 5     B  109730   0.931632    0.294160  102228.0  7502.0     0.302125    0.216414  0.333647
# 6     A   59759   0.965578    0.160200   57702.0  2057.0     0.170533    0.059339  1.055654

# %%
#calculate difference between two subsequent rows
df1['diff_prop_good']=df1['prop_good'].diff().abs()
df1['diff_WoE'] = df1['WoE'].diff().abs()

# %%
df1
# Out:
#   grade   n_obs  prop_good  prop_n_obs    n_good   n_bad  prop_n_good  prop_n_bad       WoE  diff_prop_good  diff_WoE
# 0     G    2654   0.780332    0.007115    2071.0   583.0     0.006121    0.016818 -1.010789             NaN       NaN
# 1     F   10530   0.789269    0.028228    8311.0  2219.0     0.024562    0.064013 -0.957865        0.008937  0.052924
# 2     E   28612   0.836572    0.076702   23936.0  4676.0     0.070741    0.134891 -0.645448        0.047303  0.312417
# 3     D   61498   0.870662    0.164862   53544.0  7954.0     0.158244    0.229453 -0.371560        0.034090  0.273888
# 4     C  100245   0.903496    0.268733   90571.0  9674.0     0.267674    0.279071 -0.041697        0.032834  0.329863
# 5     B  109730   0.931632    0.294160  102228.0  7502.0     0.302125    0.216414  0.333647        0.028136  0.375344
# 6     A   59759   0.965578    0.160200   57702.0  2057.0     0.170533    0.059339  1.055654        0.033946  0.722007

# %%
df1['IV']=(df1['prop_n_good']-df1['prop_n_bad'])*df1['WoE']
df1['IV']=df1['IV'].sum()
df1
# Out:
#   grade   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE       IV
# 0     G    2654   0.780332    0.007115    2071.0  ...    0.016818 -1.010789             NaN       NaN  0.26292
# 1     F   10530   0.789269    0.028228    8311.0  ...    0.064013 -0.957865        0.008937  0.052924  0.26292
# 2     E   28612   0.836572    0.076702   23936.0  ...    0.134891 -0.645448        0.047303  0.312417  0.26292
# 3     D   61498   0.870662    0.164862   53544.0  ...    0.229453 -0.371560        0.034090  0.273888  0.26292
# 4     C  100245   0.903496    0.268733   90571.0  ...    0.279071 -0.041697        0.032834  0.329863  0.26292
# 5     B  109730   0.931632    0.294160  102228.0  ...    0.216414  0.333647        0.028136  0.375344  0.26292
# 6     A   59759   0.965578    0.160200   57702.0  ...    0.059339  1.055654        0.033946  0.722007  0.26292
#
# [7 rows x 12 columns]

# %% [markdown]
# ## Automate calculations for discrete variables

# %%
def woe_discrete(df, discrete_variable_name , good_bad_variable_df):
    df = pd.concat([df[discrete_variable_name],good_bad_variable_df], axis = 1) #concatenate the variable of interest and the target columns
    df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
                    df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
    df = df.iloc[:,[0,1,3]] #keep only the first, second and fourth column
    df.columns = [df.columns.values[0],'n_obs','prop_good'] #names the columns
    df=df.copy()
    df['prop_n_obs'] = df['n_obs'] / df['n_obs'].sum() #gets the proportion of observation of a category
    df['n_good'] = df['prop_good']*df['n_obs'] #calculate the number of good borrowers
    df['n_bad'] = (1-df['prop_good'])*df['n_obs'] #calculate the number of bad 
    df['prop_n_good'] = df['n_good']/df['n_good'].sum() #proportion of good by bad
    df['prop_n_bad'] = df['n_bad']/df['n_bad'].sum() #proportion of bad by good
    df['WoE']=np.log(df['prop_n_good']/df['prop_n_bad']) #calculates weight of evidence according to formula
    df=df.sort_values(['WoE']) #sorts rows according to weight of evidence
    df=df.reset_index(drop=True) #resets index
    df['diff_prop_good']=df['prop_good'].diff().abs() #substracts two subsequent values in the column prop_good and gets the absolute value
    df['diff_WoE'] = df['WoE'].diff().abs() #substracts two subsequent values in the column WoE and gets the absolute value
    df['IV']=(df['prop_n_good']-df['prop_n_bad'])*df['WoE'] #calculate Information Value according to the formula
    df['IV']=df['IV'].sum() #sums all IV values to get the IV of a discrete value
    return df

# %%
df_temp = woe_discrete(df_inputs_prep,'grade',df_targets_prep)
df_temp
# Out:
#   grade   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE       IV
# 0     G    2654   0.780332    0.007115    2071.0  ...    0.016818 -1.010789             NaN       NaN  0.26292
# 1     F   10530   0.789269    0.028228    8311.0  ...    0.064013 -0.957865        0.008937  0.052924  0.26292
# 2     E   28612   0.836572    0.076702   23936.0  ...    0.134891 -0.645448        0.047303  0.312417  0.26292
# 3     D   61498   0.870662    0.164862   53544.0  ...    0.229453 -0.371560        0.034090  0.273888  0.26292
# 4     C  100245   0.903496    0.268733   90571.0  ...    0.279071 -0.041697        0.032834  0.329863  0.26292
# 5     B  109730   0.931632    0.294160  102228.0  ...    0.216414  0.333647        0.028136  0.375344  0.26292
# 6     A   59759   0.965578    0.160200   57702.0  ...    0.059339  1.055654        0.033946  0.722007  0.26292
#
# [7 rows x 12 columns]

# %% [markdown]
# ## visualizing data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def plot_by_woe(df_WoE, rotation_of_labels=0):
    x=np.array(df_WoE.iloc[:,0].apply(str)) #matplotlib doesn't like dataframes and strings
    y=df_WoE['WoE']
    plt.figure(figsize=(18,6))
    plt.plot(x,y, marker = 'o', linestyle = '--', color = 'k')
    plt.xlabel(df_WoE.columns[0])
    plt.ylabel('Weight of evidence')
    plt.title(str('Weight of Evidence'+df_WoE.columns[0]))
    plt.xticks(rotation= rotation_of_labels)

# %%
plot_by_woe(df_temp)

# %%
df_temp = woe_discrete(df_inputs_prep,'home_ownership',df_targets_prep)
df_temp
# Out:
#   home_ownership   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0           NONE      40   0.850000    0.000107      34.0  ...    0.000173 -0.543788             NaN       NaN  inf
# 1          OTHER     137   0.854015    0.000367     117.0  ...    0.000577 -0.511947        0.004015  0.031841  inf
# 2           RENT  150599   0.892204    0.403720  134365.0  ...    0.468311 -0.164937        0.038189  0.347011  inf
# 3            OWN   33295   0.909386    0.089256   30278.0  ...    0.087033  0.027770        0.017182  0.192706  inf
# 4       MORTGAGE  188956   0.918563    0.506546  173568.0  ...    0.443906  0.144593        0.009177  0.116823  inf
# 5            ANY       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.081437       inf  inf
#
# [6 rows x 12 columns]

# %%
plot_by_woe(df_temp)

# %%
df_temp = woe_discrete(df_inputs_prep,'home_ownership',df_targets_prep)
df_temp
# Out:
#   home_ownership   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0           NONE      40   0.850000    0.000107      34.0  ...    0.000173 -0.543788             NaN       NaN  inf
# 1          OTHER     137   0.854015    0.000367     117.0  ...    0.000577 -0.511947        0.004015  0.031841  inf
# 2           RENT  150599   0.892204    0.403720  134365.0  ...    0.468311 -0.164937        0.038189  0.347011  inf
# 3            OWN   33295   0.909386    0.089256   30278.0  ...    0.087033  0.027770        0.017182  0.192706  inf
# 4       MORTGAGE  188956   0.918563    0.506546  173568.0  ...    0.443906  0.144593        0.009177  0.116823  inf
# 5            ANY       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.081437       inf  inf
#
# [6 rows x 12 columns]

# %%
df_inputs_prep['home_ownership:RENT_OTHER_NONE_ANY'] = sum([df_inputs_prep['home_ownership:RENT'], df_inputs_prep['home_ownership:OTHER'], 
                                                            df_inputs_prep['home_ownership:NONE'], df_inputs_prep['home_ownership:ANY']])

# %%
df_temp = woe_discrete(df_inputs_prep,'addr_state',df_targets_prep)
df_temp
# Out:
#    addr_state  n_obs  prop_good  prop_n_obs   n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0          NE     13   0.692308    0.000035      9.0  ...    0.000115 -1.467459             NaN       NaN  inf
# 1          NV   5221   0.884122    0.013996   4616.0  ...    0.017453 -0.246333        0.191814  1.221125  inf
# 2          FL  25211   0.893935    0.067585  22537.0  ...    0.077138 -0.146806        0.009813  0.099528  inf
# 3          AL   4671   0.894455    0.012522   4178.0  ...    0.014222 -0.141310        0.000520  0.005496  inf
# 4          NM   2075   0.896867    0.005563   1861.0  ...    0.006173 -0.115496        0.002412  0.025814  inf
# 5          HI   2001   0.897051    0.005364   1795.0  ...    0.005943 -0.113505        0.000184  0.001991  inf
# 6          KY   3587   0.900195    0.009616   3229.0  ...    0.010327 -0.078994        0.003144  0.034511  inf
# 7          CA  57199   0.900208    0.153337  51491.0  ...    0.164662 -0.078850        0.000013  0.000144  inf
# 8          MO   6017   0.901944    0.016130   5427.0  ...    0.017020 -0.059370        0.001736  0.019481  inf
# 9          VA  11366   0.901988    0.030470  10252.0  ...    0.032136 -0.058873        0.000044  0.000496  inf
# 10         UT   2756   0.902032    0.007388   2486.0  ...    0.007789 -0.058380        0.000044  0.000493  inf
# 11         NC  10204   0.902097    0.027355   9205.0  ...    0.028819 -0.057641        0.000065  0.000739  inf
# 12         NY  32211   0.902611    0.086350  29074.0  ...    0.090495 -0.051811        0.000514  0.005830  inf
# 13         OK   3284   0.903776    0.008804   2968.0  ...    0.009116 -0.038487        0.001165  0.013324  inf
# 14         NJ  14385   0.903789    0.038563  13001.0  ...    0.039925 -0.038340        0.000013  0.000147  inf
# 15         LA   4359   0.904336    0.011685   3942.0  ...    0.012029 -0.032031        0.000547  0.006309  inf
# 16         MD   8771   0.904458    0.023513   7933.0  ...    0.024174 -0.030620        0.000122  0.001411  inf
# 17         MN   6526   0.905762    0.017495   5911.0  ...    0.017741 -0.015441        0.001304  0.015180  inf
# 18         MI   9191   0.906321    0.024639   8330.0  ...    0.024838 -0.008865        0.000560  0.006576  inf
# 19         AZ   8645   0.906651    0.023175   7838.0  ...    0.023280 -0.004973        0.000330  0.003891  inf
# 20         TN   4845   0.906708    0.012988   4393.0  ...    0.013039 -0.004303        0.000057  0.000670  inf
# 21         AR   2760   0.907246    0.007399   2504.0  ...    0.007385  0.002079        0.000538  0.006382  inf
# 22         OH  12135   0.907293    0.032531  11010.0  ...    0.032453  0.002632        0.000047  0.000554  inf
# 23         DE   1064   0.908835    0.002852    967.0  ...    0.002798  0.021099        0.001542  0.018467  inf
# 24         PA  13090   0.909778    0.035091  11909.0  ...    0.034069  0.032544        0.000944  0.011445  inf
# 25         WA   8372   0.910057    0.022443   7619.0  ...    0.021722  0.035946        0.000279  0.003402  inf
# 26         IN   5210   0.910557    0.013967   4744.0  ...    0.013443  0.042062        0.000499  0.006115  inf
# 27         MA   8858   0.910928    0.023746   8069.0  ...    0.022761  0.046630        0.000371  0.004568  inf
# 28         OR   4814   0.911924    0.012905   4390.0  ...    0.012231  0.058962        0.000996  0.012333  inf
# 29         RI   1647   0.912568    0.004415   1503.0  ...    0.004154  0.067016        0.000645  0.008054  inf
# 30         GA  11960   0.913127    0.032062  10921.0  ...    0.029973  0.074040        0.000559  0.007024  inf
# 31         SD    801   0.913858    0.002147    732.0  ...    0.001990  0.083285        0.000731  0.009245  inf
# 32         WI   4740   0.915401    0.012707   4339.0  ...    0.011568  0.103049        0.001543  0.019764  inf
# 33         CT   5775   0.917749    0.015481   5300.0  ...    0.013703  0.133759        0.002348  0.030710  inf
# 34         KS   3360   0.918155    0.009007   3085.0  ...    0.007933  0.139147        0.000406  0.005389  inf
# 35         TX  29158   0.919542    0.078166  26812.0  ...    0.067676  0.157749        0.001387  0.018602  inf
# 36         IL  14833   0.919841    0.039764  13644.0  ...    0.034300  0.161798        0.000299  0.004049  inf
# 37         IA     13   0.923077    0.000035     12.0  ...    0.000029  0.206518        0.003236  0.044719  inf
# 38         SC   4448   0.923112    0.011924   4106.0  ...    0.009866  0.207005        0.000035  0.000487  inf
# 39         CO   7823   0.923942    0.020972   7228.0  ...    0.017164  0.218767        0.000831  0.011762  inf
# 40         MT   1103   0.925657    0.002957   1021.0  ...    0.002365  0.243430        0.001715  0.024662  inf
# 41         VT    727   0.925722    0.001949    673.0  ...    0.001558  0.244373        0.000065  0.000943  inf
# 42         AK   1003   0.926221    0.002689    929.0  ...    0.002135  0.251655        0.000499  0.007282  inf
# 43         NH   1830   0.933333    0.004906   1708.0  ...    0.003519  0.360669        0.007112  0.109014  inf
# 44         WY    919   0.934712    0.002464    859.0  ...    0.001731  0.383036        0.001378  0.022367  inf
# 45         WV   1926   0.937175    0.005163   1805.0  ...    0.003491  0.424137        0.002464  0.041101  inf
# 46         MS    980   0.940816    0.002627    922.0  ...    0.001673  0.487713        0.003641  0.063577  inf
# 47         DC   1129   0.942427    0.003027   1064.0  ...    0.001875  0.517015        0.001611  0.029301  inf
# 48         ME      2   1.000000    0.000005      2.0  ...    0.000000       inf        0.057573       inf  inf
# 49         ID     10   1.000000    0.000027     10.0  ...    0.000000       inf        0.000000       NaN  inf
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp)

# %%
if['addn_state:DN'] in df_inputs_prep.columns.values:
    pass
else:
    df_inputs_prep['addr_state:ND'] = 0  #there are no borrowers from North Dakota so we add the state to list just in case it is needed in future

# %%
plot_by_woe(df_temp.iloc[2:-2,:])

# %%
# ND, NE, NV, FL AL, NM, HI, KY will make the first category. These are the states with lowest WoE (highest risk) and the least info on
# NH, WY, WV, MS, DC, ME, ID will make another category
# NY and CA have such a great number of borrowers that each will have their own category
# MO, VA, UT, NC will be another category
# OK, NJ, LA, MD, another 
# MN, MI, AZ, TN, AR, OH
# DE, PA, WA, IN, MA 
# OR, RI, GA, SD, WI
# CT, KS
# TX, IL have their own category because TX is very large and IL too different from the next category
# IA, SC, CO, MT, VT, AK

# %%
plot_by_woe(df_temp.iloc[7:-7,:])

# %%
df_inputs_prep['addr_state:ND_NE_NV_FL_AL_NM_HI_KY'] = sum([df_inputs_prep['addr_state:ND'],df_inputs_prep['addr_state:NE'], 
                                                        df_inputs_prep['addr_state:NV'], df_inputs_prep['addr_state:FL'],
                                                        df_inputs_prep['addr_state:AL'], df_inputs_prep['addr_state:NM'], 
                                                        df_inputs_prep['addr_state:HI'], df_inputs_prep['addr_state:KY']])

df_inputs_prep['addr_state:NH_WY_WV_MS_DC_ME_ID']= sum([df_inputs_prep['addr_state:NH'],df_inputs_prep['addr_state:WY'], 
                                                        df_inputs_prep['addr_state:WV'], df_inputs_prep['addr_state:MS'],
                                                        df_inputs_prep['addr_state:DC'], df_inputs_prep['addr_state:ME'], 
                                                        df_inputs_prep['addr_state:ID']])

df_inputs_prep['addr_state:CA']= sum([df_inputs_prep['addr_state:CA']])

df_inputs_prep['addr_state:NY']= sum([df_inputs_prep['addr_state:NY']])

df_inputs_prep['addr_state:MO_VA_UT_NC']= sum([df_inputs_prep['addr_state:MO'],df_inputs_prep['addr_state:VA'], 
                                               df_inputs_prep['addr_state:UT'], df_inputs_prep['addr_state:NC']])

df_inputs_prep['addr_state:OK_NJ_LA_MD']= sum([df_inputs_prep['addr_state:OK'],df_inputs_prep['addr_state:NJ'], 
                                               df_inputs_prep['addr_state:LA'], df_inputs_prep['addr_state:MD']])  

df_inputs_prep['addr_state:MN_MI_AZ_TN_AR_OH']= sum([df_inputs_prep['addr_state:MN'],df_inputs_prep['addr_state:MI'], 
                                                        df_inputs_prep['addr_state:AZ'], df_inputs_prep['addr_state:TN'],
                                                        df_inputs_prep['addr_state:AR'], df_inputs_prep['addr_state:OH']])

df_inputs_prep['addr_state:DE_PA_WA_IN_MA']= sum([df_inputs_prep['addr_state:DE'],df_inputs_prep['addr_state:PA'], 
                                                        df_inputs_prep['addr_state:WA'], df_inputs_prep['addr_state:IN'],
                                                        df_inputs_prep['addr_state:MA']])

df_inputs_prep['addr_state:OR_RI_GA_SD_WI']= sum([df_inputs_prep['addr_state:OR'],df_inputs_prep['addr_state:RI'], 
                                                        df_inputs_prep['addr_state:GA'], df_inputs_prep['addr_state:SD'],
                                                        df_inputs_prep['addr_state:WI']])

df_inputs_prep['addr_state:CT_KS']= sum([df_inputs_prep['addr_state:CT'],df_inputs_prep['addr_state:KS']])

df_inputs_prep['addr_state:TX_IL']= sum([df_inputs_prep['addr_state:TX'],df_inputs_prep['addr_state:IL']])

df_inputs_prep['addr_state:IA_SC_CO_MT_VT_AK']= sum([df_inputs_prep['addr_state:IA'],df_inputs_prep['addr_state:SC'], 
                                                        df_inputs_prep['addr_state:CO'], df_inputs_prep['addr_state:MT'],
                                                        df_inputs_prep['addr_state:VT'], df_inputs_prep['addr_state:AK']])

# %%
df_temp = woe_discrete(df_inputs_prep,'verification_status',df_targets_prep)
df_temp
# Out:
#   verification_status   n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE        IV
# 0            Verified  134414   0.889022    0.360332  ... -0.197599             NaN       NaN  0.026014
# 1     Source Verified  120030   0.914230    0.321772  ...  0.088021        0.025208  0.285620  0.026014
# 2        Not Verified  118584   0.920284    0.317896  ...  0.167828        0.006055  0.079807  0.026014
#
# [3 rows x 12 columns]

# %%
plot_by_woe(df_temp)

# %%
df_temp = woe_discrete(df_inputs_prep,'purpose',df_targets_prep)
df_temp
# Out:
#                purpose   n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE        IV
# 0       small_business    5582   0.811000    0.014964  ... -0.821870             NaN       NaN  0.037589
# 1               moving    2392   0.860786    0.006412  ... -0.456556        0.049786  0.365315  0.037589
# 2          educational     333   0.873874    0.000893  ... -0.342735        0.013088  0.113820  0.037589
# 3     renewable_energy     281   0.875445    0.000753  ... -0.328405        0.001571  0.014330  0.037589
# 4                other   18884   0.881381    0.050624  ... -0.272815        0.005936  0.055590  0.037589
# 5                house    1830   0.881421    0.004906  ... -0.272435        0.000040  0.000380  0.037589
# 6              medical    3684   0.887622    0.009876  ... -0.211709        0.006201  0.060726  0.037589
# 7              wedding    1887   0.888712    0.005059  ... -0.200735        0.001090  0.010975  0.037589
# 8             vacation    1991   0.897037    0.005337  ... -0.113665        0.008324  0.087070  0.037589
# 9   debt_consolidation  219183   0.903879    0.587578  ... -0.037296        0.006843  0.076369  0.037589
# 10      major_purchase    7837   0.917443    0.021009  ...  0.129711        0.013563  0.167008  0.037589
# 11    home_improvement   21238   0.917506    0.056934  ...  0.130550        0.000063  0.000838  0.037589
# 12                 car    4325   0.918844    0.011594  ...  0.148353        0.001338  0.017804  0.037589
# 13         credit_card   83581   0.927065    0.224061  ...  0.264063        0.008221  0.115709  0.037589
#
# [14 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
# small_business
# moving, educational, renewable_energy
# other, house
# medical, wedding
#vacation
#debt_consolidation
#major_purchase, home_improvement, car
#credit_card

# %%
df_inputs_prep['purpose:small_business']= sum([df_inputs_prep['purpose:small_business']])

df_inputs_prep['purpose:moving__educational__renewable_energy']= sum([df_inputs_prep['purpose:moving'],df_inputs_prep['purpose:educational'],df_inputs_prep['purpose:renewable_energy']])

df_inputs_prep['purpose:other__house']= sum([df_inputs_prep['purpose:other'],df_inputs_prep['purpose:house']])

df_inputs_prep['purpose:medical__wedding']= sum([df_inputs_prep['purpose:medical'],df_inputs_prep['purpose:wedding']]) 

df_inputs_prep['purpose:vacation']= sum([df_inputs_prep['purpose:vacation']]) 

df_inputs_prep['purpose:debt_consolidation']= sum([df_inputs_prep['purpose:debt_consolidation']]) 

df_inputs_prep['purpose:major_purchase__home_improvement__car']= sum([df_inputs_prep['purpose:major_purchase'],df_inputs_prep['purpose:home_improvement'],df_inputs_prep['purpose:car']])

df_inputs_prep['purpose:credit_card']= sum([df_inputs_prep['purpose:credit_card']])

# %%
df_temp = woe_discrete(df_inputs_prep,'initial_list_status',df_targets_prep)
df_temp
# Out:
#   initial_list_status   n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE        IV
# 0                   f  242514   0.894975    0.650123  ... -0.135790             NaN       NaN  0.040785
# 1                   w  130514   0.929548    0.349877  ...  0.301375        0.034573  0.437165  0.040785
#
# [2 rows x 12 columns]

# %%
plot_by_woe(df_temp)

# %%
def woe_ordered_continuous(df, discrete_variable_name , good_bad_variable_df):
    df = pd.concat([df[discrete_variable_name],good_bad_variable_df], axis = 1) #concatenate the variable of interest and the target columns
    df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
                    df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
    df = df.iloc[:,[0,1,3]] #keep only the first, second and fourth column
    df.columns = [df.columns.values[0],'n_obs','prop_good'] #names the columns
    df=df.copy()
    df['prop_n_obs'] = df['n_obs'] / df['n_obs'].sum() #gets the proportion of observation of a category
    df['n_good'] = df['prop_good']*df['n_obs'] #calculate the number of good borrowers
    df['n_bad'] = (1-df['prop_good'])*df['n_obs'] #calculate the number of bad 
    df['prop_n_good'] = df['n_good']/df['n_good'].sum() #proportion of good by bad
    df['prop_n_bad'] = df['n_bad']/df['n_bad'].sum() #proportion of bad by good
    df['WoE']=np.log(df['prop_n_good']/df['prop_n_bad']) #calculates weight of evidence according to formula

    df['diff_prop_good']=df['prop_good'].diff().abs() #substracts two subsequent values in the column prop_good and gets the absolute value
    df['diff_WoE'] = df['WoE'].diff().abs() #substracts two subsequent values in the column WoE and gets the absolute value
    df['IV']=(df['prop_n_good']-df['prop_n_bad'])*df['WoE'] #calculate Information Value according to the formula
    df['IV']=df['IV'].sum() #sums all IV values to get the IV of a discrete value
    return df

# %%
df_inputs_prep['term_int'].unique()
# Out:
# array([36, 60], dtype=int64)

# %%
df_temp= woe_ordered_continuous(df_inputs_prep,'term_int',df_targets_prep)
df_temp
# Out:
#    term_int   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE        IV
# 0        36  270419   0.917424    0.724929  248089.0  ...    0.644166  0.129468             NaN       NaN  0.037169
# 1        60  102609   0.879786    0.275071   90274.0  ...    0.355834 -0.287980        0.037638  0.417448  0.037169
#
# [2 rows x 12 columns]

# %%
plot_by_woe(df_temp)

# %%
df_inputs_prep['term:36'] = np.where((df_inputs_prep['term_int'] == 36), 1,0)
df_inputs_prep['term:60'] = np.where((df_inputs_prep['term_int'] == 60), 1,0)

# %%
df_inputs_prep['emp_length_int'].unique()
# Out:
# array([ 3.,  6., 10.,  7.,  5.,  0.,  2.,  9.,  1.,  8.,  4.])

# %%
df_temp= woe_ordered_continuous(df_inputs_prep,'emp_length_int',df_targets_prep)
df_temp
# Out:
#     emp_length_int   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE        IV
# 0              0.0   45720   0.895210    0.122565   40929.0  ...    0.138209 -0.133289             NaN       NaN  0.007033
# 1              1.0   23654   0.904414    0.063411   21393.0  ...    0.065224 -0.031132        0.009204  0.102157  0.007033
# 2              2.0   33078   0.907491    0.088674   30018.0  ...    0.088273  0.004994        0.003078  0.036126  0.007033
# 3              3.0   29205   0.907413    0.078292   26501.0  ...    0.078004  0.004062        0.000078  0.000932  0.007033
# 4              4.0   22468   0.905599    0.060231   20347.0  ...    0.061186 -0.017343        0.001814  0.021405  0.007033
# 5              5.0   24602   0.899358    0.065952   22126.0  ...    0.071427 -0.088280        0.006241  0.070937  0.007033
# 6              6.0   20887   0.900608    0.055993   18811.0  ...    0.059887 -0.074390        0.001250  0.013890  0.007033
# 7              7.0   21049   0.902988    0.056427   19007.0  ...    0.058907 -0.047511        0.002380  0.026879  0.007033
# 8              8.0   17853   0.906738    0.047860   16188.0  ...    0.048031 -0.003944        0.003750  0.043567  0.007033
# 9              9.0   14267   0.905376    0.038246   12917.0  ...    0.038944 -0.019949        0.001362  0.016005  0.007033
# 10            10.0  120245   0.915847    0.322348  110126.0  ...    0.291908  0.108822        0.010471  0.128771  0.007033
#
# [11 rows x 12 columns]

# %%
plot_by_woe(df_temp)

# %%
df_inputs_prep['emp_length:0'] = np.where(df_inputs_prep['emp_length_int'].isin([0]),1,0)
df_inputs_prep['emp_length:1'] = np.where(df_inputs_prep['emp_length_int'].isin([1]),1,0)
df_inputs_prep['emp_length:2-4'] = np.where(df_inputs_prep['emp_length_int'].isin(range(2,5)),1,0)
df_inputs_prep['emp_length:5-6'] = np.where(df_inputs_prep['emp_length_int'].isin(range(5,7)),1,0)
df_inputs_prep['emp_length:7-9'] = np.where(df_inputs_prep['emp_length_int'].isin(range(7,10)),1,0)
df_inputs_prep['emp_length:10'] = np.where(df_inputs_prep['emp_length_int'].isin([10]),1,0)

# %%
df_inputs_prep['mths_since_issue_d'].unique()
# Out:
# array([ 45,  64,  54,  44, 101,  37,  91,  53,  42,  57,  58,  43,  40,
#         51,  59, 113,  50,  62,  49,  47,  48,  41,  38,  66,  69,  87,
#         46,  76,  63,  39,  61,  89,  65,  56,  79,  68,  52,  60,  73,
#         74,  70,  88,  81,  82,  55, 103,  83,  72,  85,  36,  71,  92,
#         77,  67,  84,  86,  90, 116,  93,  95,  78,  75,  80,  96,  94,
#         98, 104, 125, 105, 118, 110, 119, 114,  97, 102, 106, 100, 122,
#        121, 108, 117, 120, 124,  99, 115, 112, 109, 123, 107, 126, 111],
#       dtype=int64)

# %%
df_inputs_prep['mths_since_issue_d_cat'] = pd.cut(df_inputs_prep['mths_since_issue_d'],50)

# %%
df_inputs_prep['mths_since_issue_d_cat']
# Out:
# 427211      (43.2, 45.0]
# 206088      (63.0, 64.8]
# 136020      (52.2, 54.0]
# 412305      (43.2, 45.0]
# 36159     (100.8, 102.6]
#                ...
# 259178     (35.91, 37.8]
# 365838      (41.4, 43.2]
# 131932      (52.2, 54.0]
# 146867      (55.8, 57.6]
# 121958      (52.2, 54.0]
# Name: mths_since_issue_d_cat, Length: 373028, dtype: category
# Categories (50, interval[float64, right]): [(35.91, 37.8] < (37.8, 39.6] < (39.6, 41.4] < (41.4, 43.2] ... (118.8, 120.6] < (120.6, 122.4] < (122.4, 124.2] < (124.2, 126.0]]

# %%
df_temp= woe_ordered_continuous(df_inputs_prep,'mths_since_issue_d_cat',df_targets_prep)
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#    mths_since_issue_d_cat  n_obs  prop_good  prop_n_obs   n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0           (35.91, 37.8]  28170   0.965140    0.075517  27188.0  ...    0.028328  1.042551             NaN       NaN  inf
# 1            (37.8, 39.6]  39636   0.951156    0.106255  37700.0  ...    0.055849  0.690647        0.013985  0.351904  inf
# 2            (39.6, 41.4]  38614   0.938157    0.103515  36226.0  ...    0.068888  0.440932        0.012998  0.249715  inf
# 3            (41.4, 43.2]  29038   0.928439    0.077844  26960.0  ...    0.059945  0.284560        0.009719  0.156373  inf
# 4            (43.2, 45.0]  28367   0.921352    0.076045  26136.0  ...    0.064359  0.182475        0.007086  0.102085  inf
# 5            (45.0, 46.8]  12165   0.915084    0.032611  11132.0  ...    0.029800  0.098968        0.006268  0.083507  inf
# 6            (46.8, 48.6]  24451   0.915873    0.065547  22394.0  ...    0.059339  0.109156        0.000788  0.010188  inf
# 7            (48.6, 50.4]  22969   0.903392    0.061574  20750.0  ...    0.064013 -0.042899        0.012481  0.152055  inf
# 8            (50.4, 52.2]  20640   0.892587    0.055331  18423.0  ...    0.063955 -0.160944        0.010804  0.118045  inf
# 9            (52.2, 54.0]  18312   0.879696    0.049090  16109.0  ...    0.063551 -0.288831        0.012891  0.127887  inf
# 10           (54.0, 55.8]   8286   0.868694    0.022213   7198.0  ...    0.031386 -0.388927        0.011002  0.100096  inf
# 11           (55.8, 57.6]  14120   0.874504    0.037852  12348.0  ...    0.051118 -0.337003        0.005810  0.051923  inf
# 12           (57.6, 59.4]  11529   0.868939    0.030907  10018.0  ...    0.043589 -0.386777        0.005565  0.049773  inf
# 13           (59.4, 61.2]   9974   0.861039    0.026738   8588.0  ...    0.039983 -0.454445        0.007900  0.067668  inf
# 14           (61.2, 63.0]   9811   0.855163    0.026301   8390.0  ...    0.040992 -0.502709        0.005876  0.048264  inf
# 15           (63.0, 64.8]   4304   0.846422    0.011538   3643.0  ...    0.019068 -0.571580        0.008741  0.068871  inf
# 16           (64.8, 66.6]   6723   0.828202    0.018023   5568.0  ...    0.033319 -0.705453        0.018220  0.133873  inf
# 17           (66.6, 68.4]   5334   0.843457    0.014299   4499.0  ...    0.024088 -0.594210        0.015255  0.111243  inf
# 18           (68.4, 70.2]   4377   0.849440    0.011734   3718.0  ...    0.019011 -0.548171        0.005983  0.046039  inf
# 19           (70.2, 72.0]   3868   0.829886    0.010369   3210.0  ...    0.018982 -0.693567        0.019554  0.145396  inf
# 20           (72.0, 73.8]   1785   0.856583    0.004785   1529.0  ...    0.007385 -0.491197        0.026696  0.202370  inf
# 21           (73.8, 75.6]   3395   0.855376    0.009101   2904.0  ...    0.014164 -0.500989        0.001207  0.009792  inf
# 22           (75.6, 77.4]   3055   0.857283    0.008190   2619.0  ...    0.012578 -0.485483        0.001908  0.015505  inf
# 23           (77.4, 79.2]   2849   0.843805    0.007637   2404.0  ...    0.012837 -0.591574        0.013478  0.106091  inf
# 24           (79.2, 81.0]   2412   0.853234    0.006466   2058.0  ...    0.010212 -0.518196        0.009429  0.073378  inf
# 25           (81.0, 82.8]   1044   0.870690    0.002799    909.0  ...    0.003894 -0.371318        0.017456  0.146877  inf
# 26           (82.8, 84.6]   2182   0.877635    0.005849   1915.0  ...    0.007702 -0.308165        0.006946  0.063154  inf
# 27           (84.6, 86.4]   1997   0.879820    0.005353   1757.0  ...    0.006923 -0.287665        0.002185  0.020500  inf
# 28           (86.4, 88.2]   1921   0.856845    0.005150   1646.0  ...    0.007933 -0.489056        0.022974  0.201392  inf
# 29           (88.2, 90.0]   1870   0.865775    0.005013   1619.0  ...    0.007241 -0.414278        0.008930  0.074779  inf
# 30           (90.0, 91.8]    795   0.877987    0.002131    698.0  ...    0.002798 -0.304881        0.012212  0.109397  inf
# 31           (91.8, 93.6]   1373   0.910415    0.003681   1250.0  ...    0.003548  0.040326        0.032428  0.345206  inf
# 32           (93.6, 95.4]   1087   0.898804    0.002914    977.0  ...    0.003173 -0.094382        0.011611  0.134708  inf
# 33           (95.4, 97.2]   1044   0.897510    0.002799    937.0  ...    0.003087 -0.108534        0.001294  0.014152  inf
# 34           (97.2, 99.0]    877   0.876853    0.002351    769.0  ...    0.003116 -0.315429        0.020657  0.206895  inf
# 35          (99.0, 100.8]    346   0.898844    0.000928    311.0  ...    0.001010 -0.093944        0.021991  0.221485  inf
# 36         (100.8, 102.6]    647   0.887172    0.001734    574.0  ...    0.002106 -0.216219        0.011672  0.122275  inf
# 37         (102.6, 104.4]    542   0.878229    0.001453    476.0  ...    0.001904 -0.302626        0.008943  0.086407  inf
# 38         (104.4, 106.2]    497   0.895372    0.001332    445.0  ...    0.001500 -0.131558        0.017143  0.171067  inf
# 39         (106.2, 108.0]    403   0.880893    0.001080    355.0  ...    0.001385 -0.277472        0.014479  0.145914  inf
# 40         (108.0, 109.8]    173   0.849711    0.000464    147.0  ...    0.000750 -0.546053        0.031182  0.268581  inf
# 41         (109.8, 111.6]    139   0.884892    0.000373    123.0  ...    0.000462 -0.238793        0.035181  0.307260  inf
# 42         (111.6, 113.4]    204   0.887255    0.000547    181.0  ...    0.000663 -0.215386        0.002363  0.023407  inf
# 43         (113.4, 115.2]    182   0.939560    0.000488    171.0  ...    0.000317  0.465380        0.052306  0.680765  inf
# 44         (115.2, 117.0]    530   0.901887    0.001421    478.0  ...    0.001500 -0.060022        0.037674  0.525401  inf
# 45         (117.0, 118.8]    247   0.919028    0.000662    227.0  ...    0.000577  0.150829        0.017142  0.210851  inf
# 46         (118.8, 120.6]    394   0.903553    0.001056    356.0  ...    0.001096 -0.041044        0.015475  0.191873  inf
# 47         (120.6, 122.4]    176   0.926136    0.000472    163.0  ...    0.000375  0.250412        0.022583  0.291456  inf
# 48         (122.4, 124.2]    104   0.932692    0.000279     97.0  ...    0.000202  0.350412        0.006556  0.100000  inf
# 49         (124.2, 126.0]     70   1.000000    0.000188     70.0  ...    0.000000       inf        0.067308       inf  inf
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
plot_by_woe(df_temp.iloc[3: , : ],90) #plot all except first 3 categories

# %%
df_inputs_prep['mths_since_issue_d:<38'] = np.where(df_inputs_prep['mths_since_issue_d'].isin(range(38)),1,0)
df_inputs_prep['mths_since_issue_d:38-39'] = np.where(df_inputs_prep['mths_since_issue_d'].isin(range(38,40)),1,0)
df_inputs_prep['mths_since_issue_d:40-41'] = np.where(df_inputs_prep['mths_since_issue_d'].isin(range(40,42)),1,0)
df_inputs_prep['mths_since_issue_d:42-48'] = np.where(df_inputs_prep['mths_since_issue_d'].isin(range(42,49)),1,0)
df_inputs_prep['mths_since_issue_d:49-52'] = np.where(df_inputs_prep['mths_since_issue_d'].isin(range(49,53)),1,0)
df_inputs_prep['mths_since_issue_d:53-64'] = np.where(df_inputs_prep['mths_since_issue_d'].isin(range(53,65)),1,0)
df_inputs_prep['mths_since_issue_d:65-84'] = np.where(df_inputs_prep['mths_since_issue_d'].isin(range(65,85)),1,0)
df_inputs_prep['mths_since_issue_d:>84'] = np.where(df_inputs_prep['mths_since_issue_d'].isin(range(85,int(df_inputs_prep['mths_since_issue_d'].max()))),1,0)

# %%
df_inputs_prep['int_rate_cat'] = pd.cut(df_inputs_prep['int_rate'],50)

# %%
df_temp= woe_ordered_continuous(df_inputs_prep,'int_rate_cat',df_targets_prep)
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#         int_rate_cat  n_obs  prop_good  prop_n_obs   n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE        IV
# 0     (5.399, 5.833]    785   0.961783    0.002104    755.0  ...    0.000865  0.947132             NaN       NaN  0.348731
# 1     (5.833, 6.246]   8459   0.982858    0.022677   8314.0  ...    0.004183  1.770574        0.021075  0.823442  0.348731
# 2     (6.246, 6.658]   7826   0.975083    0.020980   7631.0  ...    0.005625  1.388586        0.007775  0.381988  0.348731
# 3     (6.658, 7.071]   1816   0.974119    0.004868   1769.0  ...    0.001356  1.349633        0.000964  0.038953  0.348731
# 4     (7.071, 7.484]   3143   0.980910    0.008426   3083.0  ...    0.001731  1.660925        0.006791  0.311292  0.348731
# 5     (7.484, 7.897]  12581   0.967014    0.033727  12166.0  ...    0.011972  1.099733        0.013896  0.561192  0.348731
# 6      (7.897, 8.31]   9687   0.954165    0.025969   9243.0  ...    0.012808  0.757408        0.012848  0.342325  0.348731
# 7      (8.31, 8.722]   6594   0.975432    0.017677   6432.0  ...    0.004673  1.403056        0.021267  0.645647  0.348731
# 8     (8.722, 9.135]   9539   0.942656    0.025572   8992.0  ...    0.015780  0.521253        0.032776  0.881803  0.348731
# 9     (9.135, 9.548]   6681   0.974555    0.017910   6511.0  ...    0.004904  1.367061        0.031898  0.845808  0.348731
# 10    (9.548, 9.961]   7588   0.939114    0.020342   7126.0  ...    0.013328  0.457552        0.035440  0.909509  0.348731
# 11   (9.961, 10.374]  10941   0.943058    0.029330  10318.0  ...    0.017972  0.528710        0.003944  0.071158  0.348731
# 12  (10.374, 10.786]   5857   0.922998    0.015701   5406.0  ...    0.013010  0.205409        0.020060  0.323301  0.348731
# 13  (10.786, 11.199]  17851   0.940171    0.047854  16783.0  ...    0.030809  0.476190        0.017173  0.270781  0.348731
# 14  (11.199, 11.612]   4876   0.930066    0.013071   4535.0  ...    0.009837  0.309309        0.010106  0.166881  0.348731
# 15  (11.612, 12.025]  15597   0.946079    0.041812  14756.0  ...    0.024261  0.586425        0.016014  0.277116  0.348731
# 16  (12.025, 12.438]  12336   0.902886    0.033070  11138.0  ...    0.034559 -0.048680        0.043194  0.635104  0.348731
# 17   (12.438, 12.85]  11065   0.938726    0.029663  10387.0  ...    0.019559  0.450774        0.035840  0.499454  0.348731
# 18   (12.85, 13.263]  21329   0.918984    0.057178  19601.0  ...    0.049849  0.150227        0.019742  0.300547  0.348731
# 19  (13.263, 13.676]  15392   0.927625    0.041262  14278.0  ...    0.032136  0.272374        0.008641  0.122147  0.348731
# 20  (13.676, 14.089]  10991   0.916750    0.029464  10076.0  ...    0.026395  0.120599        0.010875  0.151775  0.348731
# 21  (14.089, 14.502]  23436   0.905871    0.062826  21230.0  ...    0.063638 -0.014154        0.010879  0.134753  0.348731
# 22  (14.502, 14.914]   4333   0.882068    0.011616   3822.0  ...    0.014741 -0.266229        0.023803  0.252075  0.348731
# 23  (14.914, 15.327]  18932   0.900327    0.050752  17045.0  ...    0.054435 -0.077520        0.018260  0.188709  0.348731
# 24   (15.327, 15.74]  12327   0.914010    0.033046  11267.0  ...    0.030578  0.085220        0.013682  0.162741  0.348731
# 25   (15.74, 16.153]   7477   0.855557    0.020044   6397.0  ...    0.031155 -0.499521        0.058453  0.584741  0.348731
# 26  (16.153, 16.566]  12991   0.881379    0.034826  11450.0  ...    0.044454 -0.272831        0.025822  0.226690  0.348731
# 27  (16.566, 16.978]   4237   0.866179    0.011358   3670.0  ...    0.016357 -0.410801        0.015201  0.137971  0.348731
# 28  (16.978, 17.391]  11396   0.874166    0.030550   9962.0  ...    0.041367 -0.340079        0.007987  0.070722  0.348731
# 29  (17.391, 17.804]  12288   0.863851    0.032941  10615.0  ...    0.048262 -0.430739        0.010315  0.090660  0.348731
# 30  (17.804, 18.217]   1306   0.858346    0.003501   1121.0  ...    0.005337 -0.476768        0.005505  0.046029  0.348731
# 31   (18.217, 18.63]  11036   0.858463    0.029585   9474.0  ...    0.045060 -0.475805        0.000117  0.000964  0.348731
# 32   (18.63, 19.042]   6808   0.842979    0.018251   5739.0  ...    0.030838 -0.597827        0.015484  0.122023  0.348731
# 33  (19.042, 19.455]   4425   0.821243    0.011862   3634.0  ...    0.022818 -0.753597        0.021736  0.155770  0.348731
# 34  (19.455, 19.868]   6763   0.849179    0.018130   5743.0  ...    0.029424 -0.550210        0.027936  0.203388  0.348731
# 35  (19.868, 20.281]   4899   0.860380    0.013133   4215.0  ...    0.019732 -0.459942        0.011200  0.090268  0.348731
# 36  (20.281, 20.694]   3221   0.819932    0.008635   2641.0  ...    0.016732 -0.762504        0.040448  0.302562  0.348731
# 37  (20.694, 21.106]   4016   0.831175    0.010766   3338.0  ...    0.019559 -0.684409        0.011244  0.078095  0.348731
# 38  (21.106, 21.519]   2729   0.805057    0.007316   2197.0  ...    0.015347 -0.860184        0.026119  0.175775  0.348731
# 39  (21.519, 21.932]    989   0.779575    0.002651    771.0  ...    0.006289 -1.015195        0.025481  0.155011  0.348731
# 40  (21.932, 22.345]   3476   0.821346    0.009318   2855.0  ...    0.017914 -0.752893        0.041771  0.262303  0.348731
# 41  (22.345, 22.758]   2251   0.785429    0.006034   1768.0  ...    0.013933 -0.980801        0.035918  0.227908  0.348731
# 42   (22.758, 23.17]   1535   0.791531    0.004115   1215.0  ...    0.009231 -0.944210        0.006102  0.036591  0.348731
# 43   (23.17, 23.583]   2652   0.812971    0.007109   2156.0  ...    0.014308 -0.808955        0.021440  0.135256  0.348731
# 44  (23.583, 23.996]   1573   0.745709    0.004217   1173.0  ...    0.011539 -1.202533        0.067263  0.393579  0.348731
# 45  (23.996, 24.409]   1455   0.802062    0.003901   1167.0  ...    0.008308 -0.879158        0.056353  0.323376  0.348731
# 46  (24.409, 24.822]   1664   0.795072    0.004461   1323.0  ...    0.009837 -0.922614        0.006990  0.043456  0.348731
# 47  (24.822, 25.234]   1315   0.794677    0.003525   1045.0  ...    0.007789 -0.925039        0.000395  0.002424  0.348731
# 48  (25.234, 25.647]    778   0.777635    0.002086    605.0  ...    0.004991 -1.026452        0.017042  0.101413  0.348731
# 49   (25.647, 26.06]   1786   0.797872    0.004788   1425.0  ...    0.010414 -0.905340        0.020237  0.121112  0.348731
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
df_inputs_prep['int_rate:<9.548'] = np.where((df_inputs_prep['int_rate']<=9.548),1,0)
df_inputs_prep['int_rate:9.548-12.025'] = np.where((df_inputs_prep['int_rate']>9.548) & (df_inputs_prep['int_rate']<=12.025),1,0)
df_inputs_prep['int_rate:12.025-15.745'] = np.where((df_inputs_prep['int_rate']>12.025) & (df_inputs_prep['int_rate']<=15.74),1,0)
df_inputs_prep['int_rate:15.745-20.281'] = np.where((df_inputs_prep['int_rate']>15.74) & (df_inputs_prep['int_rate']<=20.281),1,0)
df_inputs_prep['int_rate:>20.281'] = np.where((df_inputs_prep['int_rate']>20.281),1,0)

# %%
df_inputs_prep['funded_amnt_cat'] = pd.cut(df_inputs_prep['funded_amnt'],50)
df_temp= woe_ordered_continuous(df_inputs_prep,'funded_amnt_cat',df_targets_prep)
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#        funded_amnt_cat  n_obs  prop_good  prop_n_obs   n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE       IV
# 0      (465.5, 1190.0]   1224   0.924020    0.003281   1131.0  ...    0.002683  0.219869             NaN       NaN  0.01579
# 1     (1190.0, 1880.0]   3028   0.915786    0.008117   2773.0  ...    0.007356  0.108033        0.008234  0.111836  0.01579
# 2     (1880.0, 2570.0]   6018   0.907943    0.016133   5464.0  ...    0.015982  0.010383        0.007843  0.097650  0.01579
# 3     (2570.0, 3260.0]   7248   0.902456    0.019430   6541.0  ...    0.020395 -0.053574        0.005487  0.063957  0.01579
# 4     (3260.0, 3950.0]   4751   0.902547    0.012736   4288.0  ...    0.013356 -0.052540        0.000091  0.001034  0.01579
# 5     (3950.0, 4640.0]   9023   0.904577    0.024189   8162.0  ...    0.024838 -0.029239        0.002030  0.023301  0.01579
# 6     (4640.0, 5330.0]  15903   0.908445    0.042632  14447.0  ...    0.042002  0.016405        0.003868  0.045644  0.01579
# 7     (5330.0, 6020.0]  17236   0.919007    0.046206  15840.0  ...    0.040271  0.150539        0.010562  0.134134  0.01579
# 8     (6020.0, 6710.0]   6914   0.901649    0.018535   6234.0  ...    0.019616 -0.062708        0.017358  0.213247  0.01579
# 9     (6710.0, 7400.0]  11806   0.914111    0.031649  10792.0  ...    0.029251  0.086513        0.012463  0.149222  0.01579
# 10    (7400.0, 8090.0]  17692   0.912672    0.047428  16147.0  ...    0.044569  0.068322        0.001439  0.018192  0.01579
# 11    (8090.0, 8780.0]   6316   0.898195    0.016932   5673.0  ...    0.018549 -0.101060        0.014477  0.169382  0.01579
# 12    (8780.0, 9470.0]   9168   0.895724    0.024577   8212.0  ...    0.027578 -0.127795        0.002471  0.026735  0.01579
# 13   (9470.0, 10160.0]  33410   0.911972    0.089564  30469.0  ...    0.084841  0.059571        0.016248  0.187366  0.01579
# 14  (10160.0, 10850.0]   6755   0.894597    0.018109   6043.0  ...    0.020539 -0.139811        0.017376  0.199382  0.01579
# 15  (10850.0, 11540.0]   8559   0.898236    0.022945   7688.0  ...    0.025126 -0.100615        0.003639  0.039196  0.01579
# 16  (11540.0, 12230.0]  23506   0.918446    0.063014  21589.0  ...    0.055301  0.143034        0.020211  0.243648  0.01579
# 17  (12230.0, 12920.0]   4802   0.894211    0.012873   4294.0  ...    0.014655 -0.143896        0.024236  0.286930  0.01579
# 18  (12920.0, 13610.0]   7247   0.912791    0.019427   6615.0  ...    0.018232  0.069817        0.018581  0.213713  0.01579
# 19  (13610.0, 14300.0]   8123   0.911978    0.021776   7408.0  ...    0.020626  0.059644        0.000813  0.010172  0.01579
# 20  (14300.0, 14990.0]   5183   0.894849    0.013894   4638.0  ...    0.015722 -0.137136        0.017130  0.196781  0.01579
# 21  (14990.0, 15680.0]  21757   0.914924    0.058325  19906.0  ...    0.053397  0.096906        0.020075  0.234042  0.01579
# 22  (15680.0, 16370.0]  11788   0.900407    0.031601  10614.0  ...    0.033867 -0.076632        0.014517  0.173538  0.01579
# 23  (16370.0, 17060.0]   6538   0.889875    0.017527   5818.0  ...    0.020770 -0.188928        0.010533  0.112297  0.01579
# 24  (17060.0, 17750.0]   3422   0.883694    0.009174   3024.0  ...    0.011481 -0.250505        0.006181  0.061577  0.01579
# 25  (17750.0, 18440.0]  11441   0.899747    0.030671  10294.0  ...    0.033088 -0.083977        0.016053  0.166528  0.01579
# 26  (18440.0, 19130.0]   3919   0.886706    0.010506   3475.0  ...    0.012808 -0.220864        0.013041  0.136886  0.01579
# 27  (19130.0, 19820.0]   4004   0.879620    0.010734   3522.0  ...    0.013905 -0.289549        0.007085  0.068685  0.01579
# 28  (19820.0, 20510.0]  20287   0.915857    0.054385  18580.0  ...    0.049243  0.108960        0.036237  0.398508  0.01579
# 29  (20510.0, 21200.0]   6712   0.911055    0.017993   6115.0  ...    0.017222  0.048194        0.004803  0.060765  0.01579
# 30  (21200.0, 21890.0]   2081   0.867371    0.005579   1805.0  ...    0.007962 -0.400474        0.043683  0.448668  0.01579
# 31  (21890.0, 22580.0]   4114   0.906174    0.011029   3728.0  ...    0.011135 -0.010599        0.038803  0.389875  0.01579
# 32  (22580.0, 23270.0]   2445   0.902249    0.006554   2206.0  ...    0.006895 -0.055916        0.003925  0.045317  0.01579
# 33  (23270.0, 23960.0]   1825   0.867397    0.004892   1583.0  ...    0.006981 -0.400249        0.034852  0.344333  0.01579
# 34  (23960.0, 24650.0]   9836   0.920089    0.026368   9050.0  ...    0.022674  0.165174        0.052692  0.565424  0.01579
# 35  (24650.0, 25340.0]  10074   0.907187    0.027006   9139.0  ...    0.026972  0.001371        0.012903  0.163804  0.01579
# 36  (25340.0, 26030.0]   1832   0.889192    0.004911   1629.0  ...    0.005856 -0.195873        0.017995  0.197244  0.01579
# 37  (26030.0, 26720.0]   1252   0.856230    0.003356   1072.0  ...    0.005193 -0.494064        0.032962  0.298191  0.01579
# 38  (26720.0, 27410.0]   1510   0.889404    0.004048   1343.0  ...    0.004818 -0.193721        0.033174  0.300343  0.01579
# 39  (27410.0, 28100.0]   6457   0.923804    0.017310   5965.0  ...    0.014193  0.216797        0.034400  0.410518  0.01579
# 40  (28100.0, 28790.0]    795   0.880503    0.002131    700.0  ...    0.002741 -0.281185        0.043300  0.497982  0.01579
# 41  (28790.0, 29480.0]   1176   0.882653    0.003153   1038.0  ...    0.003981 -0.260591        0.002150  0.020594  0.01579
# 42  (29480.0, 30170.0]   7308   0.903667    0.019591   6604.0  ...    0.020309 -0.039736        0.021014  0.220855  0.01579
# 43  (30170.0, 30860.0]    567   0.851852    0.001520    483.0  ...    0.002423 -0.529189        0.051815  0.489453  0.01579
# 44  (30860.0, 31550.0]    884   0.901584    0.002370    797.0  ...    0.002510 -0.063442        0.049732  0.465747  0.01579
# 45  (31550.0, 32240.0]   1326   0.898190    0.003555   1191.0  ...    0.003894 -0.101115        0.003394  0.037673  0.01579
# 46  (32240.0, 32930.0]    631   0.896989    0.001692    566.0  ...    0.001875 -0.114182        0.001201  0.013067  0.01579
# 47  (32930.0, 33620.0]   1090   0.911927    0.002922    994.0  ...    0.002769  0.059000        0.014938  0.173182  0.01579
# 48  (33620.0, 34310.0]    492   0.906504    0.001319    446.0  ...    0.001327 -0.006711        0.005423  0.065711  0.01579
# 49  (34310.0, 35000.0]  13553   0.902236    0.036332  12228.0  ...    0.038223 -0.056073        0.004268  0.049362  0.01579
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
#there does not seem to be an assocition between funded_amnt and WoE, it will not be included

# %%
df_inputs_prep['mths_since_earliest_cr_line_cat'] = pd.cut(df_inputs_prep['mths_since_earliest_cr_line'],50)
df_temp= woe_ordered_continuous(df_inputs_prep,'mths_since_earliest_cr_line_cat',df_targets_prep)
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#    mths_since_earliest_cr_line_cat  n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE        IV
# 0                  (72.486, 83.28]    849   0.923439    0.002276  ...  0.211633             NaN       NaN  0.018053
# 1                   (83.28, 93.56]   1802   0.907880    0.004831  ...  0.009633        0.015559  0.202000  0.018053
# 2                  (93.56, 103.84]   2384   0.883389    0.006391  ... -0.253464        0.024491  0.263097  0.018053
# 3                 (103.84, 114.12]   3940   0.894924    0.010562  ... -0.136335        0.011535  0.117129  0.018053
# 4                  (114.12, 124.4]   6761   0.883153    0.018125  ... -0.255752        0.011770  0.119417  0.018053
# 5                  (124.4, 134.68]   8852   0.880479    0.023730  ... -0.281415        0.002674  0.025663  0.018053
# 6                 (134.68, 144.96]  10920   0.890751    0.029274  ... -0.179954        0.010272  0.101461  0.018053
# 7                 (144.96, 155.24]  12686   0.894924    0.034008  ... -0.136339        0.004173  0.043616  0.018053
# 8                 (155.24, 165.52]  14483   0.899192    0.038826  ... -0.090108        0.004269  0.046231  0.018053
# 9                  (165.52, 175.8]  16547   0.902520    0.044359  ... -0.052844        0.003328  0.037264  0.018053
# 10                 (175.8, 186.08]  20093   0.903548    0.053865  ... -0.041099        0.001028  0.011745  0.018053
# 11                (186.08, 196.36]  21232   0.900528    0.056918  ... -0.075289        0.003021  0.034190  0.018053
# 12                (196.36, 206.64]  22965   0.899543    0.061564  ... -0.086234        0.000985  0.010945  0.018053
# 13                (206.64, 216.92]  22872   0.899047    0.061314  ... -0.091710        0.000496  0.005476  0.018053
# 14                 (216.92, 227.2]  23674   0.904790    0.063464  ... -0.026770        0.005743  0.064940  0.018053
# 15                 (227.2, 237.48]  19181   0.907304    0.051420  ...  0.002765        0.002514  0.029535  0.018053
# 16                (237.48, 247.76]  16320   0.903554    0.043750  ... -0.041037        0.003750  0.043802  0.018053
# 17                (247.76, 258.04]  16793   0.911511    0.045018  ...  0.053834        0.007957  0.094871  0.018053
# 18                (258.04, 268.32]  15400   0.908571    0.041284  ...  0.017927        0.002939  0.035907  0.018053
# 19                 (268.32, 278.6]  13502   0.915716    0.036196  ...  0.107128        0.007145  0.089201  0.018053
# 20                 (278.6, 288.88]  12483   0.917568    0.033464  ...  0.131363        0.001852  0.024235  0.018053
# 21                (288.88, 299.16]  11000   0.919545    0.029488  ...  0.157798        0.001978  0.026436  0.018053
# 22                (299.16, 309.44]   7475   0.920535    0.020039  ...  0.171251        0.000990  0.013453  0.018053
# 23                (309.44, 319.72]   6984   0.924112    0.018722  ...  0.221190        0.003577  0.049938  0.018053
# 24                 (319.72, 330.0]   8070   0.918340    0.021634  ...  0.141608        0.005773  0.079581  0.018053
# 25                 (330.0, 340.28]   6896   0.921984    0.018487  ...  0.191222        0.003644  0.049613  0.018053
# 26                (340.28, 350.56]   6085   0.919803    0.016312  ...  0.161282        0.002181  0.029940  0.018053
# 27                (350.56, 360.84]   5223   0.923799    0.014002  ...  0.216725        0.003996  0.055443  0.018053
# 28                (360.84, 371.12]   5171   0.924579    0.013862  ...  0.227870        0.000781  0.011144  0.018053
# 29                 (371.12, 381.4]   4216   0.923150    0.011302  ...  0.207546        0.001429  0.020323  0.018053
# 30                 (381.4, 391.68]   3571   0.926071    0.009573  ...  0.249459        0.002921  0.041913  0.018053
# 31                (391.68, 401.96]   3544   0.919865    0.009501  ...  0.162119        0.006207  0.087339  0.018053
# 32                (401.96, 412.24]   3324   0.922383    0.008911  ...  0.196781        0.002518  0.034661  0.018053
# 33                (412.24, 422.52]   2492   0.920947    0.006680  ...  0.176896        0.001436  0.019885  0.018053
# 34                 (422.52, 432.8]   1960   0.923980    0.005254  ...  0.219299        0.003033  0.042404  0.018053
# 35                 (432.8, 443.08]   1692   0.940307    0.004536  ...  0.478609        0.016328  0.259309  0.018053
# 36                (443.08, 453.36]   1341   0.929903    0.003595  ...  0.306812        0.010404  0.171796  0.018053
# 37                (453.36, 463.64]   1407   0.918977    0.003772  ...  0.150133        0.010927  0.156679  0.018053
# 38                (463.64, 473.92]   1298   0.917565    0.003480  ...  0.131331        0.001411  0.018802  0.018053
# 39                 (473.92, 484.2]   1379   0.931109    0.003697  ...  0.325470        0.013544  0.194139  0.018053
# 40                 (484.2, 494.48]   1010   0.923762    0.002708  ...  0.216211        0.007347  0.109259  0.018053
# 41                (494.48, 504.76]    756   0.932540    0.002027  ...  0.347983        0.008777  0.131772  0.018053
# 42                (504.76, 515.04]    698   0.921203    0.001871  ...  0.180423        0.011336  0.167561  0.018053
# 43                (515.04, 525.32]    581   0.927711    0.001558  ...  0.273657        0.006507  0.093234  0.018053
# 44                 (525.32, 535.6]    472   0.930085    0.001265  ...  0.309603        0.002374  0.035946  0.018053
# 45                 (535.6, 545.88]    465   0.916129    0.001247  ...  0.112489        0.013956  0.197114  0.018053
# 46                (545.88, 556.16]    383   0.932115    0.001027  ...  0.341250        0.015986  0.228762  0.018053
# 47                (556.16, 566.44]    278   0.910072    0.000745  ...  0.036125        0.022043  0.305126  0.018053
# 48                (566.44, 576.72]    294   0.911565    0.000788  ...  0.054502        0.001493  0.018377  0.018053
# 49                 (576.72, 587.0]   1224   0.902778    0.003281  ... -0.049912        0.008787  0.104413  0.018053
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
df_inputs_prep['mths_since_earliest_cr_line:<94'] = np.where(df_inputs_prep['mths_since_earliest_cr_line'].isin(range(94)), 1, 0)
df_inputs_prep['mths_since_earliest_cr_line:94-154'] = np.where(df_inputs_prep['mths_since_earliest_cr_line'].isin(range(94, 155)), 1, 0)
df_inputs_prep['mths_since_earliest_cr_line:154-216'] = np.where(df_inputs_prep['mths_since_earliest_cr_line'].isin(range(155, 217)), 1, 0)
df_inputs_prep['mths_since_earliest_cr_line:216-270'] = np.where(df_inputs_prep['mths_since_earliest_cr_line'].isin(range(217, 271)), 1, 0)
df_inputs_prep['mths_since_earliest_cr_line:271-352'] = np.where(df_inputs_prep['mths_since_earliest_cr_line'].isin(range(271, 353)), 1, 0)
df_inputs_prep['mths_since_earliest_cr_line:>352'] = np.where(df_inputs_prep['mths_since_earliest_cr_line'].isin(range(353, int(df_inputs_prep['mths_since_earliest_cr_line'].max()))), 1, 0)

# %%
df_inputs_prep['installment_cat'] = pd.cut(df_inputs_prep['installment'],25)
df_temp= woe_ordered_continuous(df_inputs_prep,'installment_cat',df_targets_prep)
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#          installment_cat  n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE        IV
# 0       (14.276, 71.443]   6653   0.913423    0.017835  ...  0.077770             NaN       NaN  0.010842
# 1      (71.443, 127.216]  15962   0.904210    0.042790  ... -0.033485        0.009213  0.111255  0.010842
# 2     (127.216, 182.988]  26856   0.909592    0.071995  ...  0.030273        0.005382  0.063759  0.010842
# 3     (182.988, 238.761]  32306   0.915991    0.086605  ...  0.110692        0.006399  0.080418  0.010842
# 4     (238.761, 294.534]  38942   0.913179    0.104394  ...  0.074689        0.002812  0.036002  0.010842
# 5     (294.534, 350.307]  45885   0.910058    0.123007  ...  0.035952        0.003121  0.038738  0.010842
# 6      (350.307, 406.08]  37085   0.906539    0.099416  ... -0.006299        0.003519  0.042250  0.010842
# 7      (406.08, 461.852]  25919   0.898414    0.069483  ... -0.098660        0.008125  0.092362  0.010842
# 8     (461.852, 517.625]  31333   0.907925    0.083996  ...  0.010164        0.009510  0.108825  0.010842
# 9     (517.625, 573.398]  21333   0.890264    0.057189  ... -0.184949        0.017661  0.195113  0.010842
# 10    (573.398, 629.171]  18805   0.906355    0.050412  ... -0.008472        0.016091  0.176477  0.010842
# 11    (629.171, 684.944]  17528   0.910486    0.046988  ...  0.041196        0.004131  0.049668  0.010842
# 12    (684.944, 740.716]  11012   0.899927    0.029521  ... -0.081971        0.010559  0.123167  0.010842
# 13    (740.716, 796.489]  10157   0.915723    0.027229  ...  0.107218        0.015796  0.189189  0.010842
# 14    (796.489, 852.262]   7693   0.906928    0.020623  ... -0.001695        0.008795  0.108913  0.010842
# 15    (852.262, 908.035]   7507   0.903557    0.020124  ... -0.041005        0.003372  0.039311  0.010842
# 16    (908.035, 963.808]   4629   0.895658    0.012409  ... -0.128506        0.007899  0.087501  0.010842
# 17    (963.808, 1019.58]   3404   0.866921    0.009125  ... -0.404382        0.028737  0.275875  0.010842
# 18   (1019.58, 1075.353]   2165   0.898845    0.005804  ... -0.093929        0.031924  0.310452  0.010842
# 19  (1075.353, 1131.126]   1867   0.935726    0.005005  ...  0.399775        0.036880  0.493704  0.010842
# 20  (1131.126, 1186.899]   2153   0.933581    0.005772  ...  0.364657        0.002145  0.035118  0.010842
# 21  (1186.899, 1242.672]   2271   0.912373    0.006088  ...  0.064576        0.021208  0.300081  0.010842
# 22  (1242.672, 1298.444]   1168   0.865582    0.003131  ... -0.415939        0.046791  0.480515  0.010842
# 23  (1298.444, 1354.217]    318   0.792453    0.000852  ... -0.938614        0.073129  0.522675  0.010842
# 24   (1354.217, 1409.99]     77   0.779221    0.000206  ... -1.017258        0.013232  0.078643  0.010842
#
# [25 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
df_temp= woe_ordered_continuous(df_inputs_prep,'delinq_2yrs',df_targets_prep)
df_temp
# Out:
#     delinq_2yrs   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0           0.0  306417   0.906203    0.821432  277676.0  ...    0.829107 -0.010258             NaN       NaN  inf
# 1           1.0   44927   0.911634    0.120439   40957.0  ...    0.114525  0.055368        0.005431  0.065626  inf
# 2           2.0   13118   0.910352    0.035166   11942.0  ...    0.033925  0.039554        0.001282  0.015814  inf
# 3           3.0    4550   0.906813    0.012197    4126.0  ...    0.012231 -0.003059        0.003539  0.042613  inf
# 4           4.0    1868   0.917024    0.005008    1713.0  ...    0.004471  0.124188        0.010210  0.127246  inf
# 5           5.0     966   0.900621    0.002590     870.0  ...    0.002769 -0.074244        0.016402  0.198431  inf
# 6           6.0     501   0.928144    0.001343     465.0  ...    0.001039  0.280130        0.027523  0.354373  inf
# 7           7.0     279   0.888889    0.000748     248.0  ...    0.000894 -0.198947        0.039255  0.479077  inf
# 8           8.0     148   0.945946    0.000397     140.0  ...    0.000231  0.583812        0.057057  0.782759  inf
# 9           9.0      89   0.910112    0.000239      81.0  ...    0.000231  0.036619        0.035834  0.547193  inf
# 10         10.0      56   0.910714    0.000150      51.0  ...    0.000144  0.043999        0.000602  0.007380  inf
# 11         11.0      31   0.903226    0.000083      28.0  ...    0.000087 -0.044797        0.007488  0.088795  inf
# 12         12.0      30   0.766667    0.000080      23.0  ...    0.000202 -1.088805        0.136559  1.044008  inf
# 13         13.0      18   0.944444    0.000048      17.0  ...    0.000029  0.554825        0.177778  1.643629  inf
# 14         14.0       6   0.833333    0.000016       5.0  ...    0.000029 -0.668951        0.111111  1.223775  inf
# 15         15.0       6   0.833333    0.000016       5.0  ...    0.000029 -0.668951        0.000000  0.000000  inf
# 16         16.0       4   1.000000    0.000011       4.0  ...    0.000000       inf        0.166667       inf  inf
# 17         17.0       3   0.666667    0.000008       2.0  ...    0.000029 -1.585242        0.333333       inf  inf
# 18         18.0       3   0.666667    0.000008       2.0  ...    0.000029 -1.585242        0.000000  0.000000  inf
# 19         19.0       2   1.000000    0.000005       2.0  ...    0.000000       inf        0.333333       inf  inf
# 20         21.0       2   1.000000    0.000005       2.0  ...    0.000000       inf        0.000000       NaN  inf
# 21         22.0       2   1.000000    0.000005       2.0  ...    0.000000       inf        0.000000       NaN  inf
# 22         24.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 23         29.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
#
# [24 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
df_inputs_prep['delinq_2yrs:0'] = np.where((df_inputs_prep['delinq_2yrs'] == 0), 1, 0)
df_inputs_prep['delinq_2yrs:1-3'] = np.where((df_inputs_prep['delinq_2yrs'] >= 1) & (df_inputs_prep['delinq_2yrs'] <= 3), 1, 0)
df_inputs_prep['delinq_2yrs:>=4'] = np.where((df_inputs_prep['delinq_2yrs'] >= 9), 1, 0)

# %%
df_temp= woe_ordered_continuous(df_inputs_prep,'inq_last_6mths',df_targets_prep)
df_temp
# Out:
#     inq_last_6mths   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0              0.0  193232   0.922259    0.518009  178210.0  ...    0.433348  0.195058             NaN       NaN  inf
# 1              1.0  104163   0.901069    0.279236   93858.0  ...    0.297274 -0.069235        0.021191  0.264293  inf
# 2              2.0   46214   0.881226    0.123889   40725.0  ...    0.158344 -0.274293        0.019842  0.205058  inf
# 3              3.0   20040   0.857934    0.053723   17193.0  ...    0.082129 -0.480152        0.023292  0.205860  inf
# 4              4.0    5810   0.889845    0.015575    5170.0  ...    0.018462 -0.189229        0.031911  0.290923  inf
# 5              5.0    2217   0.892648    0.005943    1979.0  ...    0.006866 -0.160312        0.002803  0.028916  inf
# 6              6.0     977   0.884340    0.002619     864.0  ...    0.003260 -0.244204        0.008308  0.083891  inf
# 7              7.0     159   0.949686    0.000426     151.0  ...    0.000231  0.659450        0.065346  0.903653  inf
# 8              8.0     101   0.970297    0.000271      98.0  ...    0.000087  1.207966        0.020611  0.548517  inf
# 9              9.0      43   1.000000    0.000115      43.0  ...    0.000000       inf        0.029703       inf  inf
# 10            10.0      17   1.000000    0.000046      17.0  ...    0.000000       inf        0.000000       NaN  inf
# 11            11.0       8   1.000000    0.000021       8.0  ...    0.000000       inf        0.000000       NaN  inf
# 12            12.0      12   1.000000    0.000032      12.0  ...    0.000000       inf        0.000000       NaN  inf
# 13            13.0       5   1.000000    0.000013       5.0  ...    0.000000       inf        0.000000       NaN  inf
# 14            14.0       5   1.000000    0.000013       5.0  ...    0.000000       inf        0.000000       NaN  inf
# 15            15.0       9   1.000000    0.000024       9.0  ...    0.000000       inf        0.000000       NaN  inf
# 16            16.0       3   1.000000    0.000008       3.0  ...    0.000000       inf        0.000000       NaN  inf
# 17            17.0       2   1.000000    0.000005       2.0  ...    0.000000       inf        0.000000       NaN  inf
# 18            18.0       2   1.000000    0.000005       2.0  ...    0.000000       inf        0.000000       NaN  inf
# 19            19.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 20            20.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 21            24.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 22            25.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 23            27.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 24            28.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 25            31.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 26            32.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 27            33.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
#
# [28 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
df_inputs_prep['inq_last_6mths:0'] = np.where((df_inputs_prep['inq_last_6mths'] == 0), 1, 0)
df_inputs_prep['inq_last_6mths:1-2'] = np.where((df_inputs_prep['inq_last_6mths'] >= 1) & (df_inputs_prep['inq_last_6mths'] <= 2), 1, 0)
df_inputs_prep['inq_last_6mths:3-6'] = np.where((df_inputs_prep['inq_last_6mths'] >= 3) & (df_inputs_prep['inq_last_6mths'] <= 6), 1, 0)
df_inputs_prep['inq_last_6mths:>6'] = np.where((df_inputs_prep['inq_last_6mths'] > 6), 1, 0)

# %%
df_temp= woe_ordered_continuous(df_inputs_prep,'open_acc',df_targets_prep)
df_temp
# Out:
#     open_acc  n_obs  prop_good  prop_n_obs   n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0        0.0     29   0.896552    0.000078     26.0  ...    0.000087 -0.118905             NaN       NaN  inf
# 1        1.0    110   0.936364    0.000295    103.0  ...    0.000202  0.410430        0.039812  0.529335  inf
# 2        2.0   1456   0.867445    0.003903   1263.0  ...    0.005568 -0.399834        0.068919  0.810264  inf
# 3        3.0   4378   0.889447    0.011736   3894.0  ...    0.013962 -0.193281        0.022002  0.206552  inf
# 4        4.0  10028   0.903670    0.026883   9062.0  ...    0.027867 -0.039707        0.014222  0.153574  inf
# 5        5.0  17141   0.906131    0.045951  15532.0  ...    0.046416 -0.011099        0.002462  0.028608  inf
# 6        6.0  24621   0.907234    0.066003  22337.0  ...    0.065888  0.001927        0.001102  0.013027  inf
# 7        7.0  30169   0.907654    0.080876  27383.0  ...    0.080369  0.006927        0.000420  0.004999  inf
# 8        8.0  33579   0.905953    0.090017  30421.0  ...    0.091101 -0.013195        0.001700  0.020121  inf
# 9        9.0  35251   0.905109    0.094500  31906.0  ...    0.096495 -0.023061        0.000844  0.009867  inf
# 10      10.0  33936   0.906589    0.090974  30766.0  ...    0.091447 -0.005710        0.001480  0.017351  inf
# 11      11.0  31372   0.901983    0.084101  28297.0  ...    0.088706 -0.058938        0.004606  0.053228  inf
# 12      12.0  27699   0.905376    0.074254  25078.0  ...    0.075609 -0.019954        0.003393  0.038984  inf
# 13      13.0  23892   0.911393    0.064049  21775.0  ...    0.061070  0.052374        0.006017  0.072327  inf
# 14      14.0  19770   0.906424    0.052999  17920.0  ...    0.053368 -0.007657        0.004969  0.060031  inf
# 15      15.0  16228   0.909231    0.043503  14755.0  ...    0.042492  0.025892        0.002807  0.033549  inf
# 16      16.0  13540   0.912334    0.036298  12353.0  ...    0.034242  0.064081        0.003103  0.038189  inf
# 17      17.0  10712   0.910754    0.028716   9756.0  ...    0.027578  0.044491        0.001580  0.019590  inf
# 18      18.0   8606   0.912735    0.023071   7855.0  ...    0.021665  0.069111        0.001981  0.024620  inf
# 19      19.0   6836   0.908865    0.018326   6213.0  ...    0.017972  0.021464        0.003870  0.047647  inf
# 20      20.0   5224   0.914242    0.014004   4776.0  ...    0.012924  0.088177        0.005377  0.066713  inf
# 21      21.0   4242   0.914191    0.011372   3878.0  ...    0.010501  0.087532        0.000051  0.000644  inf
# 22      22.0   3313   0.911561    0.008881   3020.0  ...    0.008452  0.054451        0.002631  0.033081  inf
# 23      23.0   2530   0.918972    0.006782   2325.0  ...    0.005914  0.150077        0.007412  0.095626  inf
# 24      24.0   1979   0.913087    0.005305   1807.0  ...    0.004962  0.073540        0.005885  0.076537  inf
# 25      25.0   1542   0.906615    0.004134   1398.0  ...    0.004154 -0.005404        0.006473  0.078944  inf
# 26      26.0   1064   0.920113    0.002852    979.0  ...    0.002452  0.165492        0.013498  0.170896  inf
# 27      27.0    863   0.924681    0.002313    798.0  ...    0.001875  0.229333        0.004569  0.063841  inf
# 28      28.0    613   0.931485    0.001643    571.0  ...    0.001212  0.331331        0.006803  0.101998  inf
# 29      29.0    496   0.911290    0.001330    452.0  ...    0.001269  0.051104        0.020194  0.280227  inf
# 30      30.0    377   0.912467    0.001011    344.0  ...    0.000952  0.065745        0.001177  0.014642  inf
# 31      31.0    285   0.922807    0.000764    263.0  ...    0.000635  0.202723        0.010340  0.136977  inf
# 32      32.0    234   0.931624    0.000627    218.0  ...    0.000462  0.333518        0.008817  0.130795  inf
# 33      33.0    175   0.914286    0.000469    160.0  ...    0.000433  0.088735        0.017338  0.244783  inf
# 34      34.0    145   0.931034    0.000389    135.0  ...    0.000288  0.324301        0.016749  0.235566  inf
# 35      35.0    124   0.935484    0.000332    116.0  ...    0.000231  0.395760        0.004449  0.071459  inf
# 36      36.0    104   0.884615    0.000279     92.0  ...    0.000346 -0.241507        0.050868  0.637267  inf
# 37      37.0     79   0.911392    0.000212     72.0  ...    0.000202  0.052367        0.026777  0.293874  inf
# 38      38.0     64   0.890625    0.000172     57.0  ...    0.000202 -0.181248        0.020767  0.233615  inf
# 39      39.0     55   0.945455    0.000147     52.0  ...    0.000087  0.574243        0.054830  0.755490  inf
# 40      40.0     30   0.933333    0.000080     28.0  ...    0.000058  0.360669        0.012121  0.213574  inf
# 41      41.0     30   0.866667    0.000080     26.0  ...    0.000115 -0.406587        0.066667  0.767255  inf
# 42      42.0     22   0.954545    0.000059     21.0  ...    0.000029  0.766134        0.087879  1.172720  inf
# 43      43.0     15   0.866667    0.000040     13.0  ...    0.000058 -0.406587        0.087879  1.172720  inf
# 44      44.0     12   0.916667    0.000032     11.0  ...    0.000029  0.119507        0.050000  0.526093  inf
# 45      45.0     14   0.928571    0.000038     13.0  ...    0.000029  0.286561        0.011905  0.167054  inf
# 46      46.0      5   1.000000    0.000013      5.0  ...    0.000000       inf        0.071429       inf  inf
# 47      47.0      6   1.000000    0.000016      6.0  ...    0.000000       inf        0.000000       NaN  inf
# 48      48.0      4   1.000000    0.000011      4.0  ...    0.000000       inf        0.000000       NaN  inf
# 49      49.0      6   1.000000    0.000016      6.0  ...    0.000000       inf        0.000000       NaN  inf
# 50      50.0      4   1.000000    0.000011      4.0  ...    0.000000       inf        0.000000       NaN  inf
# 51      51.0      5   1.000000    0.000013      5.0  ...    0.000000       inf        0.000000       NaN  inf
# 52      52.0      1   1.000000    0.000003      1.0  ...    0.000000       inf        0.000000       NaN  inf
# 53      53.0      3   1.000000    0.000008      3.0  ...    0.000000       inf        0.000000       NaN  inf
# 54      54.0      2   1.000000    0.000005      2.0  ...    0.000000       inf        0.000000       NaN  inf
# 55      55.0      2   1.000000    0.000005      2.0  ...    0.000000       inf        0.000000       NaN  inf
# 56      58.0      1   1.000000    0.000003      1.0  ...    0.000000       inf        0.000000       NaN  inf
# 57      62.0      1   1.000000    0.000003      1.0  ...    0.000000       inf        0.000000       NaN  inf
# 58      75.0      1   1.000000    0.000003      1.0  ...    0.000000       inf        0.000000       NaN  inf
# 59      76.0      2   0.500000    0.000005      1.0  ...    0.000029 -2.278389        0.500000       inf  inf
# 60      84.0      1   1.000000    0.000003      1.0  ...    0.000000       inf        0.500000       inf  inf
#
# [61 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
df_temp= woe_ordered_continuous(df_inputs_prep,'pub_rec',df_targets_prep)
df_temp
# Out:
#     pub_rec   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0       0.0  323999   0.905848    0.868565  293494.0  ...    0.879994 -0.014422             NaN       NaN  inf
# 1       1.0   42381   0.913169    0.113613   38701.0  ...    0.106159  0.074564        0.007320  0.088986  inf
# 2       2.0    4527   0.921803    0.012136    4173.0  ...    0.010212  0.188705        0.008634  0.114141  inf
# 3       3.0    1280   0.942187    0.003431    1206.0  ...    0.002135  0.512611        0.020385  0.323906  inf
# 4       4.0     408   0.938725    0.001094     383.0  ...    0.000721  0.450770        0.003462  0.061840  inf
# 5       5.0     203   0.926108    0.000544     188.0  ...    0.000433  0.250003        0.012617  0.200767  inf
# 6       6.0     117   0.931624    0.000314     109.0  ...    0.000231  0.333518        0.005516  0.083515  inf
# 7       7.0      48   0.958333    0.000129      46.0  ...    0.000058  0.857105        0.026709  0.523588  inf
# 8       8.0      24   1.000000    0.000064      24.0  ...    0.000000       inf        0.041667       inf  inf
# 9       9.0      14   0.857143    0.000038      12.0  ...    0.000058 -0.486629        0.142857       inf  inf
# 10     10.0      10   1.000000    0.000027      10.0  ...    0.000000       inf        0.142857       inf  inf
# 11     11.0       3   1.000000    0.000008       3.0  ...    0.000000       inf        0.000000       NaN  inf
# 12     12.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 13     13.0       2   1.000000    0.000005       2.0  ...    0.000000       inf        0.000000       NaN  inf
# 14     15.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 15     16.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 16     17.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 17     18.0       2   1.000000    0.000005       2.0  ...    0.000000       inf        0.000000       NaN  inf
# 18     19.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 19     21.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 20     34.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 21     40.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 22     54.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
# 23     63.0       1   1.000000    0.000003       1.0  ...    0.000000       inf        0.000000       NaN  inf
#
# [24 rows x 12 columns]

# %%
plot_by_woe(df_temp)

# %%
df_inputs_prep['pub_rec:0-2'] = np.where((df_inputs_prep['pub_rec'] >= 0) & (df_inputs_prep['pub_rec'] <= 2), 1, 0)
df_inputs_prep['pub_rec:3-4'] = np.where((df_inputs_prep['pub_rec'] >= 3) & (df_inputs_prep['pub_rec'] <= 4), 1, 0)
df_inputs_prep['pub_rec:>=5'] = np.where((df_inputs_prep['pub_rec'] >= 5), 1, 0)

# %%
df_inputs_prep['total_acc_cat'] = pd.cut(df_inputs_prep['total_acc'],50)
df_temp= woe_ordered_continuous(df_inputs_prep,'total_acc_cat',df_targets_prep)
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#      total_acc_cat  n_obs  prop_good  prop_n_obs   n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0     (-0.15, 3.0]    459   0.880174    0.001230    404.0  ...    0.001587 -0.284307             NaN       NaN  inf
# 1       (3.0, 6.0]   6004   0.880913    0.016095   5289.0  ...    0.020626 -0.277287        0.000738  0.007020  inf
# 2       (6.0, 9.0]  15047   0.891075    0.040337  13408.0  ...    0.047281 -0.176624        0.010162  0.100663  inf
# 3      (9.0, 12.0]  25169   0.897493    0.067472  22589.0  ...    0.074427 -0.108715        0.006418  0.067908  inf
# 4     (12.0, 15.0]  33651   0.898785    0.090210  30245.0  ...    0.098255 -0.094596        0.001292  0.014119  inf
# 5     (15.0, 18.0]  38711   0.904110    0.103775  34999.0  ...    0.107082 -0.034640        0.005325  0.059956  inf
# 6     (18.0, 21.0]  40599   0.902017    0.108836  36621.0  ...    0.114756 -0.058546        0.002093  0.023906  inf
# 7     (21.0, 24.0]  40163   0.907402    0.107668  36444.0  ...    0.107284  0.003933        0.005385  0.062479  inf
# 8     (24.0, 27.0]  36286   0.911729    0.097274  33083.0  ...    0.092399  0.056543        0.004327  0.052610  inf
# 9     (27.0, 30.0]  31775   0.913423    0.085181  29024.0  ...    0.079360  0.077770        0.001693  0.021227  inf
# 10    (30.0, 33.0]  25900   0.911313    0.069432  23603.0  ...    0.066263  0.051381        0.002110  0.026389  inf
# 11    (33.0, 36.0]  20748   0.914209    0.055620  18968.0  ...    0.051349  0.087751        0.002896  0.036370  inf
# 12    (36.0, 39.0]  16055   0.917409    0.043040  14729.0  ...    0.038252  0.129263        0.003200  0.041511  inf
# 13    (39.0, 42.0]  12134   0.918246    0.032528  11142.0  ...    0.028617  0.140365        0.000837  0.011102  inf
# 14    (42.0, 45.0]   9107   0.912595    0.024414   8311.0  ...    0.022963  0.067347        0.005652  0.073018  inf
# 15    (45.0, 48.0]   6494   0.912381    0.017409   5925.0  ...    0.016414  0.064667        0.000214  0.002680  inf
# 16    (48.0, 51.0]   4551   0.920677    0.012200   4190.0  ...    0.010414  0.173189        0.008296  0.108523  inf
# 17    (51.0, 54.0]   3260   0.926687    0.008739   3021.0  ...    0.006895  0.258491        0.006010  0.085302  inf
# 18    (54.0, 57.0]   2146   0.921715    0.005753   1978.0  ...    0.004846  0.187489        0.004972  0.071002  inf
# 19    (57.0, 60.0]   1605   0.910903    0.004303   1462.0  ...    0.004125  0.046327        0.010811  0.141162  inf
# 20    (60.0, 63.0]   2164   0.918207    0.005801   1987.0  ...    0.005106  0.139843        0.007304  0.093515  inf
# 21    (63.0, 66.0]    317   0.933754    0.000850    296.0  ...    0.000606  0.367448        0.015547  0.227606  inf
# 22    (66.0, 69.0]    218   0.949541    0.000584    207.0  ...    0.000317  0.656435        0.015787  0.288987  inf
# 23    (69.0, 72.0]    120   0.950000    0.000322    114.0  ...    0.000173  0.666050        0.000459  0.009615  inf
# 24    (72.0, 75.0]    114   0.938596    0.000306    107.0  ...    0.000202  0.448530        0.011404  0.217520  inf
# 25    (75.0, 78.0]     64   0.937500    0.000172     60.0  ...    0.000115  0.429661        0.001096  0.018868  inf
# 26    (78.0, 81.0]     52   0.942308    0.000139     49.0  ...    0.000087  0.514819        0.004808  0.085158  inf
# 27    (81.0, 84.0]     25   0.920000    0.000067     23.0  ...    0.000058  0.163958        0.022308  0.350861  inf
# 28    (84.0, 87.0]     28   0.964286    0.000075     27.0  ...    0.000029  1.017448        0.044286  0.853490  inf
# 29    (87.0, 90.0]     22   0.909091    0.000059     20.0  ...    0.000058  0.024196        0.055195  0.993252  inf
# 30    (90.0, 93.0]     12   0.916667    0.000032     11.0  ...    0.000029  0.119507        0.007576  0.095310  inf
# 31    (93.0, 96.0]      8   0.875000    0.000021      7.0  ...    0.000029 -0.332479        0.041667  0.451985  inf
# 32    (96.0, 99.0]      4   1.000000    0.000011      4.0  ...    0.000000       inf        0.125000       inf  inf
# 33   (99.0, 102.0]      4   1.000000    0.000011      4.0  ...    0.000000       inf        0.000000       NaN  inf
# 34  (102.0, 105.0]      4   1.000000    0.000011      4.0  ...    0.000000       inf        0.000000       NaN  inf
# 35  (105.0, 108.0]      1   1.000000    0.000003      1.0  ...    0.000000       inf        0.000000       NaN  inf
# 36  (108.0, 111.0]      0        NaN    0.000000      NaN  ...         NaN       NaN             NaN       NaN  inf
# 37  (111.0, 114.0]      0        NaN    0.000000      NaN  ...         NaN       NaN             NaN       NaN  inf
# 38  (114.0, 117.0]      2   1.000000    0.000005      2.0  ...    0.000000       inf             NaN       NaN  inf
# 39  (117.0, 120.0]      2   1.000000    0.000005      2.0  ...    0.000000       inf        0.000000       NaN  inf
# 40  (120.0, 123.0]      1   1.000000    0.000003      1.0  ...    0.000000       inf        0.000000       NaN  inf
# 41  (123.0, 126.0]      1   1.000000    0.000003      1.0  ...    0.000000       inf        0.000000       NaN  inf
# 42  (126.0, 129.0]      0        NaN    0.000000      NaN  ...         NaN       NaN             NaN       NaN  inf
# 43  (129.0, 132.0]      0        NaN    0.000000      NaN  ...         NaN       NaN             NaN       NaN  inf
# 44  (132.0, 135.0]      0        NaN    0.000000      NaN  ...         NaN       NaN             NaN       NaN  inf
# 45  (135.0, 138.0]      0        NaN    0.000000      NaN  ...         NaN       NaN             NaN       NaN  inf
# 46  (138.0, 141.0]      0        NaN    0.000000      NaN  ...         NaN       NaN             NaN       NaN  inf
# 47  (141.0, 144.0]      0        NaN    0.000000      NaN  ...         NaN       NaN             NaN       NaN  inf
# 48  (144.0, 147.0]      0        NaN    0.000000      NaN  ...         NaN       NaN             NaN       NaN  inf
# 49  (147.0, 150.0]      1   1.000000    0.000003      1.0  ...    0.000000       inf             NaN       NaN  inf
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
df_inputs_prep['total_acc:<=27'] = np.where((df_inputs_prep['total_acc'] <= 27), 1, 0)
df_inputs_prep['total_acc:28-51'] = np.where((df_inputs_prep['total_acc'] >= 28) & (df_inputs_prep['total_acc'] <= 51), 1, 0)
df_inputs_prep['total_acc:>=52'] = np.where((df_inputs_prep['total_acc'] >= 52), 1, 0)

# %%
df_temp= woe_ordered_continuous(df_inputs_prep,'acc_now_delinq',df_targets_prep)
df_temp
# Out:
#    acc_now_delinq   n_obs  prop_good  prop_n_obs    n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE   IV
# 0             0.0  371682   0.907033    0.996392  337128.0  ...    0.996798 -0.000449             NaN       NaN  inf
# 1             1.0    1263   0.916865    0.003386    1158.0  ...    0.003029  0.122101        0.009831  0.122550  inf
# 2             2.0      70   0.942857    0.000188      66.0  ...    0.000115  0.524972        0.025993  0.402871  inf
# 3             3.0       7   0.857143    0.000019       6.0  ...    0.000029 -0.486629        0.085714  1.011601  inf
# 4             4.0       4   1.000000    0.000011       4.0  ...    0.000000       inf        0.142857       inf  inf
# 5             5.0       2   0.500000    0.000005       1.0  ...    0.000029 -2.278389        0.500000       inf  inf
#
# [6 rows x 12 columns]

# %%
plot_by_woe(df_temp)

# %%
df_inputs_prep['acc_now_delinq:0'] = np.where((df_inputs_prep['acc_now_delinq'] == 0), 1, 0)
df_inputs_prep['acc_now_delinq:>=1'] = np.where((df_inputs_prep['acc_now_delinq'] >= 1), 1, 0)

# %%
df_inputs_prep['total_rev_hi_lim_cat'] = pd.cut(df_inputs_prep['total_rev_hi_lim'], 800)
df_temp = woe_ordered_continuous(df_inputs_prep, 'total_rev_hi_lim_cat', df_targets_prep)
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
# C:\Users\Isildil\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#            total_rev_hi_lim_cat   n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE   IV
# 0        (-9999.999, 12499.999]   68860   0.904473    0.217413  ... -0.140717             NaN       NaN  inf
# 1        (12499.999, 24999.998]  104017   0.908467    0.328415  ... -0.093601        0.003994  0.047116  inf
# 2        (24999.998, 37499.996]   63020   0.915487    0.198975  ... -0.006106        0.007020  0.087495  inf
# 3        (37499.996, 49999.995]   35158   0.926930    0.111005  ...  0.151799        0.011443  0.157905  inf
# 4        (49999.995, 62499.994]   18441   0.936554    0.058224  ...  0.303366        0.009625  0.151567  inf
# ..                          ...     ...        ...         ...  ...       ...             ...       ...  ...
# 795  (9937499.006, 9949999.005]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 796  (9949999.005, 9962499.004]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 797  (9962499.004, 9974999.003]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 798  (9974999.003, 9987499.001]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 799    (9987499.001, 9999999.0]       2   1.000000    0.000006  ...       inf             NaN       NaN  inf
#
# [800 rows x 12 columns]

# %%
plot_by_woe(df_temp,90)

# %%
df_inputs_prep['total_rev_hi_lim:<=5K'] = np.where((df_inputs_prep['total_rev_hi_lim'] <= 5000), 1, 0)
df_inputs_prep['total_rev_hi_lim:5K-10K'] = np.where((df_inputs_prep['total_rev_hi_lim'] > 5000) & (df_inputs_prep['total_rev_hi_lim'] <= 10000), 1, 0)
df_inputs_prep['total_rev_hi_lim:10K-20K'] = np.where((df_inputs_prep['total_rev_hi_lim'] > 10000) & (df_inputs_prep['total_rev_hi_lim'] <= 20000), 1, 0)
df_inputs_prep['total_rev_hi_lim:20K-30K'] = np.where((df_inputs_prep['total_rev_hi_lim'] > 20000) & (df_inputs_prep['total_rev_hi_lim'] <= 30000), 1, 0)
df_inputs_prep['total_rev_hi_lim:30K-40K'] = np.where((df_inputs_prep['total_rev_hi_lim'] > 30000) & (df_inputs_prep['total_rev_hi_lim'] <= 40000), 1, 0)
df_inputs_prep['total_rev_hi_lim:40K-55K'] = np.where((df_inputs_prep['total_rev_hi_lim'] > 40000) & (df_inputs_prep['total_rev_hi_lim'] <= 55000), 1, 0)
df_inputs_prep['total_rev_hi_lim:55K-95K'] = np.where((df_inputs_prep['total_rev_hi_lim'] > 55000) & (df_inputs_prep['total_rev_hi_lim'] <= 95000), 1, 0)
df_inputs_prep['total_rev_hi_lim:>95K'] = np.where((df_inputs_prep['total_rev_hi_lim'] > 95000), 1, 0)

# %%
df_inputs_prep['annual_inc_cat'] = pd.cut(df_inputs_prep['annual_inc'], 50)
df_temp = woe_ordered_continuous(df_inputs_prep, 'annual_inc_cat', df_targets_prep)
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#               annual_inc_cat   n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE   IV
# 0     (-5243.882, 144693.64]  351901   0.905081    0.943371  ... -0.023376             NaN       NaN  inf
# 1     (144693.64, 287491.28]   19004   0.939276    0.050946  ...  0.460389        0.034195  0.483766  inf
# 2     (287491.28, 430288.92]    1525   0.950820    0.004088  ...  0.683451        0.011544  0.223061  inf
# 3     (430288.92, 573086.56]     332   0.945783    0.000890  ...  0.580641        0.005037  0.102809  inf
# 4      (573086.56, 715884.2]     112   0.919643    0.000300  ...  0.159125        0.026140  0.421517  inf
# 5      (715884.2, 858681.84]      65   0.907692    0.000174  ...  0.007398        0.011951  0.151726  inf
# 6    (858681.84, 1001479.48]      39   0.974359    0.000105  ...  1.359206        0.066667  1.351808  inf
# 7   (1001479.48, 1144277.12]      10   1.000000    0.000027  ...       inf        0.025641       inf  inf
# 8   (1144277.12, 1287074.76]      12   1.000000    0.000032  ...       inf        0.000000       NaN  inf
# 9    (1287074.76, 1429872.4]       6   1.000000    0.000016  ...       inf        0.000000       NaN  inf
# 10   (1429872.4, 1572670.04]       3   1.000000    0.000008  ...       inf        0.000000       NaN  inf
# 11  (1572670.04, 1715467.68]       1   1.000000    0.000003  ...       inf        0.000000       NaN  inf
# 12  (1715467.68, 1858265.32]       1   1.000000    0.000003  ...       inf        0.000000       NaN  inf
# 13  (1858265.32, 2001062.96]       6   1.000000    0.000016  ...       inf        0.000000       NaN  inf
# 14   (2001062.96, 2143860.6]       1   1.000000    0.000003  ...       inf        0.000000       NaN  inf
# 15   (2143860.6, 2286658.24]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 16  (2286658.24, 2429455.88]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 17  (2429455.88, 2572253.52]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 18  (2572253.52, 2715051.16]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 19   (2715051.16, 2857848.8]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 20   (2857848.8, 3000646.44]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 21  (3000646.44, 3143444.08]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 22  (3143444.08, 3286241.72]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 23  (3286241.72, 3429039.36]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 24   (3429039.36, 3571837.0]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 25   (3571837.0, 3714634.64]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 26  (3714634.64, 3857432.28]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 27  (3857432.28, 4000229.92]       1   1.000000    0.000003  ...       inf             NaN       NaN  inf
# 28  (4000229.92, 4143027.56]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 29   (4143027.56, 4285825.2]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 30   (4285825.2, 4428622.84]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 31  (4428622.84, 4571420.48]       1   1.000000    0.000003  ...       inf             NaN       NaN  inf
# 32  (4571420.48, 4714218.12]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 33  (4714218.12, 4857015.76]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 34   (4857015.76, 4999813.4]       1   1.000000    0.000003  ...       inf             NaN       NaN  inf
# 35   (4999813.4, 5142611.04]       1   1.000000    0.000003  ...       inf        0.000000       NaN  inf
# 36  (5142611.04, 5285408.68]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 37  (5285408.68, 5428206.32]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 38  (5428206.32, 5571003.96]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 39   (5571003.96, 5713801.6]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 40   (5713801.6, 5856599.24]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 41  (5856599.24, 5999396.88]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 42  (5999396.88, 6142194.52]       2   1.000000    0.000005  ...       inf             NaN       NaN  inf
# 43  (6142194.52, 6284992.16]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 44   (6284992.16, 6427789.8]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 45   (6427789.8, 6570587.44]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 46  (6570587.44, 6713385.08]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 47  (6713385.08, 6856182.72]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 48  (6856182.72, 6998980.36]       0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 49   (6998980.36, 7141778.0]       1   1.000000    0.000003  ...       inf             NaN       NaN  inf
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp, 90)

# %%
df_inputs_prep_temp = df_inputs_prep.loc[df_inputs_prep['annual_inc']<=140000, : ]

# %%
df_inputs_prep_temp['annual_inc_cat'] = pd.cut(df_inputs_prep_temp['annual_inc'], 50)
df_temp = woe_ordered_continuous(df_inputs_prep_temp, 'annual_inc_cat', df_targets_prep[df_inputs_prep_temp.index])
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\3381732880.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inputs_prep_temp['annual_inc_cat'] = pd.cut(df_inputs_prep_temp['annual_inc'], 50)
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#             annual_inc_cat  n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE        IV
# 0      (1757.896, 4658.08]     15   0.933333    0.000043  ...  0.384681             NaN       NaN  0.053585
# 1       (4658.08, 7420.16]     40   0.875000    0.000114  ... -0.308466        0.058333  0.693147  0.053585
# 2      (7420.16, 10182.24]    287   0.888502    0.000818  ... -0.178849        0.013502  0.129617  0.053585
# 3     (10182.24, 12944.32]    547   0.850091    0.001558  ... -0.519058        0.038410  0.340209  0.053585
# 4      (12944.32, 15706.4]   1210   0.851240    0.003447  ... -0.510019        0.001148  0.009039  0.053585
# 5      (15706.4, 18468.48]   1522   0.873193    0.004335  ... -0.324884        0.021953  0.185135  0.053585
# 6     (18468.48, 21230.56]   2928   0.873634    0.008340  ... -0.320898        0.000441  0.003986  0.053585
# 7     (21230.56, 23992.64]   2495   0.866132    0.007107  ... -0.387191        0.007502  0.066293  0.053585
# 8     (23992.64, 26754.72]   7016   0.871009    0.019985  ... -0.344466        0.004877  0.042725  0.053585
# 9      (26754.72, 29516.8]   5643   0.881800    0.016074  ... -0.244785        0.010791  0.099681  0.053585
# 10     (29516.8, 32278.88]  11915   0.877633    0.033940  ... -0.284170        0.004167  0.039386  0.053585
# 11    (32278.88, 35040.96]  12241   0.880157    0.034869  ... -0.260460        0.002524  0.023710  0.053585
# 12    (35040.96, 37803.04]   7905   0.878684    0.022518  ... -0.274346        0.001472  0.013886  0.053585
# 13    (37803.04, 40565.12]  17910   0.883808    0.051017  ... -0.225381        0.005124  0.048965  0.053585
# 14     (40565.12, 43327.2]  12508   0.888072    0.035629  ... -0.183183        0.004264  0.042198  0.053585
# 15     (43327.2, 46089.28]  16590   0.891501    0.047257  ... -0.148212        0.003429  0.034971  0.053585
# 16    (46089.28, 48851.36]   9878   0.894614    0.028138  ... -0.115611        0.003113  0.032601  0.053585
# 17    (48851.36, 51613.44]  19024   0.895711    0.054190  ... -0.103928        0.001096  0.011683  0.053585
# 18    (51613.44, 54375.52]  12766   0.903259    0.036364  ... -0.020408        0.007548  0.083520  0.053585
# 19     (54375.52, 57137.6]  16153   0.904166    0.046012  ... -0.009976        0.000908  0.010432  0.053585
# 20     (57137.6, 59899.68]   6482   0.903425    0.018464  ... -0.018505        0.000742  0.008528  0.053585
# 21    (59899.68, 62661.76]  21299   0.898634    0.060671  ... -0.072241        0.004791  0.053736  0.053585
# 22    (62661.76, 65423.84]  16090   0.906277    0.045833  ...  0.014627        0.007643  0.086868  0.053585
# 23    (65423.84, 68185.92]   7942   0.912616    0.022623  ...  0.091633        0.006339  0.077005  0.053585
# 24     (68185.92, 70948.0]  12982   0.909567    0.036980  ...  0.053984        0.003049  0.037648  0.053585
# 25     (70948.0, 73710.08]   8382   0.911358    0.023876  ...  0.075950        0.001791  0.021965  0.053585
# 26    (73710.08, 76472.16]  13145   0.916774    0.037444  ...  0.144931        0.005417  0.068981  0.053585
# 27    (76472.16, 79234.24]   5679   0.919352    0.016177  ...  0.179199        0.002578  0.034268  0.053585
# 28    (79234.24, 81996.32]  11397   0.917873    0.032465  ...  0.159418        0.001479  0.019781  0.053585
# 29     (81996.32, 84758.4]   6063   0.927429    0.017271  ...  0.293470        0.009556  0.134052  0.053585
# 30     (84758.4, 87520.48]   9980   0.922244    0.028428  ...  0.218865        0.005184  0.074605  0.053585
# 31    (87520.48, 90282.56]  10393   0.921678    0.029605  ...  0.210992        0.000566  0.007873  0.053585
# 32    (90282.56, 93044.64]   4337   0.930136    0.012354  ...  0.334405        0.008458  0.123413  0.053585
# 33    (93044.64, 95806.72]   5634   0.925808    0.016049  ...  0.269628        0.004328  0.064776  0.053585
# 34     (95806.72, 98568.8]   4667   0.924363    0.013294  ...  0.248776        0.001445  0.020852  0.053585
# 35    (98568.8, 101330.88]   8793   0.929489    0.025047  ...  0.324496        0.005127  0.075719  0.053585
# 36  (101330.88, 104092.96]   3232   0.934406    0.009206  ...  0.402050        0.004917  0.077554  0.053585
# 37  (104092.96, 106855.04]   3736   0.937099    0.010642  ...  0.446842        0.002693  0.044793  0.053585
# 38  (106855.04, 109617.12]   2277   0.937198    0.006486  ...  0.448532        0.000100  0.001690  0.053585
# 39   (109617.12, 112379.2]   5714   0.928421    0.016276  ...  0.308314        0.008777  0.140219  0.053585
# 40   (112379.2, 115141.28]   3218   0.949037    0.009167  ...  0.669965        0.020615  0.361651  0.053585
# 41  (115141.28, 117903.36]   1128   0.934397    0.003213  ...  0.401906        0.014640  0.268058  0.053585
# 42  (117903.36, 120665.44]   6228   0.929351    0.017741  ...  0.322391        0.005046  0.079515  0.053585
# 43  (120665.44, 123427.52]   1043   0.950144    0.002971  ...  0.693094        0.020792  0.370703  0.053585
# 44   (123427.52, 126189.6]   3566   0.935782    0.010158  ...  0.424729        0.014361  0.268365  0.053585
# 45   (126189.6, 128951.68]    791   0.929204    0.002253  ...  0.320142        0.006579  0.104587  0.053585
# 46  (128951.68, 131713.76]   3033   0.943950    0.008640  ...  0.569451        0.014746  0.249308  0.053585
# 47  (131713.76, 134475.84]    801   0.930087    0.002282  ...  0.333656        0.013862  0.235794  0.053585
# 48  (134475.84, 137237.92]   1902   0.953733    0.005418  ...  0.771576        0.023646  0.437920  0.053585
# 49   (137237.92, 140000.0]   2532   0.938784    0.007212  ...  0.475793        0.014949  0.295783  0.053585
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp, 90)

# %%
df_inputs_prep['annual_inc:<20K'] = np.where((df_inputs_prep['annual_inc'] <= 20000), 1, 0)
df_inputs_prep['annual_inc:20K-30K'] = np.where((df_inputs_prep['annual_inc'] > 20000) & (df_inputs_prep['annual_inc'] <= 30000), 1, 0)
df_inputs_prep['annual_inc:30K-40K'] = np.where((df_inputs_prep['annual_inc'] > 30000) & (df_inputs_prep['annual_inc'] <= 40000), 1, 0)
df_inputs_prep['annual_inc:40K-50K'] = np.where((df_inputs_prep['annual_inc'] > 40000) & (df_inputs_prep['annual_inc'] <= 50000), 1, 0)
df_inputs_prep['annual_inc:50K-60K'] = np.where((df_inputs_prep['annual_inc'] > 50000) & (df_inputs_prep['annual_inc'] <= 60000), 1, 0)
df_inputs_prep['annual_inc:60K-70K'] = np.where((df_inputs_prep['annual_inc'] > 60000) & (df_inputs_prep['annual_inc'] <= 70000), 1, 0)
df_inputs_prep['annual_inc:70K-80K'] = np.where((df_inputs_prep['annual_inc'] > 70000) & (df_inputs_prep['annual_inc'] <= 80000), 1, 0)
df_inputs_prep['annual_inc:80K-90K'] = np.where((df_inputs_prep['annual_inc'] > 80000) & (df_inputs_prep['annual_inc'] <= 90000), 1, 0)
df_inputs_prep['annual_inc:90K-100K'] = np.where((df_inputs_prep['annual_inc'] > 90000) & (df_inputs_prep['annual_inc'] <= 100000), 1, 0)
df_inputs_prep['annual_inc:100K-120K'] = np.where((df_inputs_prep['annual_inc'] > 100000) & (df_inputs_prep['annual_inc'] <= 120000), 1, 0)
df_inputs_prep['annual_inc:120K-140K'] = np.where((df_inputs_prep['annual_inc'] > 120000) & (df_inputs_prep['annual_inc'] <= 140000), 1, 0)
df_inputs_prep['annual_inc:>140K'] = np.where((df_inputs_prep['annual_inc'] > 140000), 1, 0)

# %%
# Create a category for missing values and do fine and coarse classing for the rest.
df_inputs_prep_temp = df_inputs_prep[pd.notnull(df_inputs_prep['mths_since_last_delinq'])] #store not nulls in a temp
df_inputs_prep_temp['mths_since_last_delinq_factor'] = pd.cut(df_inputs_prep_temp['mths_since_last_delinq'], 50) #fine classing
df_temp = woe_ordered_continuous(df_inputs_prep_temp, 'mths_since_last_delinq_factor', df_targets_prep[df_inputs_prep_temp.index])
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\319674983.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_inputs_prep_temp['mths_since_last_delinq_factor'] = pd.cut(df_inputs_prep_temp['mths_since_last_delinq'], 50) #fine classing
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\319674983.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inputs_prep_temp['mths_since_last_delinq_factor'] = pd.cut(df_inputs_prep_temp['mths_since_last_delinq'], 50) #fine classing
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#    mths_since_last_delinq_factor  n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE   IV
# 0                 (-0.188, 3.76]   5277   0.910745    0.030531  ... -0.007006             NaN       NaN  inf
# 1                   (3.76, 7.52]  11167   0.907943    0.064608  ... -0.040994        0.002802  0.033988  inf
# 2                  (7.52, 11.28]  13306   0.912596    0.076983  ...  0.015982        0.004653  0.056976  inf
# 3                 (11.28, 15.04]  13216   0.908520    0.076462  ... -0.034072        0.004076  0.050054  inf
# 4                  (15.04, 18.8]   9337   0.912713    0.054020  ...  0.017450        0.004193  0.051522  inf
# 5                  (18.8, 22.56]  11641   0.912379    0.067350  ...  0.013263        0.000334  0.004188  inf
# 6                 (22.56, 26.32]  10887   0.913199    0.062988  ...  0.023571        0.000821  0.010308  inf
# 7                 (26.32, 30.08]  10560   0.913068    0.061096  ...  0.021919        0.000131  0.001652  inf
# 8                 (30.08, 33.84]   7576   0.918955    0.043832  ...  0.098459        0.005886  0.076541  inf
# 9                  (33.84, 37.6]   9795   0.915467    0.056670  ...  0.052525        0.003488  0.045934  inf
# 10                 (37.6, 41.36]   9352   0.907934    0.054107  ... -0.041100        0.007533  0.093626  inf
# 11                (41.36, 45.12]   9202   0.912628    0.053239  ...  0.016382        0.004694  0.057482  inf
# 12                (45.12, 48.88]   6538   0.915418    0.037826  ...  0.051886        0.002790  0.035504  inf
# 13                (48.88, 52.64]   6486   0.907493    0.037525  ... -0.046366        0.007924  0.098251  inf
# 14                 (52.64, 56.4]   6045   0.911001    0.034974  ... -0.003851        0.003508  0.042514  inf
# 15                 (56.4, 60.16]   5867   0.917164    0.033944  ...  0.074653        0.006163  0.078504  inf
# 16                (60.16, 63.92]   4040   0.904950    0.023374  ... -0.076286        0.012213  0.150939  inf
# 17                (63.92, 67.68]   5314   0.910802    0.030745  ... -0.006305        0.005851  0.069980  inf
# 18                (67.68, 71.44]   5141   0.908578    0.029744  ... -0.033372        0.002224  0.027067  inf
# 19                 (71.44, 75.2]   4950   0.904040    0.028639  ... -0.086821        0.004538  0.053449  inf
# 20                 (75.2, 78.96]   3312   0.912138    0.019162  ...  0.010252        0.008097  0.097073  inf
# 21                (78.96, 82.72]   3577   0.903271    0.020695  ... -0.095660        0.008867  0.105912  inf
# 22                (82.72, 86.48]     94   0.829787    0.000544  ... -0.745648        0.073484  0.649988  inf
# 23                (86.48, 90.24]     38   0.894737    0.000220  ... -0.189702        0.064950  0.555946  inf
# 24                 (90.24, 94.0]     32   0.937500    0.000185  ...  0.378282        0.042763  0.567984  inf
# 25                 (94.0, 97.76]     20   0.750000    0.000116  ... -1.231156        0.187500  1.609438  inf
# 26               (97.76, 101.52]     13   0.923077    0.000075  ...  0.155139        0.173077  1.386294  inf
# 27              (101.52, 105.28]     11   0.909091    0.000064  ... -0.027183        0.013986  0.182322  inf
# 28              (105.28, 109.04]      8   0.750000    0.000046  ... -1.231156        0.159091  1.203973  inf
# 29               (109.04, 112.8]      2   0.500000    0.000012  ... -2.329768        0.250000  1.098612  inf
# 30               (112.8, 116.56]      7   0.857143    0.000040  ... -0.538008        0.357143  1.791759  inf
# 31              (116.56, 120.32]      2   1.000000    0.000012  ...       inf        0.142857       inf  inf
# 32              (120.32, 124.08]      1   1.000000    0.000006  ...       inf        0.000000       NaN  inf
# 33              (124.08, 127.84]      2   1.000000    0.000012  ...       inf        0.000000       NaN  inf
# 34               (127.84, 131.6]      5   1.000000    0.000029  ...       inf        0.000000       NaN  inf
# 35               (131.6, 135.36]      7   0.857143    0.000040  ... -0.538008        0.142857       inf  inf
# 36              (135.36, 139.12]      2   1.000000    0.000012  ...       inf        0.142857       inf  inf
# 37              (139.12, 142.88]      3   1.000000    0.000017  ...       inf        0.000000       NaN  inf
# 38              (142.88, 146.64]      1   1.000000    0.000006  ...       inf        0.000000       NaN  inf
# 39               (146.64, 150.4]      3   0.666667    0.000017  ... -1.636621        0.333333       inf  inf
# 40               (150.4, 154.16]      2   0.500000    0.000012  ... -2.329768        0.166667  0.693147  inf
# 41              (154.16, 157.92]      1   1.000000    0.000006  ...       inf        0.500000       inf  inf
# 42              (157.92, 161.68]      1   1.000000    0.000006  ...       inf        0.000000       NaN  inf
# 43              (161.68, 165.44]      0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 44               (165.44, 169.2]      0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 45               (169.2, 172.96]      0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 46              (172.96, 176.72]      0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 47              (176.72, 180.48]      1   1.000000    0.000006  ...       inf             NaN       NaN  inf
# 48              (180.48, 184.24]      0        NaN    0.000000  ...       NaN             NaN       NaN  inf
# 49               (184.24, 188.0]      1   1.000000    0.000006  ...       inf             NaN       NaN  inf
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp, 90)

# %%
df_inputs_prep['mths_since_last_delinq:Missing'] = np.where((df_inputs_prep['mths_since_last_delinq'].isnull()), 1, 0)
df_inputs_prep['mths_since_last_delinq:0-3'] = np.where((df_inputs_prep['mths_since_last_delinq'] >= 0) & (df_inputs_prep['mths_since_last_delinq'] <= 3), 1, 0)
df_inputs_prep['mths_since_last_delinq:4-30'] = np.where((df_inputs_prep['mths_since_last_delinq'] >= 4) & (df_inputs_prep['mths_since_last_delinq'] <= 30), 1, 0)
df_inputs_prep['mths_since_last_delinq:31-56'] = np.where((df_inputs_prep['mths_since_last_delinq'] >= 31) & (df_inputs_prep['mths_since_last_delinq'] <= 56), 1, 0)
df_inputs_prep['mths_since_last_delinq:>=57'] = np.where((df_inputs_prep['mths_since_last_delinq'] >= 57), 1, 0)

# %%
df_inputs_prep['dti_factor'] = pd.cut(df_inputs_prep['dti'], 100)
df_temp = woe_ordered_continuous(df_inputs_prep, 'dti_factor', df_targets_prep)
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#           dti_factor  n_obs  prop_good  prop_n_obs  n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE      IV
# 0       (-0.04, 0.4]    745   0.895302    0.001997   667.0  ...    0.002250 -0.132308             NaN       NaN  0.0276
# 1         (0.4, 0.8]    808   0.925743    0.002166   748.0  ...    0.001731  0.244670        0.030441  0.376977  0.0276
# 2         (0.8, 1.2]    922   0.908894    0.002472   838.0  ...    0.002423  0.021813        0.016849  0.222857  0.0276
# 3         (1.2, 1.6]   1043   0.907958    0.002796   947.0  ...    0.002769  0.010562        0.000936  0.011250  0.0276
# 4         (1.6, 2.0]   1172   0.910410    0.003142  1067.0  ...    0.003029  0.040257        0.002452  0.029695  0.0276
# 5       (2.0, 2.399]   1337   0.931189    0.003584  1245.0  ...    0.002654  0.326713        0.020780  0.286456  0.0276
# 6     (2.399, 2.799]   1538   0.925878    0.004123  1424.0  ...    0.003289  0.246638        0.005311  0.080076  0.0276
# 7     (2.799, 3.199]   1696   0.920991    0.004547  1562.0  ...    0.003866  0.177494        0.004887  0.069144  0.0276
# 8     (3.199, 3.599]   1927   0.913337    0.005166  1760.0  ...    0.004818  0.076687        0.007654  0.100807  0.0276
# 9     (3.599, 3.999]   2197   0.929449    0.005890  2042.0  ...    0.004471  0.299871        0.016112  0.223185  0.0276
# 10    (3.999, 4.399]   2466   0.927007    0.006611  2286.0  ...    0.005193  0.263213        0.002442  0.036658  0.0276
# 11    (4.399, 4.799]   2571   0.927266    0.006892  2384.0  ...    0.005394  0.267038        0.000258  0.003824  0.0276
# 12    (4.799, 5.199]   2906   0.922574    0.007790  2681.0  ...    0.006491  0.199456        0.004692  0.067582  0.0276
# 13    (5.199, 5.599]   3083   0.922478    0.008265  2844.0  ...    0.006895  0.198114        0.000096  0.001341  0.0276
# 14    (5.599, 5.999]   3252   0.932964    0.008718  3034.0  ...    0.006289  0.354753        0.010486  0.156639  0.0276
# 15    (5.999, 6.398]   3529   0.923774    0.009460  3260.0  ...    0.007760  0.216382        0.009190  0.138371  0.0276
# 16    (6.398, 6.798]   3766   0.924854    0.010096  3483.0  ...    0.008164  0.231814        0.001080  0.015431  0.0276
# 17    (6.798, 7.198]   3899   0.927674    0.010452  3617.0  ...    0.008135  0.273104        0.002820  0.041291  0.0276
# 18    (7.198, 7.598]   4239   0.926398    0.011364  3927.0  ...    0.009000  0.254239        0.001276  0.018865  0.0276
# 19    (7.598, 7.998]   4508   0.927462    0.012085  4181.0  ...    0.009433  0.269957        0.001065  0.015718  0.0276
# 20    (7.998, 8.398]   4677   0.927304    0.012538  4337.0  ...    0.009808  0.267604        0.000158  0.002353  0.0276
# 21    (8.398, 8.798]   4895   0.925434    0.013122  4530.0  ...    0.010529  0.240191        0.001870  0.027413  0.0276
# 22    (8.798, 9.198]   5129   0.924352    0.013750  4741.0  ...    0.011193  0.224609        0.001082  0.015582  0.0276
# 23    (9.198, 9.598]   5191   0.919476    0.013916  4773.0  ...    0.012058  0.156860        0.004876  0.067749  0.0276
# 24    (9.598, 9.998]   5471   0.922683    0.014666  5048.0  ...    0.012203  0.200986        0.003207  0.044126  0.0276
# 25   (9.998, 10.397]   5621   0.920299    0.015069  5173.0  ...    0.012924  0.168026        0.002384  0.032960  0.0276
# 26  (10.397, 10.797]   5824   0.921360    0.015613  5366.0  ...    0.013212  0.182580        0.001061  0.014554  0.0276
# 27  (10.797, 11.197]   6116   0.911053    0.016396  5572.0  ...    0.015693  0.048171        0.010307  0.134409  0.0276
# 28  (11.197, 11.597]   6168   0.925097    0.016535  5706.0  ...    0.013328  0.235320        0.014044  0.187149  0.0276
# 29  (11.597, 11.997]   6303   0.917341    0.016897  5782.0  ...    0.015030  0.128366        0.007756  0.106954  0.0276
# 30  (11.997, 12.397]   6457   0.920861    0.017310  5946.0  ...    0.014741  0.175716        0.003520  0.047350  0.0276
# 31  (12.397, 12.797]   6789   0.911769    0.018200  6190.0  ...    0.017280  0.057040        0.009092  0.118676  0.0276
# 32  (12.797, 13.197]   6667   0.920504    0.017873  6137.0  ...    0.015289  0.170826        0.008735  0.113786  0.0276
# 33  (13.197, 13.597]   6769   0.914758    0.018146  6192.0  ...    0.016645  0.094782        0.005746  0.076043  0.0276
# 34  (13.597, 13.997]   6854   0.911439    0.018374  6247.0  ...    0.017510  0.052939        0.003320  0.041843  0.0276
# 35  (13.997, 14.396]   6855   0.915536    0.018377  6276.0  ...    0.016703  0.104797        0.004098  0.051858  0.0276
# 36  (14.396, 14.796]   7081   0.917243    0.018982  6495.0  ...    0.016905  0.127079        0.001707  0.022283  0.0276
# 37  (14.796, 15.196]   6964   0.914848    0.018669  6371.0  ...    0.017107  0.095929        0.002396  0.031151  0.0276
# 38  (15.196, 15.596]   6811   0.916018    0.018259  6239.0  ...    0.016501  0.111047        0.001170  0.015119  0.0276
# 39  (15.596, 15.996]   7059   0.909336    0.018924  6419.0  ...    0.018462  0.027161        0.006683  0.083887  0.0276
# 40  (15.996, 16.396]   6862   0.910230    0.018395  6246.0  ...    0.017770  0.038061        0.000895  0.010900  0.0276
# 41  (16.396, 16.796]   6873   0.906591    0.018425  6231.0  ...    0.018520 -0.005685        0.003639  0.043746  0.0276
# 42  (16.796, 17.196]   6958   0.903564    0.018653  6287.0  ...    0.019357 -0.040919        0.003027  0.035234  0.0276
# 43  (17.196, 17.596]   6752   0.907287    0.018101  6126.0  ...    0.018059  0.002558        0.003722  0.043477  0.0276
# 44  (17.596, 17.996]   6774   0.904931    0.018159  6130.0  ...    0.018578 -0.025137        0.002356  0.027696  0.0276
# 45  (17.996, 18.395]   6832   0.898712    0.018315  6140.0  ...    0.019962 -0.095395        0.006219  0.070257  0.0276
# 46  (18.395, 18.795]   6737   0.908416    0.018060  6120.0  ...    0.017799  0.016060        0.009704  0.111454  0.0276
# 47  (18.795, 19.195]   6472   0.898177    0.017350  5813.0  ...    0.019011 -0.101260        0.010239  0.117320  0.0276
# 48  (19.195, 19.595]   6613   0.900499    0.017728  5955.0  ...    0.018982 -0.075607        0.002322  0.025653  0.0276
# 49  (19.595, 19.995]   6570   0.901218    0.017613  5921.0  ...    0.018722 -0.067561        0.000719  0.008046  0.0276
# 50  (19.995, 20.395]   6236   0.901700    0.016717  5623.0  ...    0.017684 -0.062133        0.000482  0.005428  0.0276
# 51  (20.395, 20.795]   6199   0.897080    0.016618  5561.0  ...    0.018405 -0.113194        0.004620  0.051061  0.0276
# 52  (20.795, 21.195]   5981   0.889483    0.016034  5320.0  ...    0.019068 -0.192914        0.007597  0.079720  0.0276
# 53  (21.195, 21.595]   5921   0.901537    0.015873  5338.0  ...    0.016818 -0.063970        0.012054  0.128944  0.0276
# 54  (21.595, 21.995]   5793   0.896081    0.015530  5191.0  ...    0.017366 -0.123965        0.005455  0.059995  0.0276
# 55  (21.995, 22.394]   5510   0.893103    0.014771  4921.0  ...    0.016991 -0.155548        0.002978  0.031583  0.0276
# 56  (22.394, 22.794]   5476   0.896457    0.014680  4909.0  ...    0.016357 -0.119923        0.003354  0.035625  0.0276
# 57  (22.794, 23.194]   5537   0.889290    0.014843  4924.0  ...    0.017684 -0.194877        0.007167  0.074955  0.0276
# 58  (23.194, 23.594]   5256   0.895167    0.014090  4705.0  ...    0.015895 -0.133743        0.005877  0.061135  0.0276
# 59  (23.594, 23.994]   4973   0.892017    0.013331  4436.0  ...    0.015491 -0.166878        0.003151  0.033136  0.0276
# 60  (23.994, 24.394]   5036   0.892971    0.013500  4497.0  ...    0.015549 -0.156939        0.000954  0.009940  0.0276
# 61  (24.394, 24.794]   4886   0.883135    0.013098  4315.0  ...    0.016472 -0.255925        0.009835  0.098987  0.0276
# 62  (24.794, 25.194]   4485   0.894314    0.012023  4011.0  ...    0.013674 -0.142800        0.011179  0.113125  0.0276
# 63  (25.194, 25.594]   4081   0.896594    0.010940  3659.0  ...    0.012174 -0.118449        0.002280  0.024351  0.0276
# 64  (25.594, 25.994]   3922   0.897246    0.010514  3519.0  ...    0.011626 -0.111393        0.000652  0.007056  0.0276
# 65  (25.994, 26.393]   3855   0.892348    0.010334  3440.0  ...    0.011972 -0.163441        0.004899  0.052047  0.0276
# 66  (26.393, 26.793]   3766   0.891662    0.010096  3358.0  ...    0.011770 -0.170555        0.000685  0.007115  0.0276
# 67  (26.793, 27.193]   3485   0.888379    0.009342  3096.0  ...    0.011222 -0.204102        0.003283  0.033547  0.0276
# 68  (27.193, 27.593]   3336   0.882494    0.008943  2944.0  ...    0.011308 -0.262126        0.005885  0.058024  0.0276
# 69  (27.593, 27.993]   3291   0.888484    0.008822  2924.0  ...    0.010587 -0.203043        0.005990  0.059083  0.0276
# 70  (27.993, 28.393]   3285   0.887062    0.008806  2914.0  ...    0.010702 -0.217309        0.001421  0.014266  0.0276
# 71  (28.393, 28.793]   3076   0.891092    0.008246  2741.0  ...    0.009664 -0.176441        0.004030  0.040868  0.0276
# 72  (28.793, 29.193]   2967   0.885743    0.007954  2628.0  ...    0.009779 -0.230410        0.005349  0.053969  0.0276
# 73  (29.193, 29.593]   2818   0.887864    0.007554  2502.0  ...    0.009116 -0.209285        0.002121  0.021125  0.0276
# 74  (29.593, 29.993]   2667   0.883390    0.007150  2356.0  ...    0.008972 -0.253461        0.004474  0.044176  0.0276
# 75  (29.993, 30.392]   2038   0.888126    0.005463  1810.0  ...    0.006577 -0.206652        0.004736  0.046809  0.0276
# 76  (30.392, 30.792]   1919   0.881709    0.005144  1692.0  ...    0.006548 -0.269672        0.006416  0.063020  0.0276
# 77  (30.792, 31.192]   1933   0.888774    0.005182  1718.0  ...    0.006202 -0.200111        0.007065  0.069562  0.0276
# 78  (31.192, 31.592]   1797   0.885921    0.004817  1592.0  ...    0.005914 -0.228652        0.002853  0.028542  0.0276
# 79  (31.592, 31.992]   1713   0.900175    0.004592  1542.0  ...    0.004933 -0.079217        0.014254  0.149436  0.0276
# 80  (31.992, 32.392]   1542   0.877432    0.004134  1353.0  ...    0.005452 -0.310056        0.022743  0.230839  0.0276
# 81  (32.392, 32.792]   1499   0.893262    0.004018  1339.0  ...    0.004616 -0.153884        0.015830  0.156172  0.0276
# 82  (32.792, 33.192]   1475   0.892881    0.003954  1317.0  ...    0.004558 -0.157872        0.000381  0.003988  0.0276
# 83  (33.192, 33.592]   1336   0.882485    0.003582  1179.0  ...    0.004529 -0.262213        0.010396  0.104341  0.0276
# 84  (33.592, 33.992]   1389   0.886969    0.003724  1232.0  ...    0.004529 -0.218240        0.004484  0.043972  0.0276
# 85  (33.992, 34.391]   1203   0.890274    0.003225  1071.0  ...    0.003808 -0.184843        0.003305  0.033398  0.0276
# 86  (34.391, 34.791]   1174   0.885009    0.003147  1039.0  ...    0.003894 -0.237650        0.005266  0.052807  0.0276
# 87  (34.791, 35.191]    668   0.878743    0.001791   587.0  ...    0.002337 -0.297813        0.006266  0.060164  0.0276
# 88  (35.191, 35.591]    247   0.935223    0.000662   231.0  ...    0.000462  0.391440        0.056480  0.689253  0.0276
# 89  (35.591, 35.991]    283   0.932862    0.000759   264.0  ...    0.000548  0.353121        0.002360  0.038319  0.0276
# 90  (35.991, 36.391]    290   0.937931    0.000777   272.0  ...    0.000519  0.437042        0.005069  0.083920  0.0276
# 91  (36.391, 36.791]    249   0.911647    0.000668   227.0  ...    0.000635  0.055519        0.026284  0.381523  0.0276
# 92  (36.791, 37.191]    247   0.894737    0.000662   221.0  ...    0.000750 -0.138323        0.016910  0.193841  0.0276
# 93  (37.191, 37.591]    244   0.934426    0.000654   228.0  ...    0.000462  0.378368        0.039689  0.516691  0.0276
# 94  (37.591, 37.991]    240   0.966667    0.000643   232.0  ...    0.000231  1.088907        0.032240  0.710539  0.0276
# 95   (37.991, 38.39]    202   0.896040    0.000542   181.0  ...    0.000606 -0.124414        0.070627  1.213321  0.0276
# 96    (38.39, 38.79]    193   0.927461    0.000517   179.0  ...    0.000404  0.269940        0.031422  0.394354  0.0276
# 97    (38.79, 39.19]    192   0.911458    0.000515   175.0  ...    0.000490  0.053184        0.016003  0.216756  0.0276
# 98    (39.19, 39.59]    183   0.945355    0.000491   173.0  ...    0.000288  0.572318        0.033897  0.519134  0.0276
# 99    (39.59, 39.99]    186   0.919355    0.000499   171.0  ...    0.000433  0.155225        0.026000  0.417093  0.0276
#
# [100 rows x 12 columns]

# %%
plot_by_woe(df_temp, 90)

# %%
df_inputs_prep_temp = df_inputs_prep.loc[df_inputs_prep['dti'] <= 35, : ] #leave out the last part for better visualization

# %%
df_inputs_prep_temp['dti_factor'] = pd.cut(df_inputs_prep_temp['dti'], 50)
df_temp = woe_ordered_continuous(df_inputs_prep_temp, 'dti_factor', df_targets_prep[df_inputs_prep_temp.index])
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\1452516224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inputs_prep_temp['dti_factor'] = pd.cut(df_inputs_prep_temp['dti'], 50)
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#        dti_factor  n_obs  prop_good  prop_n_obs   n_good  ...  prop_n_bad       WoE  diff_prop_good  diff_WoE        IV
# 0   (-0.035, 0.7]   1366   0.908492    0.003690   1241.0  ...    0.003628  0.018758             NaN       NaN  0.025455
# 1      (0.7, 1.4]   1664   0.905048    0.004496   1506.0  ...    0.004586 -0.021984        0.003444  0.040742  0.025455
# 2      (1.4, 2.1]   1986   0.921450    0.005365   1830.0  ...    0.004528  0.185614        0.016402  0.207598  0.025455
# 3      (2.1, 2.8]   2594   0.924441    0.007008   2398.0  ...    0.005689  0.227675        0.002991  0.042060  0.025455
# 4      (2.8, 3.5]   3135   0.917384    0.008470   2876.0  ...    0.007517  0.130727        0.007057  0.096948  0.025455
# 5      (3.5, 4.2]   3844   0.929240    0.010385   3572.0  ...    0.007895  0.298478        0.011856  0.167751  0.025455
# 6      (4.2, 4.9]   4595   0.924483    0.012414   4248.0  ...    0.010072  0.228278        0.004757  0.070200  0.025455
# 7      (4.9, 5.6]   5312   0.923381    0.014351   4905.0  ...    0.011813  0.212596        0.001102  0.015682  0.025455
# 8      (5.6, 6.3]   5927   0.927619    0.016013   5498.0  ...    0.012452  0.274082        0.004238  0.061486  0.025455
# 9      (6.3, 7.0]   6482   0.924560    0.017512   5993.0  ...    0.014193  0.229384        0.003059  0.044698  0.025455
# 10     (7.0, 7.7]   7256   0.928611    0.019603   6738.0  ...    0.015035  0.288942        0.004050  0.059558  0.025455
# 11     (7.7, 8.4]   8120   0.927217    0.021937   7529.0  ...    0.017154  0.268101        0.001394  0.020842  0.025455
# 12     (8.4, 9.1]   8817   0.924464    0.023820   8151.0  ...    0.019331  0.228005        0.002753  0.040095  0.025455
# 13     (9.1, 9.8]   9194   0.921253    0.024839   8470.0  ...    0.021014  0.182893        0.003211  0.045112  0.025455
# 14    (9.8, 10.5]   9888   0.922128    0.026714   9118.0  ...    0.022349  0.195014        0.000875  0.012121  0.025455
# 15   (10.5, 11.2]  10483   0.914147    0.028321   9583.0  ...    0.026123  0.088750        0.007981  0.106264  0.025455
# 16   (11.2, 11.9]  10774   0.922406    0.029107   9938.0  ...    0.024265  0.198891        0.008259  0.110141  0.025455
# 17   (11.9, 12.6]  11566   0.916566    0.031247  10601.0  ...    0.028009  0.119975        0.005840  0.078917  0.025455
# 18   (12.6, 13.3]  11670   0.916710    0.031528  10698.0  ...    0.028212  0.121855        0.000144  0.001881  0.025455
# 19   (13.3, 14.0]  12043   0.913560    0.032536  11002.0  ...    0.030215  0.081294        0.003150  0.040561  0.025455
# 20   (14.0, 14.7]  12212   0.917213    0.032992  11201.0  ...    0.029344  0.128462        0.003653  0.047168  0.025455
# 21   (14.7, 15.4]  11941   0.914329    0.032260  10918.0  ...    0.029693  0.091072        0.002884  0.037390  0.025455
# 22   (15.4, 16.1]  12117   0.912932    0.032736  11062.0  ...    0.030621  0.073374        0.001397  0.017698  0.025455
# 23   (16.1, 16.8]  12054   0.907417    0.032566  10938.0  ...    0.032392  0.005891        0.005516  0.067483  0.025455
# 24   (16.8, 17.5]  12222   0.904680    0.033019  11057.0  ...    0.033814 -0.026258        0.002737  0.032149  0.025455
# 25   (17.5, 18.2]  11921   0.907306    0.032206  10816.0  ...    0.032073  0.004580        0.002626  0.030839  0.025455
# 26   (18.2, 18.9]  11753   0.899345    0.031752  10570.0  ...    0.034337 -0.086635        0.007962  0.091215  0.025455
# 27   (18.9, 19.6]  11242   0.900907    0.030372  10128.0  ...    0.032334 -0.069254        0.001562  0.017381  0.025455
# 28   (19.6, 20.3]  11286   0.900230    0.030491  10160.0  ...    0.032682 -0.076814        0.000677  0.007560  0.025455
# 29   (20.3, 21.0]  10987   0.897697    0.029683   9863.0  ...    0.032624 -0.104704        0.002533  0.027890  0.025455
# 30   (21.0, 21.7]  10285   0.896062    0.027786   9216.0  ...    0.031028 -0.122384        0.001635  0.017679  0.025455
# 31   (21.7, 22.4]   9797   0.895376    0.026468   8772.0  ...    0.029751 -0.129729        0.000686  0.007345  0.025455
# 32   (22.4, 23.1]   9475   0.893509    0.025598   8466.0  ...    0.029286 -0.149503        0.001867  0.019774  0.025455
# 33   (23.1, 23.8]   9229   0.893488    0.024933   8246.0  ...    0.028532 -0.149727        0.000021  0.000224  0.025455
# 34   (23.8, 24.5]   8858   0.890607    0.023931   7889.0  ...    0.028125 -0.179641        0.002881  0.029914  0.025455
# 35   (24.5, 25.2]   8115   0.888232    0.021924   7208.0  ...    0.026326 -0.203797        0.002376  0.024156  0.025455
# 36   (25.2, 25.9]   6944   0.897177    0.018760   6230.0  ...    0.020724 -0.110352        0.008946  0.093444  0.025455
# 37   (25.9, 26.6]   6676   0.892301    0.018036   5957.0  ...    0.020869 -0.162140        0.004877  0.051788  0.025455
# 38   (26.6, 27.3]   6168   0.890726    0.016664   5494.0  ...    0.019563 -0.178419        0.001574  0.016279  0.025455
# 39   (27.3, 28.0]   5865   0.884910    0.015845   5190.0  ...    0.019592 -0.236825        0.005816  0.058405  0.025455
# 40   (28.0, 28.7]   5588   0.890122    0.015097   4974.0  ...    0.017821 -0.184616        0.005211  0.052208  0.025455
# 41   (28.7, 29.4]   5119   0.885915    0.013830   4535.0  ...    0.016951 -0.226922        0.004206  0.042305  0.025455
# 42   (29.4, 30.1]   4522   0.883680    0.012217   3996.0  ...    0.015267 -0.248853        0.002235  0.021931  0.025455
# 43   (30.1, 30.8]   3451   0.886410    0.009323   3059.0  ...    0.011378 -0.222019        0.002730  0.026834  0.025455
# 44   (30.8, 31.5]   3295   0.887102    0.008902   2923.0  ...    0.010797 -0.215129        0.000692  0.006890  0.025455
# 45   (31.5, 32.2]   2945   0.893039    0.007956   2630.0  ...    0.009143 -0.154434        0.005937  0.060695  0.025455
# 46   (32.2, 32.9]   2617   0.886893    0.007070   2321.0  ...    0.008591 -0.217207        0.006146  0.062773  0.025455
# 47   (32.9, 33.6]   2438   0.888433    0.006587   2166.0  ...    0.007895 -0.201766        0.001540  0.015441  0.025455
# 48   (33.6, 34.3]   2321   0.888841    0.006270   2063.0  ...    0.007488 -0.197644        0.000408  0.004122  0.025455
# 49   (34.3, 35.0]   1987   0.880725    0.005368   1750.0  ...    0.006879 -0.277290        0.008116  0.079646  0.025455
#
# [50 rows x 12 columns]

# %%
plot_by_woe(df_temp, 90)

# %%
df_inputs_prep['dti:<=1.4'] = np.where((df_inputs_prep['dti'] <= 1.4), 1, 0)
df_inputs_prep['dti:1.4-3.5'] = np.where((df_inputs_prep['dti'] > 1.4) & (df_inputs_prep['dti'] <= 3.5), 1, 0)
df_inputs_prep['dti:3.5-7.7'] = np.where((df_inputs_prep['dti'] > 3.5) & (df_inputs_prep['dti'] <= 7.7), 1, 0)
df_inputs_prep['dti:7.7-10.5'] = np.where((df_inputs_prep['dti'] > 7.7) & (df_inputs_prep['dti'] <= 10.5), 1, 0)
df_inputs_prep['dti:10.5-16.1'] = np.where((df_inputs_prep['dti'] > 10.5) & (df_inputs_prep['dti'] <= 16.1), 1, 0)
df_inputs_prep['dti:16.1-20.3'] = np.where((df_inputs_prep['dti'] > 16.1) & (df_inputs_prep['dti'] <= 20.3), 1, 0)
df_inputs_prep['dti:20.3-21.7'] = np.where((df_inputs_prep['dti'] > 20.3) & (df_inputs_prep['dti'] <= 21.7), 1, 0)
df_inputs_prep['dti:21.7-22.4'] = np.where((df_inputs_prep['dti'] > 21.7) & (df_inputs_prep['dti'] <= 22.4), 1, 0)
df_inputs_prep['dti:22.4-35'] = np.where((df_inputs_prep['dti'] > 22.4) & (df_inputs_prep['dti'] <= 35), 1, 0)
df_inputs_prep['dti:>35'] = np.where((df_inputs_prep['dti'] > 35), 1, 0)

# %%
# create a category for null values
df_inputs_prep_temp = df_inputs_prep[pd.notnull(df_inputs_prep['mths_since_last_record'])]
df_inputs_prep_temp['mths_since_last_record_factor'] = pd.cut(df_inputs_prep_temp['mths_since_last_record'], 25)
df_temp = woe_ordered_continuous(df_inputs_prep_temp, 'mths_since_last_record_factor', df_targets_prep[df_inputs_prep_temp.index])
df_temp
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\1725153943.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_inputs_prep_temp['mths_since_last_record_factor'] = pd.cut(df_inputs_prep_temp['mths_since_last_record'], 25)
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\1725153943.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inputs_prep_temp['mths_since_last_record_factor'] = pd.cut(df_inputs_prep_temp['mths_since_last_record'], 25)
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = pd.concat([df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].count(), #groups by categories in the first column and count them
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\251026891.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df.columns.values[0], as_index=False)[df.columns.values[1]].mean()], axis=1) #groups and gets the mean
#    mths_since_last_record_factor  n_obs  prop_good  prop_n_obs  ...       WoE  diff_prop_good  diff_WoE        IV
# 0                 (-0.121, 4.84]   1162   0.919966    0.023209  ...  0.062342             NaN       NaN  0.066647
# 1                   (4.84, 9.68]    319   0.934169    0.006371  ...  0.273034        0.014204  0.210692  0.066647
# 2                  (9.68, 14.52]    499   0.929860    0.009967  ...  0.204999        0.004310  0.068035  0.066647
# 3                 (14.52, 19.36]    544   0.931985    0.010865  ...  0.238056        0.002126  0.033057  0.066647
# 4                  (19.36, 24.2]    738   0.929539    0.014740  ...  0.200097        0.002446  0.037959  0.066647
# 5                  (24.2, 29.04]    951   0.921136    0.018995  ...  0.078341        0.008404  0.121756  0.066647
# 6                 (29.04, 33.88]    938   0.934968    0.018735  ...  0.286096        0.013832  0.207755  0.066647
# 7                 (33.88, 38.72]   1439   0.942321    0.028741  ...  0.413916        0.007353  0.127821  0.066647
# 8                 (38.72, 43.56]   1820   0.945604    0.036351  ...  0.476004        0.003283  0.062087  0.066647
# 9                  (43.56, 48.4]   2107   0.942098    0.042084  ...  0.409816        0.003507  0.066188  0.066647
# 10                 (48.4, 53.24]   2481   0.933091    0.049554  ...  0.255640        0.009006  0.154176  0.066647
# 11                (53.24, 58.08]   2724   0.937225    0.054407  ...  0.323823        0.004133  0.068184  0.066647
# 12                (58.08, 62.92]   2308   0.926776    0.046098  ...  0.158658        0.010448  0.165166  0.066647
# 13                (62.92, 67.76]   2719   0.934167    0.054307  ...  0.272996        0.007391  0.114339  0.066647
# 14                 (67.76, 72.6]   2554   0.929522    0.051012  ...  0.199837        0.004645  0.073159  0.066647
# 15                 (72.6, 77.44]   2366   0.914624    0.047257  ... -0.008091        0.014898  0.207929  0.066647
# 16                (77.44, 82.28]   2290   0.917467    0.045739  ...  0.028884        0.002843  0.036976  0.066647
# 17                (82.28, 87.12]   2074   0.891514    0.041424  ... -0.273238        0.025953  0.302122  0.066647
# 18                (87.12, 91.96]   1726   0.884705    0.034474  ... -0.341782        0.006809  0.068544  0.066647
# 19                 (91.96, 96.8]   2637   0.874099    0.052669  ... -0.441836        0.010605  0.100054  0.066647
# 20                (96.8, 101.64]   3079   0.895096    0.061498  ... -0.235654        0.020996  0.206182  0.066647
# 21              (101.64, 106.48]   3632   0.900055    0.072543  ... -0.181701        0.004959  0.053953  0.066647
# 22              (106.48, 111.32]   3855   0.905837    0.076997  ... -0.115710        0.005782  0.065991  0.066647
# 23              (111.32, 116.16]   3498   0.896226    0.069866  ... -0.223556        0.009610  0.107845  0.066647
# 24               (116.16, 121.0]   1607   0.912259    0.032097  ... -0.038004        0.016032  0.185551  0.066647
#
# [25 rows x 12 columns]

# %%
plot_by_woe(df_temp, 90)

# %%
df_inputs_prep['mths_since_last_record:Missing'] = np.where((df_inputs_prep['mths_since_last_record'].isnull()), 1, 0)
df_inputs_prep['mths_since_last_record:0-2'] = np.where((df_inputs_prep['mths_since_last_record'] >= 0) & (df_inputs_prep['mths_since_last_record'] <= 2), 1, 0)
df_inputs_prep['mths_since_last_record:3-20'] = np.where((df_inputs_prep['mths_since_last_record'] >= 3) & (df_inputs_prep['mths_since_last_record'] <= 20), 1, 0)
df_inputs_prep['mths_since_last_record:21-31'] = np.where((df_inputs_prep['mths_since_last_record'] >= 21) & (df_inputs_prep['mths_since_last_record'] <= 31), 1, 0)
df_inputs_prep['mths_since_last_record:32-80'] = np.where((df_inputs_prep['mths_since_last_record'] >= 32) & (df_inputs_prep['mths_since_last_record'] <= 80), 1, 0)
df_inputs_prep['mths_since_last_record:81-86'] = np.where((df_inputs_prep['mths_since_last_record'] >= 81) & (df_inputs_prep['mths_since_last_record'] <= 86), 1, 0)
df_inputs_prep['mths_since_last_record:>86'] = np.where((df_inputs_prep['mths_since_last_record'] > 86), 1, 0)
# Out:
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\673684153.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_inputs_prep['mths_since_last_record:0-2'] = np.where((df_inputs_prep['mths_since_last_record'] >= 0) & (df_inputs_prep['mths_since_last_record'] <= 2), 1, 0)
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\673684153.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_inputs_prep['mths_since_last_record:3-20'] = np.where((df_inputs_prep['mths_since_last_record'] >= 3) & (df_inputs_prep['mths_since_last_record'] <= 20), 1, 0)
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\673684153.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_inputs_prep['mths_since_last_record:21-31'] = np.where((df_inputs_prep['mths_since_last_record'] >= 21) & (df_inputs_prep['mths_since_last_record'] <= 31), 1, 0)
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\673684153.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_inputs_prep['mths_since_last_record:32-80'] = np.where((df_inputs_prep['mths_since_last_record'] >= 32) & (df_inputs_prep['mths_since_last_record'] <= 80), 1, 0)
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\673684153.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_inputs_prep['mths_since_last_record:81-86'] = np.where((df_inputs_prep['mths_since_last_record'] >= 81) & (df_inputs_prep['mths_since_last_record'] <= 86), 1, 0)
# C:\Users\Isildil\AppData\Local\Temp\ipykernel_42000\673684153.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_inputs_prep['mths_since_last_record:>86'] = np.where((df_inputs_prep['mths_since_last_record'] > 86), 1, 0)

# %% [markdown]
# ## Preprocesing the Test Dataset

# %%
loan_data_inputs_train = df_inputs_prep
