# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the data and selecting features

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv', index_col=0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv', index_col=0)
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv', index_col=0)
loan_data_targets_test = pd.read_csv('loan_data_targets_test.csv', index_col=0, header = None)

# %%
loan_data_inputs_train.head()
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 427211      427211  12796369   14818505      24000        24000
# 206088      206088   1439740    1691948      10000        10000
# 136020      136020   5214749    6556909      20425        20425
# 412305      412305  13827698   15890016      17200        17200
# 36159        36159    422455     496525       8400         8400
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 427211          24000.0   36 months      8.90       762.08     A  ...
# 206088          10000.0   36 months     14.33       343.39     C  ...
# 136020          20425.0   36 months      8.90       648.56     A  ...
# 412305          17200.0   36 months     16.59       609.73     D  ...
# 36159            7450.0   36 months     12.84       282.40     C  ...
#
#        dti:21.7-22.4 dti:22.4-35 dti:>35 mths_since_last_record:Missing  \
# 427211             1           0       0                              1
# 206088             0           0       0                              1
# 136020             0           0       0                              1
# 412305             0           0       0                              1
# 36159              0           1       0                              1
#
#         mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 427211                           0                           0
# 206088                           0                           0
# 136020                           0                           0
# 412305                           0                           0
# 36159                            0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>=86
# 427211                            0                           0
# 206088                            0                           0
# 136020                            0                           0
# 412305                            0                           0
# 36159                             0                           0
#
# [5 rows x 328 columns]

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         1
# 36159          0

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_NV_FL_AL_NM_HI_KY',
'addr_state:NH_WY_WV_MS_DC_ME_ID',
'addr_state:CA',
'addr_state:NY',
'addr_state:MO_VA_UT_NC',
'addr_state:OK_NJ_LA_MD',
'addr_state:MN_MI_AZ_TN_AR_OH',
'addr_state:DE_PA_WA_IN_MA',
'addr_state:OR_RI_GA_SD_WI',
'addr_state:CT_KS',
'addr_state:TX_IL',
'addr_state:IA_SC_CO_MT_VT_AK',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:renewable_energy__small_business__educational',
'purpose:house__medical__wedding__other',
'purpose:moving__vacation',
'purpose:debt_consolidation',
'purpose:major_purchase__home_improvement__car',
'purpose:credit_card',                                                          
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.745',
'int_rate:15.745-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<94',
'mths_since_earliest_cr_line:94-154',
'mths_since_earliest_cr_line:154-216',
'mths_since_earliest_cr_line:216-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:<4',
'open_acc:4-7',
'open_acc:8-10',
'open_acc:11-15',
'open_acc:16-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86',
]]

# %%
ref_categories=['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_NV_FL_AL_NM_HI_KY',
'verification_status:Verified',
'purpose:renewable_energy__small_business__educational',                                                           
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<94',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:<4',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train= inputs_train_with_ref_cat.drop(ref_categories,axis=1)
inputs_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 373028 entries, 427211 to 121958
# Columns: 103 entries, grade:A to mths_since_last_record:>=86
# dtypes: bool(10), int64(93)
# memory usage: 271.1 MB

# %% [markdown]
# # PD Model Estimation

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
pd.options.display.max_rows=None

# %%
inputs_train.shape
# Out:
# (373028, 103)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
reg.fit(inputs_train, loan_data_targets_train.values.ravel())
# Out:
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([0.29246551])

# %%
reg.coef_
# Out:
# array([[ 7.60024905e-01,  5.42127177e-01,  3.70581863e-01,
#          2.24076032e-01,  1.33669046e-01, -3.86488186e-02,
#          7.69259713e-02,  1.10014853e-01,  5.85161485e-01,
#          6.63278510e-02,  1.01383943e-01,  1.00507419e-01,
#          8.71947674e-02,  1.29710029e-01,  1.63507197e-01,
#          2.21025369e-01,  2.67669346e-01,  2.72453260e-01,
#          3.55124302e-01,  8.48184094e-02, -8.40719742e-03,
#          4.72563945e-01,  4.12463631e-01,  4.46074921e-01,
#          5.09875928e-01,  5.66722541e-01,  6.61470733e-02,
#          9.03060376e-02,  1.09932199e-01,  1.34958019e-01,
#          1.03168384e-01,  7.54722680e-02,  1.36341419e-01,
#          1.10048914e+00,  8.31254118e-01,  6.20697106e-01,
#          3.53493728e-01,  1.16783233e-01, -1.80521721e-01,
#         -3.01395899e-01,  1.06660563e+00,  7.30101072e-01,
#          4.83078618e-01,  2.26221685e-01,  4.18297627e-02,
#          3.84396688e-02,  6.39550806e-02,  1.38727353e-01,
#          1.19800620e-01,  1.83786627e-02, -4.56930499e-02,
#          5.24445110e-02, -9.23140919e-02, -2.37817781e-01,
#         -1.63110679e-02, -9.90135447e-02, -1.36735926e-01,
#         -1.16031590e-01, -9.48929717e-02, -4.43911745e-02,
#         -5.11749311e-02,  1.30554937e-01,  1.83411429e-02,
#         -2.93018496e-02, -2.11296417e-02,  8.33901626e-02,
#          2.01282621e-01,  1.84816594e-01,  2.09021202e-01,
#          2.22229121e-01,  2.30460338e-01,  2.72677045e-01,
#          4.36240315e-01, -1.99440645e-01, -1.47326564e-01,
#         -3.52157327e-02,  4.43072389e-02,  1.11031852e-01,
#          1.90422083e-01,  2.53955695e-01,  2.84935170e-01,
#          3.77064378e-01,  4.63459097e-01,  3.94160614e-01,
#          6.09571071e-03,  1.59034670e-01,  2.02459884e-01,
#          1.60412023e-01,  8.54638625e-02, -9.91074541e-04,
#         -3.66374188e-02, -4.28772609e-02, -1.00491440e-01,
#         -9.88987142e-02,  3.26273302e-02,  1.82686079e-02,
#         -3.34561541e-02, -1.05415484e-01,  1.13663965e-01,
#          4.58046166e-02,  1.12568605e-01, -1.29917553e-01,
#         -1.76428004e-01]])

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index+1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                                       Feature name  Coefficients
# 0                                        Intercept      0.292466
# 1                                          grade:A      0.760025
# 2                                          grade:B      0.542127
# 3                                          grade:C      0.370582
# 4                                          grade:D      0.224076
# 5                                          grade:E      0.133669
# 6                                          grade:F     -0.038649
# 7                               home_ownership:OWN      0.076926
# 8                          home_ownership:MORTGAGE      0.110015
# 9                  addr_state:NH_WY_WV_MS_DC_ME_ID      0.585161
# 10                                   addr_state:CA      0.066328
# 11                                   addr_state:NY      0.101384
# 12                          addr_state:MO_VA_UT_NC      0.100507
# 13                          addr_state:OK_NJ_LA_MD      0.087195
# 14                    addr_state:MN_MI_AZ_TN_AR_OH      0.129710
# 15                       addr_state:DE_PA_WA_IN_MA      0.163507
# 16                       addr_state:OR_RI_GA_SD_WI      0.221025
# 17                                addr_state:CT_KS      0.267669
# 18                                addr_state:TX_IL      0.272453
# 19                    addr_state:IA_SC_CO_MT_VT_AK      0.355124
# 20                verification_status:Not Verified      0.084818
# 21             verification_status:Source Verified     -0.008407
# 22          purpose:house__medical__wedding__other      0.472564
# 23                        purpose:moving__vacation      0.412464
# 24                      purpose:debt_consolidation      0.446075
# 25   purpose:major_purchase__home_improvement__car      0.509876
# 26                             purpose:credit_card      0.566723
# 27                           initial_list_status:w      0.066147
# 28                                         term:36      0.090306
# 29                                    emp_length:1      0.109932
# 30                                  emp_length:2-4      0.134958
# 31                                  emp_length:5-6      0.103168
# 32                                  emp_length:7-9      0.075472
# 33                                   emp_length:10      0.136341
# 34                          mths_since_issue_d:<38      1.100489
# 35                        mths_since_issue_d:38-39      0.831254
# 36                        mths_since_issue_d:40-41      0.620697
# 37                        mths_since_issue_d:42-48      0.353494
# 38                        mths_since_issue_d:49-52      0.116783
# 39                        mths_since_issue_d:53-64     -0.180522
# 40                        mths_since_issue_d:65-84     -0.301396
# 41                                 int_rate:<9.548      1.066606
# 42                           int_rate:9.548-12.025      0.730101
# 43                          int_rate:12.025-15.745      0.483079
# 44                          int_rate:15.745-20.281      0.226222
# 45              mths_since_earliest_cr_line:94-154      0.041830
# 46             mths_since_earliest_cr_line:154-216      0.038440
# 47             mths_since_earliest_cr_line:216-270      0.063955
# 48             mths_since_earliest_cr_line:271-352      0.138727
# 49                mths_since_earliest_cr_line:>352      0.119801
# 50                                   delinq_2yrs:0      0.018379
# 51                                 delinq_2yrs:1-3     -0.045693
# 52                                inq_last_6mths:0      0.052445
# 53                              inq_last_6mths:1-2     -0.092314
# 54                              inq_last_6mths:3-6     -0.237818
# 55                                    open_acc:4-7     -0.016311
# 56                                   open_acc:8-10     -0.099014
# 57                                  open_acc:11-15     -0.136736
# 58                                  open_acc:16-22     -0.116032
# 59                                  open_acc:23-25     -0.094893
# 60                                  open_acc:26-30     -0.044391
# 61                                   open_acc:>=31     -0.051175
# 62                                     pub_rec:3-4      0.130555
# 63                                     pub_rec:>=5      0.018341
# 64                                 total_acc:28-51     -0.029302
# 65                                  total_acc:>=52     -0.021130
# 66                              acc_now_delinq:>=1      0.083390
# 67                         total_rev_hi_lim:5K-10K      0.201283
# 68                        total_rev_hi_lim:10K-20K      0.184817
# 69                        total_rev_hi_lim:20K-30K      0.209021
# 70                        total_rev_hi_lim:30K-40K      0.222229
# 71                        total_rev_hi_lim:40K-55K      0.230460
# 72                        total_rev_hi_lim:55K-95K      0.272677
# 73                           total_rev_hi_lim:>95K      0.436240
# 74                              annual_inc:20K-30K     -0.199441
# 75                              annual_inc:30K-40K     -0.147327
# 76                              annual_inc:40K-50K     -0.035216
# 77                              annual_inc:50K-60K      0.044307
# 78                              annual_inc:60K-70K      0.111032
# 79                              annual_inc:70K-80K      0.190422
# 80                              annual_inc:80K-90K      0.253956
# 81                             annual_inc:90K-100K      0.284935
# 82                            annual_inc:100K-120K      0.377064
# 83                            annual_inc:120K-140K      0.463459
# 84                                annual_inc:>140K      0.394161
# 85                                       dti:<=1.4      0.006096
# 86                                     dti:1.4-3.5      0.159035
# 87                                     dti:3.5-7.7      0.202460
# 88                                    dti:7.7-10.5      0.160412
# 89                                   dti:10.5-16.1      0.085464
# 90                                   dti:16.1-20.3     -0.000991
# 91                                   dti:20.3-21.7     -0.036637
# 92                                   dti:21.7-22.4     -0.042877
# 93                                     dti:22.4-35     -0.100491
# 94                  mths_since_last_delinq:Missing     -0.098899
# 95                     mths_since_last_delinq:4-30      0.032627
# 96                    mths_since_last_delinq:31-56      0.018269
# 97                     mths_since_last_delinq:>=57     -0.033456
# 98                  mths_since_last_record:Missing     -0.105415
# 99                     mths_since_last_record:3-20      0.113664
# 100                   mths_since_last_record:21-31      0.045805
# 101                   mths_since_last_record:32-80      0.112569
# 102                   mths_since_last_record:81-86     -0.129918
# 103                    mths_since_last_record:>=86     -0.176428

# %%
# P values for sklearn logistic regression.

# Class to display p-values for logistic regression in sklearn.

from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):#,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)#,**args)

    def fit(self,X,y):
        self.model.fit(X,y)
        
        #### Get p-values for the fitted model ####
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X) ## Fisher Information Matrix
        Cramer_Rao = np.linalg.inv(F_ij) ## Inverse Information Matrix
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates # z-score for eaach model coefficient
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores] ### two tailed test for p-values
        
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
X_numeric = inputs_train.astype(np.float64) #having bool variables causes issues with the inverse
y = loan_data_targets_train.values.ravel()

# %%
reg = LogisticRegression_with_p_values()

# %%
reg.fit(X_numeric, y)

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                                       Feature name  Coefficients
# 0                                        Intercept      0.292466
# 1                                          grade:A      0.760025
# 2                                          grade:B      0.542127
# 3                                          grade:C      0.370582
# 4                                          grade:D      0.224076
# 5                                          grade:E      0.133669
# 6                                          grade:F     -0.038649
# 7                               home_ownership:OWN      0.076926
# 8                          home_ownership:MORTGAGE      0.110015
# 9                  addr_state:NH_WY_WV_MS_DC_ME_ID      0.585161
# 10                                   addr_state:CA      0.066328
# 11                                   addr_state:NY      0.101384
# 12                          addr_state:MO_VA_UT_NC      0.100507
# 13                          addr_state:OK_NJ_LA_MD      0.087195
# 14                    addr_state:MN_MI_AZ_TN_AR_OH      0.129710
# 15                       addr_state:DE_PA_WA_IN_MA      0.163507
# 16                       addr_state:OR_RI_GA_SD_WI      0.221025
# 17                                addr_state:CT_KS      0.267669
# 18                                addr_state:TX_IL      0.272453
# 19                    addr_state:IA_SC_CO_MT_VT_AK      0.355124
# 20                verification_status:Not Verified      0.084818
# 21             verification_status:Source Verified     -0.008407
# 22          purpose:house__medical__wedding__other      0.472564
# 23                        purpose:moving__vacation      0.412464
# 24                      purpose:debt_consolidation      0.446075
# 25   purpose:major_purchase__home_improvement__car      0.509876
# 26                             purpose:credit_card      0.566723
# 27                           initial_list_status:w      0.066147
# 28                                         term:36      0.090306
# 29                                    emp_length:1      0.109932
# 30                                  emp_length:2-4      0.134958
# 31                                  emp_length:5-6      0.103168
# 32                                  emp_length:7-9      0.075472
# 33                                   emp_length:10      0.136341
# 34                          mths_since_issue_d:<38      1.100489
# 35                        mths_since_issue_d:38-39      0.831254
# 36                        mths_since_issue_d:40-41      0.620697
# 37                        mths_since_issue_d:42-48      0.353494
# 38                        mths_since_issue_d:49-52      0.116783
# 39                        mths_since_issue_d:53-64     -0.180522
# 40                        mths_since_issue_d:65-84     -0.301396
# 41                                 int_rate:<9.548      1.066606
# 42                           int_rate:9.548-12.025      0.730101
# 43                          int_rate:12.025-15.745      0.483079
# 44                          int_rate:15.745-20.281      0.226222
# 45              mths_since_earliest_cr_line:94-154      0.041830
# 46             mths_since_earliest_cr_line:154-216      0.038440
# 47             mths_since_earliest_cr_line:216-270      0.063955
# 48             mths_since_earliest_cr_line:271-352      0.138727
# 49                mths_since_earliest_cr_line:>352      0.119801
# 50                                   delinq_2yrs:0      0.018379
# 51                                 delinq_2yrs:1-3     -0.045693
# 52                                inq_last_6mths:0      0.052445
# 53                              inq_last_6mths:1-2     -0.092314
# 54                              inq_last_6mths:3-6     -0.237818
# 55                                    open_acc:4-7     -0.016311
# 56                                   open_acc:8-10     -0.099014
# 57                                  open_acc:11-15     -0.136736
# 58                                  open_acc:16-22     -0.116032
# 59                                  open_acc:23-25     -0.094893
# 60                                  open_acc:26-30     -0.044391
# 61                                   open_acc:>=31     -0.051175
# 62                                     pub_rec:3-4      0.130555
# 63                                     pub_rec:>=5      0.018341
# 64                                 total_acc:28-51     -0.029302
# 65                                  total_acc:>=52     -0.021130
# 66                              acc_now_delinq:>=1      0.083390
# 67                         total_rev_hi_lim:5K-10K      0.201283
# 68                        total_rev_hi_lim:10K-20K      0.184817
# 69                        total_rev_hi_lim:20K-30K      0.209021
# 70                        total_rev_hi_lim:30K-40K      0.222229
# 71                        total_rev_hi_lim:40K-55K      0.230460
# 72                        total_rev_hi_lim:55K-95K      0.272677
# 73                           total_rev_hi_lim:>95K      0.436240
# 74                              annual_inc:20K-30K     -0.199441
# 75                              annual_inc:30K-40K     -0.147327
# 76                              annual_inc:40K-50K     -0.035216
# 77                              annual_inc:50K-60K      0.044307
# 78                              annual_inc:60K-70K      0.111032
# 79                              annual_inc:70K-80K      0.190422
# 80                              annual_inc:80K-90K      0.253956
# 81                             annual_inc:90K-100K      0.284935
# 82                            annual_inc:100K-120K      0.377064
# 83                            annual_inc:120K-140K      0.463459
# 84                                annual_inc:>140K      0.394161
# 85                                       dti:<=1.4      0.006096
# 86                                     dti:1.4-3.5      0.159035
# 87                                     dti:3.5-7.7      0.202460
# 88                                    dti:7.7-10.5      0.160412
# 89                                   dti:10.5-16.1      0.085464
# 90                                   dti:16.1-20.3     -0.000991
# 91                                   dti:20.3-21.7     -0.036637
# 92                                   dti:21.7-22.4     -0.042877
# 93                                     dti:22.4-35     -0.100491
# 94                  mths_since_last_delinq:Missing     -0.098899
# 95                     mths_since_last_delinq:4-30      0.032627
# 96                    mths_since_last_delinq:31-56      0.018269
# 97                     mths_since_last_delinq:>=57     -0.033456
# 98                  mths_since_last_record:Missing     -0.105415
# 99                     mths_since_last_record:3-20      0.113664
# 100                   mths_since_last_record:21-31      0.045805
# 101                   mths_since_last_record:32-80      0.112569
# 102                   mths_since_last_record:81-86     -0.129918
# 103                    mths_since_last_record:>=86     -0.176428

# %%
p_values = reg.p_values

# %%
# Add the intercept for completeness.
p_values = np.append(np.nan, np.array(p_values))
# We add the value 'NaN' in the beginning of the variable with p-values.

# %%
summary_table['p_values'] = p_values

# %%
summary_table
# Out:
#                                       Feature name  Coefficients  \
# 0                                        Intercept      0.292466
# 1                                          grade:A      0.760025
# 2                                          grade:B      0.542127
# 3                                          grade:C      0.370582
# 4                                          grade:D      0.224076
# 5                                          grade:E      0.133669
# 6                                          grade:F     -0.038649
# 7                               home_ownership:OWN      0.076926
# 8                          home_ownership:MORTGAGE      0.110015
# 9                  addr_state:NH_WY_WV_MS_DC_ME_ID      0.585161
# 10                                   addr_state:CA      0.066328
# 11                                   addr_state:NY      0.101384
# 12                          addr_state:MO_VA_UT_NC      0.100507
# 13                          addr_state:OK_NJ_LA_MD      0.087195
# 14                    addr_state:MN_MI_AZ_TN_AR_OH      0.129710
# 15                       addr_state:DE_PA_WA_IN_MA      0.163507
# 16                       addr_state:OR_RI_GA_SD_WI      0.221025
# 17                                addr_state:CT_KS      0.267669
# 18                                addr_state:TX_IL      0.272453
# 19                    addr_state:IA_SC_CO_MT_VT_AK      0.355124
# 20                verification_status:Not Verified      0.084818
# 21             verification_status:Source Verified     -0.008407
# 22          purpose:house__medical__wedding__other      0.472564
# 23                        purpose:moving__vacation      0.412464
# 24                      purpose:debt_consolidation      0.446075
# 25   purpose:major_purchase__home_improvement__car      0.509876
# 26                             purpose:credit_card      0.566723
# 27                           initial_list_status:w      0.066147
# 28                                         term:36      0.090306
# 29                                    emp_length:1      0.109932
# 30                                  emp_length:2-4      0.134958
# 31                                  emp_length:5-6      0.103168
# 32                                  emp_length:7-9      0.075472
# 33                                   emp_length:10      0.136341
# 34                          mths_since_issue_d:<38      1.100489
# 35                        mths_since_issue_d:38-39      0.831254
# 36                        mths_since_issue_d:40-41      0.620697
# 37                        mths_since_issue_d:42-48      0.353494
# 38                        mths_since_issue_d:49-52      0.116783
# 39                        mths_since_issue_d:53-64     -0.180522
# 40                        mths_since_issue_d:65-84     -0.301396
# 41                                 int_rate:<9.548      1.066606
# 42                           int_rate:9.548-12.025      0.730101
# 43                          int_rate:12.025-15.745      0.483079
# 44                          int_rate:15.745-20.281      0.226222
# 45              mths_since_earliest_cr_line:94-154      0.041830
# 46             mths_since_earliest_cr_line:154-216      0.038440
# 47             mths_since_earliest_cr_line:216-270      0.063955
# 48             mths_since_earliest_cr_line:271-352      0.138727
# 49                mths_since_earliest_cr_line:>352      0.119801
# 50                                   delinq_2yrs:0      0.018379
# 51                                 delinq_2yrs:1-3     -0.045693
# 52                                inq_last_6mths:0      0.052445
# 53                              inq_last_6mths:1-2     -0.092314
# 54                              inq_last_6mths:3-6     -0.237818
# 55                                    open_acc:4-7     -0.016311
# 56                                   open_acc:8-10     -0.099014
# 57                                  open_acc:11-15     -0.136736
# 58                                  open_acc:16-22     -0.116032
# 59                                  open_acc:23-25     -0.094893
# 60                                  open_acc:26-30     -0.044391
# 61                                   open_acc:>=31     -0.051175
# 62                                     pub_rec:3-4      0.130555
# 63                                     pub_rec:>=5      0.018341
# 64                                 total_acc:28-51     -0.029302
# 65                                  total_acc:>=52     -0.021130
# 66                              acc_now_delinq:>=1      0.083390
# 67                         total_rev_hi_lim:5K-10K      0.201283
# 68                        total_rev_hi_lim:10K-20K      0.184817
# 69                        total_rev_hi_lim:20K-30K      0.209021
# 70                        total_rev_hi_lim:30K-40K      0.222229
# 71                        total_rev_hi_lim:40K-55K      0.230460
# 72                        total_rev_hi_lim:55K-95K      0.272677
# 73                           total_rev_hi_lim:>95K      0.436240
# 74                              annual_inc:20K-30K     -0.199441
# 75                              annual_inc:30K-40K     -0.147327
# 76                              annual_inc:40K-50K     -0.035216
# 77                              annual_inc:50K-60K      0.044307
# 78                              annual_inc:60K-70K      0.111032
# 79                              annual_inc:70K-80K      0.190422
# 80                              annual_inc:80K-90K      0.253956
# 81                             annual_inc:90K-100K      0.284935
# 82                            annual_inc:100K-120K      0.377064
# 83                            annual_inc:120K-140K      0.463459
# 84                                annual_inc:>140K      0.394161
# 85                                       dti:<=1.4      0.006096
# 86                                     dti:1.4-3.5      0.159035
# 87                                     dti:3.5-7.7      0.202460
# 88                                    dti:7.7-10.5      0.160412
# 89                                   dti:10.5-16.1      0.085464
# 90                                   dti:16.1-20.3     -0.000991
# 91                                   dti:20.3-21.7     -0.036637
# 92                                   dti:21.7-22.4     -0.042877
# 93                                     dti:22.4-35     -0.100491
# 94                  mths_since_last_delinq:Missing     -0.098899
# 95                     mths_since_last_delinq:4-30      0.032627
# 96                    mths_since_last_delinq:31-56      0.018269
# 97                     mths_since_last_delinq:>=57     -0.033456
# 98                  mths_since_last_record:Missing     -0.105415
# 99                     mths_since_last_record:3-20      0.113664
# 100                   mths_since_last_record:21-31      0.045805
# 101                   mths_since_last_record:32-80      0.112569
# 102                   mths_since_last_record:81-86     -0.129918
# 103                    mths_since_last_record:>=86     -0.176428
#
#           p_values
# 0              NaN
# 1     1.515451e-13
# 2     5.447036e-16
# 3     2.524605e-09
# 4     1.549214e-04
# 5     1.093989e-02
# 6     4.776006e-01
# 7     3.933006e-04
# 8     8.977323e-16
# 9     2.511586e-26
# 10    2.329312e-03
# 11    6.494626e-05
# 12    8.424873e-05
# 13    6.656178e-04
# 14    2.430739e-08
# 15    3.587338e-11
# 16    9.734711e-15
# 17    2.472262e-10
# 18    1.247845e-29
# 19    4.861152e-24
# 20    7.106671e-08
# 21    5.624019e-01
# 22    3.990355e-33
# 23    1.654821e-12
# 24    2.770718e-36
# 25    2.317679e-37
# 26    1.275770e-51
# 27    3.823445e-06
# 28    3.142131e-09
# 29    8.367394e-05
# 30    2.995188e-11
# 31    6.826989e-06
# 32    7.456561e-04
# 33    6.627496e-12
# 34   5.726090e-103
# 35    1.199039e-72
# 36    8.412228e-44
# 37    6.264720e-18
# 38    6.275530e-03
# 39    7.419930e-06
# 40    1.192697e-21
# 41    2.220256e-34
# 42    6.975335e-52
# 43    7.090351e-34
# 44    8.323536e-13
# 45    4.835219e-01
# 46    5.138907e-01
# 47    2.824635e-01
# 48    2.121465e-02
# 49    5.189991e-02
# 50    7.673698e-01
# 51    4.364156e-01
# 52    6.521757e-01
# 53    4.272413e-01
# 54    4.172974e-02
# 55    7.103897e-01
# 56    2.667929e-02
# 57    2.521183e-03
# 58    1.569409e-02
# 59    1.562473e-01
# 60    5.930388e-01
# 61    6.668607e-01
# 62    2.288745e-01
# 63    9.294449e-01
# 64    5.632234e-02
# 65    6.229225e-01
# 66    4.843318e-01
# 67    5.192559e-10
# 68    3.556465e-10
# 69    1.688633e-11
# 70    4.829088e-11
# 71    1.398963e-10
# 72    1.041934e-11
# 73    5.378198e-12
# 74    2.365592e-05
# 75    1.227815e-03
# 76    4.404856e-01
# 77    3.385966e-01
# 78    1.901557e-02
# 79    8.052711e-05
# 80    4.166404e-07
# 81    4.144319e-08
# 82    3.099852e-13
# 83    2.247828e-15
# 84    3.867010e-13
# 85    9.501511e-01
# 86    6.075486e-02
# 87    7.523100e-03
# 88    3.321251e-02
# 89    2.440636e-01
# 90    9.892244e-01
# 91    6.287587e-01
# 92    5.903760e-01
# 93    1.668225e-01
# 94    1.340724e-01
# 95    5.930269e-01
# 96    7.857081e-01
# 97    6.245000e-01
# 98    3.087855e-01
# 99    4.492630e-01
# 100   7.403719e-01
# 101   2.976236e-01
# 102   3.011842e-01
# 103   9.678939e-02
