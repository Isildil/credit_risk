# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the data and selecting features

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv', index_col=0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv', index_col=0)
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv', index_col=0)
loan_data_targets_test = pd.read_csv('loan_data_targets_test.csv', index_col=0, header = None)

# %%
loan_data_inputs_train.head()
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 427211      427211  12796369   14818505      24000        24000
# 206088      206088   1439740    1691948      10000        10000
# 136020      136020   5214749    6556909      20425        20425
# 412305      412305  13827698   15890016      17200        17200
# 36159        36159    422455     496525       8400         8400
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 427211          24000.0   36 months      8.90       762.08     A  ...
# 206088          10000.0   36 months     14.33       343.39     C  ...
# 136020          20425.0   36 months      8.90       648.56     A  ...
# 412305          17200.0   36 months     16.59       609.73     D  ...
# 36159            7450.0   36 months     12.84       282.40     C  ...
#
#        dti:21.7-22.4 dti:22.4-35 dti:>35 mths_since_last_record:Missing  \
# 427211             1           0       0                              1
# ...

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         1
# 36159          0

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_NV_FL_AL_NM_HI_KY',
'addr_state:NH_WY_WV_MS_DC_ME_ID',
'addr_state:CA',
'addr_state:NY',
'addr_state:MO_VA_UT_NC',
'addr_state:OK_NJ_LA_MD',
'addr_state:MN_MI_AZ_TN_AR_OH',
'addr_state:DE_PA_WA_IN_MA',
'addr_state:OR_RI_GA_SD_WI',
'addr_state:CT_KS',
'addr_state:TX_IL',
'addr_state:IA_SC_CO_MT_VT_AK',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:renewable_energy__small_business__educational',
'purpose:house__medical__wedding__other',
'purpose:moving__vacation',
'purpose:debt_consolidation',
'purpose:major_purchase__home_improvement__car',
'purpose:credit_card',                                                          
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.745',
'int_rate:15.745-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<94',
'mths_since_earliest_cr_line:94-154',
'mths_since_earliest_cr_line:154-216',
'mths_since_earliest_cr_line:216-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:<4',
'open_acc:4-7',
'open_acc:8-10',
'open_acc:11-15',
'open_acc:16-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:<48',
'mths_since_last_record:48-64',
'mths_since_last_record:65-80',
'mths_since_last_record:81-95',
'mths_since_last_record:96-100',
'mths_since_last_record:>100',
]]

# %%
ref_categories=['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_NV_FL_AL_NM_HI_KY',
'verification_status:Verified',
'purpose:renewable_energy__small_business__educational',                                                           
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<94',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:<4',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:<48']

# %%
#dropping the ref categories to avoid multicollinearity
inputs_train= inputs_train_with_ref_cat.drop(ref_categories,axis=1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211     True    False    False    False    False    False
# 206088    False    False     True    False    False    False
# 136020     True    False    False    False    False    False
# 412305    False    False    False     True    False    False
# 36159     False    False     True    False    False    False
#
#         home_ownership:OWN  home_ownership:MORTGAGE  \
# 427211               False                     True
# 206088               False                     True
# 136020               False                     True
# 412305               False                    False
# 36159                False                     True
#
#         addr_state:NH_WY_WV_MS_DC_ME_ID  addr_state:CA  ...  \
# 427211                                0              0  ...
# 206088                                0              0  ...
# 136020                                0              0  ...
# ...

# %% [markdown]
# # PD Model Estimation

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
pd.options.display.max_rows=None

# %%
inputs_train.shape
# Out:
# (373028, 103)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
reg.fit(inputs_train, loan_data_targets_train.values.ravel())
# Out:
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([0.30940201])

# %%
reg.coef_
# Out:
# array([[ 0.7572211 ,  0.68336487,  0.51700574,  0.37065749,  0.26556177,
#          0.11144792,  0.08730876,  0.10822826,  0.43477526,  0.03556643,
#          0.07159512,  0.06691447,  0.05581727,  0.09918231,  0.13300997,
#          0.18321777,  0.24192236,  0.24230466,  0.34172699,  0.08165505,
#         -0.00905453,  0.5237892 ,  0.49225602,  0.50510737,  0.56679591,
#          0.62806013,  0.06632197,  0.09344646,  0.11513599,  0.13863596,
#          0.10825639,  0.0777652 ,  0.13708945,  1.22316439,  0.90268433,
#          0.69618427,  0.4347775 ,  0.19822784, -0.10047398, -0.29503399,
#          1.17835385,  0.70712969,  0.46124523,  0.20389628,  0.07264406,
#          0.07068947,  0.09481343,  0.1697327 ,  0.15840564,  0.08005091,
#          0.02489314, -0.14215486, -0.29242754, -0.43361323, -0.0398287 ,
#         -0.12266621, -0.16349265, -0.15107814, -0.18544496, -0.17140743,
#         -0.16415528,  0.15018371,  0.01406736, -0.01568341,  0.0723341 ,
# ...

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index+1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                                       Feature name  Coefficients
# 0                                        Intercept      0.309402
# 1                                          grade:A      0.757221
# 2                                          grade:B      0.683365
# 3                                          grade:C      0.517006
# 4                                          grade:D      0.370657
# 5                                          grade:E      0.265562
# 6                                          grade:F      0.111448
# 7                               home_ownership:OWN      0.087309
# 8                          home_ownership:MORTGAGE      0.108228
# 9                  addr_state:NH_WY_WV_MS_DC_ME_ID      0.434775
# 10                                   addr_state:CA      0.035566
# 11                                   addr_state:NY      0.071595
# 12                          addr_state:MO_VA_UT_NC      0.066914
# ...

# %%
# P values for sklearn logistic regression.

# Class to display p-values for logistic regression in sklearn.

from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):#,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)#,**args)

    def fit(self,X,y):
        self.model.fit(X,y)
        
        #### Get p-values for the fitted model ####
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X) ## Fisher Information Matrix
        Cramer_Rao = np.linalg.inv(F_ij) ## Inverse Information Matrix
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates # z-score for eaach model coefficient
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores] ### two tailed test for p-values
        
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
X_numeric = inputs_train.astype(np.float64) #having bool variables causes issues with the inverse
y = loan_data_targets_train.values.ravel()

# %%
reg = LogisticRegression_with_p_values()

# %%
reg.fit(X_numeric, y)

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                                       Feature name  Coefficients
# 0                                        Intercept      0.309402
# 1                                          grade:A      0.757221
# 2                                          grade:B      0.683365
# 3                                          grade:C      0.517006
# 4                                          grade:D      0.370657
# 5                                          grade:E      0.265562
# 6                                          grade:F      0.111448
# 7                               home_ownership:OWN      0.087309
# 8                          home_ownership:MORTGAGE      0.108228
# 9                  addr_state:NH_WY_WV_MS_DC_ME_ID      0.434775
# 10                                   addr_state:CA      0.035566
# 11                                   addr_state:NY      0.071595
# 12                          addr_state:MO_VA_UT_NC      0.066914
# ...

# %%
p_values = reg.p_values

# %%
# Add the intercept for completeness.
p_values = np.append(np.nan, np.array(p_values))
# We add the value 'NaN' in the beginning of the variable with p-values.

# %%
summary_table['p_values'] = p_values

# %%
summary_table
# Out:
#                                       Feature name  Coefficients  \
# 0                                        Intercept      0.309402
# 1                                          grade:A      0.757221
# 2                                          grade:B      0.683365
# 3                                          grade:C      0.517006
# 4                                          grade:D      0.370657
# 5                                          grade:E      0.265562
# 6                                          grade:F      0.111448
# 7                               home_ownership:OWN      0.087309
# 8                          home_ownership:MORTGAGE      0.108228
# 9                  addr_state:NH_WY_WV_MS_DC_ME_ID      0.434775
# 10                                   addr_state:CA      0.035566
# 11                                   addr_state:NY      0.071595
# 12                          addr_state:MO_VA_UT_NC      0.066914
# ...

# %%
#owerwriting the  df with only the variables that have at least one cat that is stat. significant
#dropping: 
#delinq_2yrs
#pub_rec
#mths since last delinq
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_NV_FL_AL_NM_HI_KY',
'addr_state:NH_WY_WV_MS_DC_ME_ID',
'addr_state:CA',
'addr_state:NY',
'addr_state:MO_VA_UT_NC',
'addr_state:OK_NJ_LA_MD',
'addr_state:MN_MI_AZ_TN_AR_OH',
'addr_state:DE_PA_WA_IN_MA',
'addr_state:OR_RI_GA_SD_WI',
'addr_state:CT_KS',
'addr_state:TX_IL',
'addr_state:IA_SC_CO_MT_VT_AK',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:renewable_energy__small_business__educational',
'purpose:house__medical__wedding__other',
'purpose:moving__vacation',
'purpose:debt_consolidation',
'purpose:major_purchase__home_improvement__car',
'purpose:credit_card',                                                          
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.745',
'int_rate:15.745-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<94',
'mths_since_earliest_cr_line:94-154',
'mths_since_earliest_cr_line:154-216',
'mths_since_earliest_cr_line:216-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:<4',
'open_acc:4-7',
'open_acc:8-10',
'open_acc:11-15',
'open_acc:16-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_record:Missing',
'mths_since_last_record:<48',
'mths_since_last_record:48-64',
'mths_since_last_record:65-80',
'mths_since_last_record:81-95',
'mths_since_last_record:96-100',
'mths_since_last_record:>100',
]]

# %%
ref_categories=['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_NV_FL_AL_NM_HI_KY',
'verification_status:Verified',
'purpose:renewable_energy__small_business__educational',                                                           
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<94',
'inq_last_6mths:>6',
'open_acc:<4',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_record:<48']

# %%
#dropping the ref categories to avoid multicollinearity
inputs_train_b= inputs_train_with_ref_cat.drop(ref_categories,axis=1)

# %%
inputs_train = inputs_train_b.astype(int) 
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  \
# 427211                   0                        1
# 206088                   0                        1
# 136020                   0                        1
# 412305                   0                        0
# 36159                    0                        1
#
#         addr_state:NH_WY_WV_MS_DC_ME_ID  addr_state:CA  ...  dti:16.1-20.3  \
# 427211                                0              0  ...              0
# 206088                                0              0  ...              0
# ...

# %%
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train.values.ravel())

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index+1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                                      Feature name  Coefficients
# 0                                       Intercept      0.309402
# 1                                         grade:A      0.748797
# 2                                         grade:B      0.693751
# 3                                         grade:C      0.523098
# 4                                         grade:D      0.376644
# 5                                         grade:E      0.275048
# 6                                         grade:F      0.106515
# 7                              home_ownership:OWN      0.086054
# 8                         home_ownership:MORTGAGE      0.106953
# 9                 addr_state:NH_WY_WV_MS_DC_ME_ID      0.423211
# 10                                  addr_state:CA      0.033786
# 11                                  addr_state:NY      0.068323
# 12                         addr_state:MO_VA_UT_NC      0.064585
# 13                         addr_state:OK_NJ_LA_MD      0.054788
# ...

# %%
p_values = reg2.p_values
p_values = np.append(np.nan,np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Out:
#                                      Feature name  Coefficients       p_values
# 0                                       Intercept      0.309402            NaN
# 1                                         grade:A      0.748797   9.055662e-13
# 2                                         grade:B      0.693751   2.885542e-26
# 3                                         grade:C      0.523098   6.503616e-18
# 4                                         grade:D      0.376644   6.666106e-11
# 5                                         grade:E      0.275048   6.481224e-08
# 6                                         grade:F      0.106515   4.402957e-02
# 7                              home_ownership:OWN      0.086054   7.470623e-05
# 8                         home_ownership:MORTGAGE      0.106953   4.578913e-15
# 9                 addr_state:NH_WY_WV_MS_DC_ME_ID      0.423211   8.050491e-16
# 10                                  addr_state:CA      0.033786   1.224534e-01
# ...

# %% [markdown]
# # PD Model Test

# %%
inputs_test_with_ref_cat = loan_data_inputs_test.loc[:, ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_NV_FL_AL_NM_HI_KY',
'addr_state:NH_WY_WV_MS_DC_ME_ID',
'addr_state:CA',
'addr_state:NY',
'addr_state:MO_VA_UT_NC',
'addr_state:OK_NJ_LA_MD',
'addr_state:MN_MI_AZ_TN_AR_OH',
'addr_state:DE_PA_WA_IN_MA',
'addr_state:OR_RI_GA_SD_WI',
'addr_state:CT_KS',
'addr_state:TX_IL',
'addr_state:IA_SC_CO_MT_VT_AK',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:renewable_energy__small_business__educational',
'purpose:house__medical__wedding__other',
'purpose:moving__vacation',
'purpose:debt_consolidation',
'purpose:major_purchase__home_improvement__car',
'purpose:credit_card',                                                          
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.745',
'int_rate:15.745-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<94',
'mths_since_earliest_cr_line:94-154',
'mths_since_earliest_cr_line:154-216',
'mths_since_earliest_cr_line:216-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:<4',
'open_acc:4-7',
'open_acc:8-10',
'open_acc:11-15',
'open_acc:16-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_record:Missing',
'mths_since_last_record:<48',
'mths_since_last_record:48-64',
'mths_since_last_record:65-80',
'mths_since_last_record:81-95',
'mths_since_last_record:96-100',
'mths_since_last_record:>100',
]]

# %%
inputs_test_b= inputs_test_with_ref_cat.drop(ref_categories,axis=1)

# %%
inputs_test = inputs_test_b.astype(int) 
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514        0        0        1        0        0        0
# 288564        0        0        0        0        1        0
# 213591        0        0        1        0        0        0
# 263083        0        0        1        0        0        0
# 165001        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  \
# 362514                   0                        1
# 288564                   0                        1
# 213591                   0                        1
# 263083                   0                        1
# 165001                   0                        1
#
#         addr_state:NH_WY_WV_MS_DC_ME_ID  addr_state:CA  ...  dti:16.1-20.3  \
# 362514                                0              1  ...              0
# 288564                                0              0  ...              0
# ...

# %%
y_hat_test = reg2.model.predict(inputs_test)

# %%
y_hat_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
y_hat_test_proba = reg2.model.predict_proba(inputs_test)

# %%
y_hat_test_proba
# Out:
# array([[0.05483034, 0.94516966],
#        [0.09382551, 0.90617449],
#        [0.11012767, 0.88987233],
#        ...,
#        [0.02269729, 0.97730271],
#        [0.03194841, 0.96805159],
#        [0.0466496 , 0.9533504 ]])

# %%
y_hat_test_proba[:][: , 1] #keep only the second column (both sum 1 so we only need one to know the probability of being a good or bad borrower), the probability of being a good borrower
# Out:
# array([0.94516966, 0.90617449, 0.88987233, ..., 0.97730271, 0.96805159,
#        0.9533504 ])

# %%
y_hat_test_proba= y_hat_test_proba[:][: , 1]

# %%
y_hat_test_proba[93256]
# Out:
# 0.9533503958022623

# %%
loan_data_targets_test_temp=loan_data_targets_test

# %%
loan_data_targets_test_temp=loan_data_targets_test_temp[1:]

# %%
loan_data_targets_test_temp.reset_index(drop = True, inplace= True)

# %%
df_predicted_probs= pd.concat([loan_data_targets_test_temp, pd.DataFrame(y_hat_test_proba)],axis=1)

# %%
df_predicted_probs.columns=['loan_data_targets_test','y_hat_test_proba']

# %%
df_predicted_probs.index = loan_data_inputs_test.index

# %%
df_predicted_probs.head()
# Out:
#        loan_data_targets_test  y_hat_test_proba
# 362514                      1          0.945170
# 288564                      1          0.906174
# 213591                      1          0.889872
# 263083                      1          0.962954
# 165001                      1          0.971189
